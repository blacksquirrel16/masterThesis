# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

avg_data_ndcg = {
    'cf': {
        'di_ndcg': [1.02602, 0.579479, 1.643193],# DONE
        'gru_ndcg': [0.000035, 0.000632, 0.000792],# DONE
        'ucv_ndcg': [23.958175, 22.053886, 23.765452],# DONE
        'avg_ndcg': [0.001360,0.001399,0.001362]# DONE
    },
    'cb': {
        'di_ndcg': [1.3003, 1.5186, 1.7254],# DONE
        'gru_ndcg': [ 0.005288, 0.002698, 0.001507],# DONE
        'ucv_ndcg': [6.5519, 11.4271, 17.2364],# DONE
        'avg_ndcg': [ 0.018932, 0.005737, 0.002374]# DONE
    },
    'hybrid': {
        'di_ndcg': [1.374453,1.375262, 1.374630],# DOME
        'gru_ndcg': [0.014184, 0.014208, 0.014208],# DONE
        'ucv_ndcg': [3.7838,3.7846, 3.7808],# DONE
        'avg_ndcg': [0.041831,  0.041821, 0.041882]# DONE
    },
    'warp': {
        'di_ndcg': [2.768467, 3.251485, 3.610232],# DONE
        'gru_ndcg': [0.009466, 0.011479, 0.013396],# DONE
        'ucv_ndcg': [8.485735, 8.395601,8.340071],# DONE
        'avg_ndcg': [0.006912, 0.006990, 0.007339]# DONE
    },
    'bpr': {
        'di_ndcg': [1.948876, 1.642475, 0.981884],# DONE
        'gru_ndcg': [0.002662, 0.001777, 0.00005],# DONE
        'ucv_ndcg': [11.646441, 12.307827, 13.074922],# DONE
        'avg_ndcg': [0.003244, 0.003059, 0.002938]# DONE
    }
}

low_data_ndcg = {
    'cf': {
        'di_ndcg': [0, 0, 0],
        'gru_ndcg': [0, 0, 0],
        'ucv_ndcg': [0, 0, 0],
        'avg_ndcg': [0.001390, 0.000871, 0.002023]# DONE
    },
    'cb': {
        'di_ndcg': [0, 0, 0],
        'gru_ndcg': [0, 0, 0],
        'ucv_ndcg': [0, 0, 0],
        'avg_ndcg': [0.022891 , 0.007899, 0.003584]# DONE
    },
    'hybrid': {
        'di_ndcg': [0, 0, 0],
        'gru_ndcg': [0, 0, 0],
        'ucv_ndcg': [0, 0, 0],
        'avg_ndcg': [0.052064, 0.052072 ,0.052132]# DONE
    },
    'warp': {
        'di_ndcg': [0, 0, 0],
        'gru_ndcg': [0, 0, 0],
        'ucv_ndcg': [0, 0, 0],
        'avg_ndcg': [0.014819, 0.016578, 0.018528]# DONE
    },
    'bpr': {
        'di_ndcg': [0, 0, 0],
        'gru_ndcg': [0, 0, 0],
        'ucv_ndcg': [0, 0, 0],
        'avg_ndcg': [ 0.005467, 0.004544, 0.002894]# DONE
    }
}

high_data_ndcg = {
    'cf': {
        'di_ndcg': [0, 0, 0],
        'gru_ndcg': [0, 0, 0],
        'ucv_ndcg': [0, 0, 0],
        'avg_ndcg': [0.001354, 0.001503, 0.001231] # DONE
    },
    'cb': {
        'di_ndcg': [0, 0, 0],
        'gru_ndcg': [0, 0, 0],
        'ucv_ndcg': [0, 0, 0],
        'avg_ndcg': [0.017603 , 0.005201, 0.002077]# DONE
    },
    'hybrid': {
        'di_ndcg': [0, 0, 0],
        'gru_ndcg': [0, 0, 0],
        'ucv_ndcg': [0, 0, 0],
        'avg_ndcg': [0.037880, 0.037863, 0.037924]# DONE
    },
    'warp': {
        'di_ndcg': [0, 0, 0],
        'gru_ndcg': [0, 0, 0],
        'ucv_ndcg': [0, 0, 0],
        'avg_ndcg': [0.005353, 0.005099, 0.005132]# DONE
    },
    'bpr': {
        'di_ndcg': [0, 0, 0],
        'gru_ndcg': [0, 0, 0],
        'ucv_ndcg': [0, 0, 0],
        'avg_ndcg': [0.002805, 0.002766, 0.002947]# DONE
    }
}

avg_data_hr = {
    'cf': {
        'di_hr': [1.086167, 0.844797, 1.169718],# DONE
        'gru_hr': [0.000160, 0.000372, 0.000294],# DONE
        'ucv_hr': [22.68062, 21.311081, 23.118368],# DONE
        'avg_hr': [0.001889, 0.002333, 0.001778]# DONE
    },
    'cb': {
        'di_hr': [1.311, 1.5825, 2.0391],# DONE
        'gru_hr': [0.006710, 0.004160, 0.002951],# DONE
        'ucv_hr': [6.2972, 10.5721, 15.9197],# DONE
        'avg_hr': [ 0.023265, 0.007967, 0.003421]# DONE
    },
    'hybrid': {
        'di_hr': [1.3693,1.3704,  1.3692],# DONE
        'gru_hr': [0.023429, 0.02348, 0.02346],# DONE
        'ucv_hr': [3.5420, 3.5428, 3.5390],# DONE
        'avg_hr': [0.069973, 0.069936,  0.070082]# DONE
    },
    'warp': {
        'di_hr': [ 2.467695, 3.069824, 3.548146],# DONE
        'gru_hr': [0.014839, 0.019550, 0.023729],# DONE
        'ucv_hr': [8.073164, 8.013839, 7.862043],# DONE
        'avg_hr': [0.012556, 0.012667, 0.013222]# DONE
    },
    'bpr': {
        'di_hr': [1.930964, 1.568908, 1.013756],# DONE
        'gru_hr': [0.005202, 0.003178, 0.000082],# DONE
        'ucv_hr': [11.458065, 11.987268, 12.841696],# DONE
        'avg_hr': [ 0.006444, 0.006111, 0.006]# DONE
    }
}

low_data_hr = {
    'cf': {
        'di_hr': [0, 0, 0],
        'gru_hr': [0, 0, 0],
        'ucv_hr': [0, 0, 0],
        'avg_hr': [0.002023, 0.002333, 0.002022]# DONE
    },
    'cb': {
        'di_hr': [0, 0, 0],
        'gru_hr': [0, 0, 0],
        'ucv_hr': [0, 0, 0],
        'avg_hr': [0.028289 , 0.011302 , 0.005792]# DONE
    },
    'hybrid': {
        'di_hr': [0, 0, 0],
        'gru_hr': [0, 0, 0],
        'ucv_hr': [0,0,0],
        'avg_hr': [0.08688, 0.086877, 0.087008]# DONE
    },
    'warp': {
        'di_hr': [0, 0, 0],
        'gru_hr': [0, 0, 0],
        'ucv_hr': [0, 0, 0],
        'avg_hr': [0.024949, 0.028995, 0.033041]# DONE
    },
    'bpr': {
        'di_hr': [0, 0, 0],
        'gru_hr': [0, 0, 0],
        'ucv_hr': [0, 0, 0],
        'avg_hr': [0.010789, 0.008766, 0.006067]# DONE
    }
}

high_data_hr = {
    'cf': {
        'di_hr': [0, 0, 0],
        'gru_hr': [0, 0, 0],
        'ucv_hr': [0, 0, 0],
        'avg_hr': [0.001862, 0.002395, 0.001729]# DONE
    },
    'cb': {
        'di_hr': [0, 0, 0],
        'gru_hr': [0, 0, 0],
        'ucv_hr': [0, 0, 0],
        'avg_hr': [0.021579, 0.007141, 0.002840]# DONE
    },
    'hybrid': {
        'di_hr': [0, 0, 0],
        'gru_hr': [0, 0, 0],
        'ucv_hr': [0,0,0],
        'avg_hr': [0.063447, 0.063397,  0.063548 ]# DONE
    },
    'warp': {
        'di_hr': [0, 0, 0],
        'gru_hr': [0, 0, 0],
        'ucv_hr': [0, 0, 0],
        'avg_hr': [0.010110, 0.009445, 0.009312]# DONE
    },
    'bpr': {
        'di_hr': [0,0,0],
        'gru_hr': [0,0,0],
        'ucv_hr': [0,0,0],
        'avg_hr': [0.005587, 0.005587, 0.005986]# DONE
    }
}

avg_data_mrr = {
    'cf': {
        'di_mrr': [0.994807, 0.416232, 1.900792],# DONE
        'gru_mrr': [0.000006, 0.000709, 0.000959],# DONE
        'ucv_mrr': [25.594556, 23.17701, 24.598035],# DONE
        'avg_mrr': [0.001185, 0.001098, 0.001222]# DONE
    },
    'cb': {
        'di_mrr': [1.2585, 1.5899,  1.7982], # DONE
        'gru_mrr': [ 0.005314,  0.003384, 0.001892],# DONE
        'ucv_mrr': [6.4714, 11.3142, 17.0474],# DONE
        'avg_mrr': [0.021894, 0.006407, 0.002743]# DONE
    },
    'hybrid': {
        'di_mrr': [1.3755, 1.3761, 1.3758],# DONE
        'gru_mrr': [ 0.011094, 0.011111, 0.011115],# DONE
        'ucv_mrr': [4.1933, 4.1939, 4.1903],# DONE
        'avg_mrr': [0.032635, 0.032633,  0.032668]# DONE
    },
    'warp': {
        'di_mrr': [3.015304, 3.410796, 3.658802],# DONE
        'gru_mrr': [0.007677, 0.008857, 0.010045],# DONE
        'ucv_mrr': [ 9.302230, 9.154596, 9.273057],# DONE
        'avg_mrr': [0.005074, 0.005133, 0.005433]# DONE
    },
    'bpr': {
        'di_mrr': [1.964597, 1.701705, 0.95183],# DONE
        'gru_mrr': [0.001826, .001302, 0.000094],# DONE
        'ucv_mrr': [12.075506, 13.054980, 13.673085],# DONE
        'avg_mrr': [0.002194, 0.002070, 0.001944]# DONE
    }
}

low_data_mrr = {
    'cf': {
        'di_mrr': [0.0, 0.0, 0.0],
        'gru_mrr': [0.0, 0.0, 0.0],
        'ucv_mrr': [0.0, 0.0, 0.0],
        'avg_mrr': [0.001180, 0.000506, 0.002023]# DONE
    },
    'cb': {
        'di_mrr': [0, 0, 0],
        'gru_mrr': [0, 0, 0],
        'ucv_mrr': [0.0, 0.0, 0.0],
        'avg_mrr': [0.004263,  0.009119 , 0.025872]# DONE
    },
    'hybrid': {
        'di_mrr': [0, 0, 0],
        'gru_mrr': [0, 0, 0],
        'ucv_mrr': [0, 0, 0],
        'avg_mrr': [0.040638,  0.040649, 0.040686]# DONE
    },
    'warp': {
        'di_mrr': [0, 0, 0],
        'gru_mrr': [0, 0, 0],
        'ucv_mrr': [0, 0, 0],
        'avg_mrr': [0.011486, 0.012531, 0.013823]# DONE
    },
    'bpr': {
        'di_mrr': [0, 0, 0],
        'gru_mrr': [0, 0, 0],
        'ucv_mrr': [0, 0, 0],
        'avg_mrr': [0.00372, 0.003158, 0.001866]# DONE
    }
}

high_data_mrr = {
    'cf': {
        'di_mrr': [0, 0, 0],
        'gru_mrr': [0.0, 0.0, 0.0],
        'ucv_mrr': [0, 0, 0],
        'avg_mrr': [0.001186, 0.001215, 0.001064]# DONE
    },
    'cb': {
        'di_mrr': [0, 0, 0],
        'gru_mrr': [0, 0, 0],
        'ucv_mrr': [0, 0, 0],
        'avg_mrr': [0.002371, 0.005736 , 0.020558]# DONE
    },
    'hybrid': {
        'di_mrr': [0, 0, 0],
        'gru_mrr': [0, 0, 0],
        'ucv_mrr': [0, 0, 0],
        'avg_mrr': [0.029545, 0.029539, 0.029572]# DONE
    },
    'warp': {
        'di_mrr': [0, 0, 0],
        'gru_mrr': [0, 0, 0],
        'ucv_mrr': [0, 0, 0],
        'avg_mrr': [0.003809, 0.003673, 0.003778]# DONE
    },
    'bpr': {
        'di_mrr': [0, 0, 0],
        'gru_mrr': [0, 0, 0],
        'ucv_mrr': [0, 0, 0],
        'avg_mrr': [0.001893, 0.001856, 0.001960]# DONE
    }
}

models = ['cf', 'cb', 'hybrid', 'warp', 'bpr']

def plot_metrics(avg_d, low_d, high_d, model_name, axs, metrics):
    rounds = [1, 2, 3]
    colors = {'avg': '#1f77b4', 'low': '#2ca02c', 'high': '#d62728'}
    labels = {'avg': 'Average', 'low': 'Low', 'high': 'High'}
    formatter = FuncFormatter(lambda x, _: f'{x:.6f}')

    for i, metric in enumerate(metrics):
        ax = axs[i]
        ax.plot(rounds, avg_d[metric], label=labels['avg'], marker='o', color=colors['avg'])
        ax.plot(rounds, low_d[metric], label=labels['low'], marker='o', color=colors['low'])
        ax.plot(rounds, high_d[metric], label=labels['high'], marker='o', color=colors['high'])
        ax.set_title(f'{metric.upper()} over Rounds', fontsize=12)
        ax.set_xlabel('Round', fontsize=10)
        ax.set_ylabel(metric.upper(), fontsize=10)
        ax.yaxis.set_major_formatter(formatter)
        ax.set_xticks(rounds)
        ax.tick_params(axis='both', which='major', labelsize=8)
        ax.legend(fontsize=9)

# Plot NDCG
metrics_ndcg = ['avg_ndcg','di_ndcg', 'gru_ndcg', 'ucv_ndcg']
fig, axes = plt.subplots(len(models), len(metrics_ndcg), figsize=(14, 14), sharex=True)
for row_idx, model in enumerate(models):
    plot_metrics(avg_data_ndcg.get(model, {}), low_data_ndcg.get(model, {}), high_data_ndcg.get(model, {}), model, axes[row_idx], metrics_ndcg)
    axes[row_idx][0].set_ylabel(f'{model.upper()}', rotation=90, size='large')
fig.add_artist(plt.Line2D([0.255, 0.255], [0, 0.95],
                          transform=fig.transFigure, color='gray', linestyle='--', linewidth=2))
#plt.suptitle('NDCG Metrics (DI, GRU, UCV, AVG) over 3 Rounds for RentTheRunway Models', fontsize=18)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('ndcg__rent_metrics.png')
plt.show()

# Plot HR
metrics_hr = ['avg_hr','di_hr', 'gru_hr', 'ucv_hr' ]
fig, axes = plt.subplots(len(models), len(metrics_hr), figsize=(14, 14), sharex=True)
for row_idx, model in enumerate(models):
    plot_metrics(avg_data_hr.get(model, {}), low_data_hr.get(model, {}), high_data_hr.get(model, {}), model, axes[row_idx], metrics_hr)
    axes[row_idx][0].set_ylabel(f'{model.upper()}', rotation=90, size='large')
fig.add_artist(plt.Line2D([0.255, 0.255], [0, 0.95],
                          transform=fig.transFigure, color='gray', linestyle='--', linewidth=2))
#plt.suptitle('HR Metrics (DI, GRU, UCV, AVG) over 3 Rounds for RentTheRunway Models', fontsize=18)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('hr__rent_metrics.png')
plt.show()

# Plot MRR
metrics_mrr = ['avg_mrr','di_mrr', 'gru_mrr', 'ucv_mrr']
fig, axes = plt.subplots(len(models), len(metrics_mrr), figsize=(14, 14), sharex=True)
for row_idx, model in enumerate(models):
    plot_metrics(avg_data_mrr.get(model, {}), low_data_mrr.get(model, {}), high_data_mrr.get(model, {}), model, axes[row_idx], metrics_mrr)
    axes[row_idx][0].set_ylabel(f'{model.upper()}', rotation=90, size='large')
fig.add_artist(plt.Line2D([0.255, 0.255], [0, 0.95],
                          transform=fig.transFigure, color='gray', linestyle='--', linewidth=2))
#plt.suptitle('MRR Metrics (DI, GRU, UCV, AVG) over 3 Rounds for RentTheRunway Models', fontsize=18)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('mrr__rent_metrics.png')
plt.show()
