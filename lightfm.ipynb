# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity

# %%
df_modcloth = pd.read_json("modcloth_final_data.json", lines=True)

# %% [markdown]
# # Preprocessing

# %%
df_modcloth_clean = df_modcloth.dropna(subset=["user_id","item_id"]).drop_duplicates()

# %%
vectorizer = CountVectorizer()
category_bow = vectorizer.fit_transform(df_modcloth_clean['category'])

# %%
###############################################
# 3. Implicit Feedback
###############################################

fit_mapping = {'fit': 0, 'large': 2, 'small': 1}
df_modcloth_clean.loc[:, 'fit'] = df_modcloth_clean['fit'].map(fit_mapping)


user_reviews = df_modcloth_clean.groupby('user_id')['review_text'].count().to_dict()
df_modcloth_clean.loc[:, 'num_user_reviews'] = df_modcloth_clean['user_id'].map(user_reviews).fillna(0).astype(int)
max_reviews = df_modcloth_clean['num_user_reviews'].max()
df_modcloth_clean.loc[:, 'num_user_reviews_normalized'] = df_modcloth_clean['num_user_reviews'] / max_reviews

max_quality = df_modcloth_clean['quality'].max()
df_modcloth_clean.loc[:, 'quality_normalized'] = df_modcloth_clean['quality'] / max_quality


df_modcloth_clean.loc[:, 'interaction_strength'] = (
    df_modcloth_clean['fit'] * 0.33 +
    df_modcloth_clean['num_user_reviews'] * 0.33 +
    df_modcloth_clean['quality'] * 0.34
)

# %%
df_modcloth_clean['fit'] = df_modcloth_clean['fit'].fillna(df_modcloth_clean['fit'].median())
df_modcloth_clean['num_user_reviews'] = df_modcloth_clean['num_user_reviews'].fillna(df_modcloth_clean['num_user_reviews'].median())
df_modcloth_clean['quality'] = df_modcloth_clean['quality'].fillna(df_modcloth_clean['quality'].median())
# Out:
# <ipython-input-5-f6caecb067aa>:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_modcloth_clean['fit'] = df_modcloth_clean['fit'].fillna(df_modcloth_clean['fit'].median())

# %%
def calculate_sparsity(df):
    """Calculates sparsity for each numerical feature in the DataFrame.

    Args: dataset as df
    Return : dictionary with item feature name and sparsity values
    """
    numerical_features = df.select_dtypes(include=np.number).columns
    sparsity_results = {}

    for feature in numerical_features:
        sparsity = df[feature].isnull().sum() / len(df)
        sparsity_results[feature] = sparsity

    return sparsity_results

sparsity_dict = calculate_sparsity(df_modcloth_clean)


for feature, sparsity in sparsity_dict.items():
    print(f"Sparsity of {feature}: {sparsity:.2f}")
# Out:
# Sparsity of item_id: 0.00
# Sparsity of waist: 0.97
# Sparsity of size: 0.00
# Sparsity of quality: 0.00
# Sparsity of hips: 0.32
# Sparsity of bra size: 0.07
# Sparsity of fit: 0.00
# Sparsity of user_id: 0.00
# Sparsity of shoe size: 0.66
# Sparsity of num_user_reviews: 0.00
# Sparsity of num_user_reviews_normalized: 0.00
# Sparsity of quality_normalized: 0.00

# %%
def preprocess_data(df, sparsity_threshold=0.50, user_id_col='user_id'):
    """Preprocesses the data by removing numerical features with high sparsity
    Args:
    df : dataset
    sparsity_threshold: how sparse can a feature be to be accepted
    user_id columns

    Return:
    preprocessed dataset -> df_modcloth_clean
    """
    numerical_cols = df.select_dtypes(include=np.number).columns
    cols_to_check = [col for col in numerical_cols if col != user_id_col]

    for col in cols_to_check:
        sparsity = df[col].isnull().sum() / len(df)
        if sparsity > sparsity_threshold:
            print(f"Dropping sparse feature: {col} (Sparsity: {sparsity:.2f})")
            df = df.drop(col, axis=1)

    user_interaction_counts = df_modcloth_clean.groupby('user_id')['interaction_strength'].count()
    print(user_interaction_counts)
    users_with_more_than_two_interactions = user_interaction_counts[user_interaction_counts >= 2]
    print(f"Number of users with more than 2 interactions: {len(users_with_more_than_two_interactions)}")
    df = df_modcloth_clean[df_modcloth_clean["user_id"].isin(users_with_more_than_two_interactions.index)]

    return df

# %%
df_modcloth_clean = preprocess_data(df_modcloth_clean, sparsity_threshold=0.50)
# Out:
# Dropping sparse feature: waist (Sparsity: 0.97)
# Dropping sparse feature: shoe size (Sparsity: 0.66)
# user_id
# 6         1
# 46        1
# 55        1
# 66        4
# 104       2
#          ..
# 999864    1
# 999887    2
# 999888    1
# 999923    3
# 999972    3
# Name: interaction_strength, Length: 47958, dtype: int64
# Number of users with more than 2 interactions: 15924

# %%
user_activity = df_modcloth_clean.groupby('user_id')['interaction_strength'].sum()

# %%
median_interaction_strength = df_modcloth_clean.groupby('user_id')['interaction_strength'].sum().median()

df_modcloth_clean['user_activity'] = df_modcloth_clean.groupby('user_id')['interaction_strength'].transform('sum').map(
    lambda x: 'Low' if x < median_interaction_strength else 'High'
)

print(df_modcloth_clean['user_activity'].value_counts())
# Out:
# user_activity
# High    34900
# Low     15471
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
# random Split
train_df, temp_df = train_test_split(df_modcloth_clean, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# %%
###############################################
# 3. User Item Matrix
###############################################

# Rows = users.
#Columns = items.
#cell values represent user  interacted with an item.

train_user_item_matrix = train_df.pivot_table(
    index="user_id",
    columns="item_id",
    values="interaction_strength",
    aggfunc="sum",
    fill_value=0
)
val_user_item_matrix = val_df.pivot_table(
    index="user_id",
    columns="item_id",
    values="interaction_strength",
    aggfunc="sum",
    fill_value=0
)
test_user_item_matrix = test_df.pivot_table(
    index="user_id",
    columns="item_id",
    values="interaction_strength",
    aggfunc="sum",
    fill_value=0
)
# Out:
# <ipython-input-14-f947f7bf47dd>:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_user_item_matrix = train_df.pivot_table(
# <ipython-input-14-f947f7bf47dd>:16: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   val_user_item_matrix = val_df.pivot_table(
# <ipython-input-14-f947f7bf47dd>:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_user_item_matrix = test_df.pivot_table(

# %% [markdown]
# #Definition effectiveness

# %%
###############################################
# 3. Utility/Ranking metrics
###############################################
def dcg_at_k_recursive(relevance_scores, k, b=2):
    """
    Calculate the Discounted Cumulative Gain at rank k recursively.

    :param relevance_scores: A list or array of relevance scores for the ranked items.
    :param k: The rank at which to stop (k items to evaluate).
    :param b: The base of the logarithm (typically 2).
    :return: DCG at rank k.
    """
    k = min(k, len(relevance_scores))
    if k == 0:
        return 0.0

    if k < b:
        return np.sum([rel / np.log2(idx + 2) for idx, rel in enumerate(relevance_scores[:k])])

    else:
        dcg_k_minus_1 = dcg_at_k_recursive(relevance_scores, k - 1, b)
        rel_k = relevance_scores[k - 1]
        return dcg_k_minus_1 + (rel_k / np.log2(k + 1))

def dcg_at_k(relevance_scores, k, b=2):
    """
    Calculate the Discounted Cumulative Gain at rank k (non-recursive).
    """
    dcg = 0
    for idx, rel in enumerate(relevance_scores[:k]):
        dcg += rel / np.log2(idx + 2)
    return dcg
def idcg_at_k(relevance_scores, k):
    """
    Calculate the Ideal Discounted Cumulative Gain at rank k.
    :param relevance_scores: A list or array of relevance scores for the ranked items.
    :param k: The rank at which to stop (k items to evaluate).
    :return: Ideal DCG at rank k.
    """
    relevance_scores = sorted(relevance_scores, reverse=True)
    return dcg_at_k(relevance_scores, k)

def ndcg_at_k(relevance_scores, k):
    """
    Calculate the Normalized Discounted Cumulative Gain at rank k.
    :param relevance_scores: A list or array of relevance scores for the ranked items.
    :param k: The rank at which to stop (k items to evaluate).
    :return: nDCG at rank k.
    """
    dcg = dcg_at_k_recursive(relevance_scores, k)
    idcg = idcg_at_k(relevance_scores, k)
    if idcg == 0:
        return 0
    return dcg / idcg

# %%
def hr_at_k(actual, predicted, k=5):
    """
    Computes Hit Rate (HR) at rank k.

    Args:
        actual: list of relevant items
        predicted: ranked list of items
        k: rank cutoff (default is 5)

    Returns:
        Hit Rate at rank k.
    """

    for item in predicted[:k]:
        if item in actual:
            return 1
    return 0



def hit_rate_at_k(actual, predicted, k=5):
    """
    Computes Mean Hit Rate (HR) at rank k for all users.

    Args:
        actual: list of relevant items for each user
        predicted: list of predicted ranked items for each user
        k: rank cutoff (default is 5)

    Returns:
        HR at rank k.
    """

    if not actual or len(predicted) == 0:
        return 0.0
    hr_scores = []
    for user_actual, user_predicted in zip(actual, predicted):
        hr = hr_at_k(user_actual, user_predicted, k)
        hr_scores.append(hr)
    return np.mean(hr_scores)

# %%
def rr_at_k(actual, predicted, k=5):
    """
    Computes Reciprocal Rank at rank k.

    Args:
        actual: the relevant item(s)
        predicted: the ranked list of items
        k: rank cutoff (default is 5)

    Returns:
        Reciprocal Rank at rank k.
    """

    for i, item in enumerate(predicted[:k]):
        if item == actual:
            return 1 / (i + 1)
    return 0.0


def mrr_at_k(actual, predicted, k=5):
    """
    Computes Mean Reciprocal Rank (MRR) at rank k.

    Args:
        actual: list of relevant items (can be multiple)
        predicted: ranked list of items
        k: rank cutoff (default is 5)

    Returns:
        MRR at rank k.
    """

    if actual is None or len(predicted) == 0:
        return 0.0


    rr_scores = []
    for item in actual:
        rr = rr_at_k(item, predicted, k)
        rr_scores.append(rr)
    return np.mean(rr_scores)

# %% [markdown]
# #DEfinition Fairness metrics

# %%
###############################################
# 3. Fairness metrics
###############################################
def calculate_disparate_impact(protected_outcomes, privileged_outcomes):
    """
    Args:
        protected_outcomes: List of binary outcomes (1=favorable) for the protected group.
        privileged_outcomes: List of binary outcomes for the privileged group.
    Returns:
        Disparate impact ratio.
    """
    protected_rate = np.mean(protected_outcomes)
    privileged_rate = np.mean(privileged_outcomes)

    if privileged_rate == 0:
        return np.inf

    return protected_rate / privileged_rate


def calculate_group_recommender_unfairness(group1_metrics, group2_metrics):
  """
    Calculates the absolute difference in mean metrics between two groups.
    This metric quantifies the unfairness of a recommender system by examining
    the absolute difference in average performance between different user groups.

    Args:
        group1_metrics (list or numpy.ndarray): A list or numpy array of metrics for group 1.
        group2_metrics (list or numpy.ndarray): A list or numpy array of metrics for group 2.

    Returns:
        float: The absolute difference in mean metrics between the two groups.
  """
  return np.abs(np.mean(group1_metrics) - np.mean(group2_metrics))

# %%
def coefficient_of_variation(arr):
    mean_val = np.mean(arr)
    if mean_val == 0:
        return 0
    return np.std(arr) / mean_val

def calculate_ucv(metric_low_group, metric_high_group):

    cv_low = coefficient_of_variation(metric_low_group) if len(metric_low_group) > 0 else 0
    cv_high = coefficient_of_variation(metric_high_group) if len(metric_high_group) > 0 else 0
    return (cv_low + cv_high) / 2

def coefficient_of_variance(group):
    """Calculates the coefficient of variance for a group."""
    return np.std(group) / np.mean(group) if np.mean(group) != 0 else 0

def coef_variation(arr):
    mean_val = np.mean(arr)
    if mean_val == 0:
        return 0
    return np.std(arr) / mean_val

# %% [markdown]
# # First round

# %%
# !pip install lightfm
# Out:
# Collecting lightfm
#   Downloading lightfm-1.17.tar.gz (316 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.4/316.4 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from lightfm) (2.0.2)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.11/dist-packages (from lightfm) (1.15.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from lightfm) (2.32.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from lightfm) (1.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->lightfm) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->lightfm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->lightfm) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->lightfm) (2025.4.26)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->lightfm) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->lightfm) (3.6.0)
# Building wheels for collected packages: lightfm
#   Building wheel for lightfm (setup.py) ... done
#   Created wheel for lightfm: filename=lightfm-1.17-cp311-cp311-linux_x86_64.whl size=831162 sha256=3cfe6b755d99d0fa2236707f10661d593a7dc0f565573d7d8449604c2fa68d68
#   Stored in directory: /root/.cache/pip/wheels/b9/0d/8a/0729d2e6e3ca2a898ba55201f905da7db3f838a33df5b3fcdd
# Successfully built lightfm
# Installing collected packages: lightfm
# Successfully installed lightfm-1.17

# %%
import numpy as np
from lightfm import LightFM
from scipy.sparse import coo_matrix # sparse matrix
from lightfm.evaluation import precision_at_k, recall_at_k
###############################################
# 3. WARP Model
###############################################

interactions = coo_matrix(train_user_item_matrix.values)

# Create a LightFM model using 'warp' (Weighted Approximate Ranking) loss
# why warp ? because handles implicit feedback effectively,
# offers computational efficiency, and has a track record of good performance.
# predicting rankings for each
model = LightFM(loss='warp')
 # https://making.lyst.com/lightfm/docs/lightfm.html


model.fit(interactions, epochs=30, num_threads=2)

#  precision@k, recall@k) on the training set
train_precision = precision_at_k(model, interactions, k=5).mean()
train_recall = recall_at_k(model, interactions, k=5).mean()


print(f"Train Precision at k=5: {train_precision}")
print(f"Train Recall at k=5: {train_recall}")


user_id = 55 # example
scores = model.predict(user_id, np.arange(interactions.shape[1]))

top_items = np.argsort(-scores)

print("Top 10 recommended items for user 55:", top_items[:10])
# Out:
# Train Precision at k=5: 0.26242509484291077
# Train Recall at k=5: 0.6313707094613337
# Top 10 recommended items for user 55: [397 503 739 698 796 388 875  84 385  41]

# %%
#Best parameters: {'item_alpha': 1e-06, 'learning_rate': 0.01, 'loss': 'warp', 'no_components': 50, 'user_alpha': 1e-05}, Best AUC: 0.775144100189209
#<lightfm.lightfm.LightFM at 0x7b035c2baf10>
best_model = LightFM(loss='warp', no_components=50, learning_rate=0.01, item_alpha=1e-06, user_alpha=0.0)
best_model.fit(interactions, epochs=30, num_threads=2)

# %%
test_items = test_df.groupby("user_id")["item_id"].first().to_dict()

def calculate_metrics_for_user(user, actual_item, recs, group):
    relevance_scores = [1 if item == actual_item else 0 for item in recs]
    ndcg = ndcg_at_k(relevance_scores, k=6)
    hr = hr_at_k([actual_item], recs, k=5)
    mrr = mrr_at_k([actual_item], recs, k=5)
    cv = coefficient_of_variance(relevance_scores)
    return [user, ndcg, hr, mrr, cv, group]



metrics_lightfm = []
for user_id in train_user_item_matrix.index:
    actual_item = test_items.get(user_id, None)
    if actual_item is None:
        continue
    engagement_level = df_modcloth_clean[df_modcloth_clean["user_id"] == user_id][
        "user_activity"
    ].values[0]
    try:
        user_id_internal = train_user_item_matrix.index.get_loc(user_id)
    except KeyError:

        print(f"User {user_id} not found in training data. Skipping.")
        continue

    scores = best_model.predict(user_id_internal, np.arange(interactions.shape[1]))
    top_items = np.argsort(-scores)
    recs = [train_user_item_matrix.columns[i] for i in top_items]
    metrics_lightfm.append(
        calculate_metrics_for_user(user_id, actual_item, recs, engagement_level)
    )

metrics_lightfm_df = pd.DataFrame(
    metrics_lightfm, columns=["User", "NDCG@K", "HR@K", "MRR@K","CV", "Engagement Group"]
)
metrics_lightfm_df['User'] = pd.to_numeric(metrics_lightfm_df['User'], errors='coerce')
grouped_metrics_lightfm = metrics_lightfm_df.groupby("Engagement Group").agg(
    {"NDCG@K": "mean", "HR@K": "mean", "MRR@K": "mean", "CV":"mean"}
)
print("\nLightFM Metrics by User Engagement Level:")
grouped_metrics_lightfm
# Out:
# LightFM Metrics by User Engagement Level:
#                     NDCG@K      HR@K     MRR@K         CV
# Engagement Group
# High              0.062067  0.099600  0.040294  30.777480
# Low               0.074612  0.121676  0.051491  30.698086

# %%
ndcg_low = grouped_metrics_lightfm.loc["Low", "NDCG@K"]
ndcg_moderate_high = grouped_metrics_lightfm.loc["High", "NDCG@K"]

di_ndcg = calculate_disparate_impact(ndcg_low, ndcg_moderate_high)
gru_ndcg = calculate_group_recommender_unfairness(ndcg_low, ndcg_moderate_high)

cv_low_ndcg = coefficient_of_variance(ndcg_low)
cv_moderate_high_ndcg = coefficient_of_variance(ndcg_moderate_high)


print(f"\nLightFM - NDCG Metrics:")
print(f"Disparate Impact: {di_ndcg}")
print(f"Group Recommender Unfairness: {gru_ndcg}")

hr_low = grouped_metrics_lightfm.loc["Low", "HR@K"]
hr_moderate_high = grouped_metrics_lightfm.loc["High", "HR@K"]

di_hr = calculate_disparate_impact(hr_low, hr_moderate_high)
gru_hr = calculate_group_recommender_unfairness(hr_low, hr_moderate_high)

cv_low_hr = coefficient_of_variance(hr_low)
cv_moderate_high_hr = coefficient_of_variance(hr_moderate_high)


print(f"\nLightFM - HR@K Metrics:")
print(f"Disparate Impact: {di_hr}")
print(f"Group Recommender Unfairness: {gru_hr}")

mrr_low = grouped_metrics_lightfm.loc["Low", "MRR@K"]
mrr_moderate_high = grouped_metrics_lightfm.loc["High", "MRR@K"]

di_mrr = calculate_disparate_impact(mrr_low, mrr_moderate_high)
gru_mrr = calculate_group_recommender_unfairness(mrr_low, mrr_moderate_high)

cv_low_mrr = coefficient_of_variance(mrr_low)
cv_moderate_high_mrr = coefficient_of_variance(mrr_moderate_high)


print(f"\nLightFM - MRR@K Metrics:")
print(f"Disparate Impact: {di_mrr}")
print(f"Group Recommender Unfairness: {gru_mrr}")
# Out:
# LightFM - NDCG Metrics:
# Disparate Impact: 1.2021155521108302
# Group Recommender Unfairness: 0.01254474364446443
#
# LightFM - HR@K Metrics:
# Disparate Impact: 1.2216454825105725
# Group Recommender Unfairness: 0.0220759222856768
#
# LightFM - MRR@K Metrics:
# Disparate Impact: 1.2778620410664498
# Group Recommender Unfairness: 0.011196294893571775

# %%
def calculate_ucv(metric_low_group, metric_high_group):
    """Calculates the Unconditional Coefficient of Variation (UCV)."""
    cv_low = coefficient_of_variation(metric_low_group) if isinstance(metric_low_group, (list, np.ndarray)) and len(metric_low_group) > 0 else 0
    cv_high = coefficient_of_variation(metric_high_group) if isinstance(metric_high_group, (list, np.ndarray)) and len(metric_high_group) > 0 else 0
    return (cv_low + cv_high) / 2

def coefficient_of_variation(arr):
    """Calculates the Coefficient of Variation (CV)."""
    if isinstance(arr, (int, float, np.number)):
    mean_val = np.mean(arr)
    if mean_val == 0:
        return 0
    return np.std(arr) / mean_val

# %% [markdown]
# # multiple rounds

# %%
###############################################
# 3. Multiple Rounds WARP
###############################################

from lightfm import LightFM
from scipy.sparse import csr_matrix #-> sparse matrix
from lightfm.evaluation import precision_at_k, recall_at_k, auc_score
from lightfm.cross_validation import random_train_test_split
from sklearn.metrics import ndcg_score


def evaluate_lightfm_multiple_rounds(
    interactions, test_df, df_rent_clean, num_rounds=3, k=5, epochs=30, user_id_to_print=55
):
    """
    Evaluates LightFM model with multiple training rounds, fairness metrics, and prints recommendations for a user.

    Args:
        interactions: The user-item interaction matrix (sparse).
        test_df: The test DataFrame.
        df_rent_clean: The cleaned main DataFrame with user activity.
        num_rounds: The number of training rounds.
        k: The value of k for precision@k, recall@k metrics.
        epochs: The number of epochs for each training round.
        user_id_to_print: The user ID for which recommendations will be printed.

    Returns:
        A dictionary containing metrics for each round.
    """

    train_interactions, test_interactions = random_train_test_split(
        interactions, test_percentage=0.2, random_state=42
    )

    round_metrics = {}
    model = LightFM( # best parameters
        loss="warp",
        no_components=50,
        learning_rate=0.01,
        item_alpha=1e-06,
        user_alpha=0.0,
    )

    test_items = test_df.groupby("user_id")["item_id"].first().to_dict()
    user_id_map = {user: i for i, user in enumerate(train_user_item_matrix.index)}


    for round_num in range(num_rounds):
        print(f"Training Round {round_num + 1}...")
        model.fit(train_interactions, epochs=epochs)
        test_user_ids = test_df['user_id'].unique()
        ndcg_scores = []
        hr_scores = []
        mrr_scores = []
        cv_scores = []
        engagement_levels_list = []

        for user_id in test_user_ids:
            actual_item = test_items.get(user_id, None)
            if actual_item is None:
                continue
            user_id_internal = user_id_map.get(user_id, None)
            if user_id_internal is None:
                print(f"User {user_id} not found in training data. Skipping evaluation.")
                continue

            engagement_level_row = df_modcloth_clean[df_modcloth_clean["user_id"] == user_id]
            if engagement_level_row.empty:
                 print(f"User {user_id} not found in df_rent_clean for engagement level. Skipping.")
                 continue
            engagement_level = engagement_level_row["user_activity"].values[0]
            engagement_levels_list.append(engagement_level)

            scores = model.predict(user_id_internal, np.arange(interactions.shape[1]))
            top_k_indices = np.argsort(-scores)[:k]
            top_k_items_predicted = [train_user_item_matrix.columns[i] for i in top_k_indices]


            relevance_scores = [1 if item == actual_item else 0 for item in top_k_items_predicted]
            ndcg_scores.append(ndcg_at_k(relevance_scores, k))

            hr_scores.append(hr_at_k([actual_item], top_k_items_predicted, k))
            mrr_scores.append(mrr_at_k([actual_item], top_k_items_predicted, k))
            cv_scores.append(coefficient_of_variance(np.array(relevance_scores)))


        ndcg = np.mean(ndcg_scores) if ndcg_scores else 0
        hr = np.mean(hr_scores) if hr_scores else 0
        mrr = np.mean(mrr_scores) if mrr_scores else 0
        cv = np.mean(cv_scores) if cv_scores else 0


        ndcg_low = [
            ndcg_scores[i]
            for i in range(len(ndcg_scores))
            if engagement_levels_list[i] == "Low"
        ]
        ndcg_moderate_high = [
            ndcg_scores[i]
            for i in range(len(ndcg_scores))
            if engagement_levels_list[i] == "High"
        ]


        cv_low = [
            cv_scores[i]
            for i in range(len(cv_scores))
            if engagement_levels_list[i] == "Low"
        ]
        cv_moderate_high = [
            cv_scores[i]
            for i in range(len(cv_scores))
            if engagement_levels_list[i] == "High"
        ]
        hr_low = [
            hr_scores[i]
            for i in range(len(hr_scores))
            if engagement_levels_list[i] == "Low"
        ]
        hr_moderate_high = [
            hr_scores[i]
            for i in range(len(hr_scores))
            if engagement_levels_list[i] == "High"
        ]
        mrr_low = [
            mrr_scores[i]
            for i in range(len(mrr_scores))
            if engagement_levels_list[i] == "Low"
        ]
        mrr_moderate_high = [
            mrr_scores[i]
            for i in range(len(mrr_scores))
            if engagement_levels_list[i] == "High"
        ]
        ucv_ndcg = calculate_ucv(ndcg_low, ndcg_moderate_high)

        ucv_hr = calculate_ucv(hr_low, hr_moderate_high)
        ucv_mrr = calculate_ucv(mrr_low, mrr_moderate_high)
        cv_low_mean = np.mean(cv_low) if cv_low else 0
        cv_moderate_high_mean = np.mean(cv_moderate_high) if cv_moderate_high else 0
        hr_low_mean = np.mean(hr_low) if hr_low else 0
        hr_moderate_high_mean = np.mean(hr_moderate_high) if hr_moderate_high else 0
        mrr_low_mean = np.mean(mrr_low) if mrr_low else 0
        mrr_moderate_high_mean = np.mean(mrr_moderate_high) if mrr_moderate_high else 0
        di_ndcg = calculate_disparate_impact(ndcg_low, ndcg_moderate_high) if ndcg_moderate_high else np.inf
        gru_ndcg = calculate_group_recommender_unfairness(ndcg_low, ndcg_moderate_high)
        ndcg_low = np.mean(ndcg_low) if ndcg_low else 0
        ndcg_moderate_high = np.mean(ndcg_moderate_high) if ndcg_moderate_high else 0
        di_hr = calculate_disparate_impact(hr_low, hr_moderate_high) if hr_moderate_high else np.inf
        gru_hr = calculate_group_recommender_unfairness(hr_low, hr_moderate_high)
        di_mrr = calculate_disparate_impact(mrr_low, mrr_moderate_high) if mrr_moderate_high else np.inf
        gru_mrr = calculate_group_recommender_unfairness(mrr_low, mrr_moderate_high)

        round_metrics[round_num + 1] = {
            "ndcg@k": ndcg,
            "hr@k": hr,
            "mrr@k": mrr,
            "ndcg_low": ndcg_low,
            "ndcg_moderate_high": ndcg_moderate_high,
            "DI_NDCG": di_ndcg,
            "GRU_NDCG": gru_ndcg,
            "CV": cv,
            "cv_low": cv_low_mean,
            "cv_moderate_high": cv_moderate_high_mean,
            "HR_LOW": hr_low_mean,
            "HR_MODERATE_HIGH": hr_moderate_high_mean,
            "MRR_LOW": mrr_low_mean,
            "MRR_MODERATE_HIGH": mrr_moderate_high_mean,
            "UCV_NDCG": ucv_ndcg,
            "UCV_HR": ucv_hr,
            "UCV_MRR": ucv_mrr,
            "DI_HR": di_hr,
            "GRU_HR": gru_hr,
            "DI_MRR": di_mrr,
            "GRU_MRR": gru_mrr
        }

        print(f"Metrics for round {round_num + 1}: {round_metrics[round_num + 1]}")


        if round_num == 0 and user_id_to_print in user_id_map:
            user_index = user_id_map[user_id_to_print]
            scores = model.predict(user_index, np.arange(interactions.shape[1]))
            top_items_indices = np.argsort(-scores)[:k]
            top_items_actual_ids = [train_user_item_matrix.columns[i] for i in top_items_indices]
            print(
                f"Top {k} recommendations for user {user_id_to_print}: {top_items_actual_ids}"
            )
        elif round_num == 0 and user_id_to_print not in user_id_map:
            print(
                f"User {user_id_to_print} not found in training data mapping. Skipping recommendations."
            )

    return round_metrics

interactions = csr_matrix(train_user_item_matrix.values)

# Pass the test_df and df_modcloth_clean to the function
round_results = evaluate_lightfm_multiple_rounds(interactions, test_df, df_modcloth_clean)

print("\nOverall Results:")
print(round_results)
# Out:
# Training Round 1...
# User 759686 not found in training data. Skipping evaluation.
# User 633700 not found in training data. Skipping evaluation.
# User 847972 not found in training data. Skipping evaluation.
# User 554236 not found in training data. Skipping evaluation.
# User 867579 not found in training data. Skipping evaluation.
# User 634356 not found in training data. Skipping evaluation.
# User 902075 not found in training data. Skipping evaluation.
# User 716249 not found in training data. Skipping evaluation.
# User 901112 not found in training data. Skipping evaluation.
# User 167789 not found in training data. Skipping evaluation.
# User 608089 not found in training data. Skipping evaluation.
# User 373717 not found in training data. Skipping evaluation.
# User 382674 not found in training data. Skipping evaluation.
# User 688594 not found in training data. Skipping evaluation.
# User 89438 not found in training data. Skipping evaluation.
# User 397724 not found in training data. Skipping evaluation.
# User 632710 not found in training data. Skipping evaluation.
# User 790847 not found in training data. Skipping evaluation.
# User 592065 not found in training data. Skipping evaluation.
# User 413844 not found in training data. Skipping evaluation.
# User 371335 not found in training data. Skipping evaluation.
# User 774863 not found in training data. Skipping evaluation.
# User 384270 not found in training data. Skipping evaluation.
# User 594557 not found in training data. Skipping evaluation.
# User 877323 not found in training data. Skipping evaluation.
# User 913139 not found in training data. Skipping evaluation.
# User 408008 not found in training data. Skipping evaluation.
# User 812798 not found in training data. Skipping evaluation.
# User 253950 not found in training data. Skipping evaluation.
# User 679431 not found in training data. Skipping evaluation.
# User 865033 not found in training data. Skipping evaluation.
# User 446201 not found in training data. Skipping evaluation.
# User 990283 not found in training data. Skipping evaluation.
# User 89500 not found in training data. Skipping evaluation.
# User 750543 not found in training data. Skipping evaluation.
# User 429031 not found in training data. Skipping evaluation.
# User 339 not found in training data. Skipping evaluation.
# User 288435 not found in training data. Skipping evaluation.
# User 41992 not found in training data. Skipping evaluation.
# User 523600 not found in training data. Skipping evaluation.
# User 281723 not found in training data. Skipping evaluation.
# User 775478 not found in training data. Skipping evaluation.
# User 610378 not found in training data. Skipping evaluation.
# User 610200 not found in training data. Skipping evaluation.
# User 532209 not found in training data. Skipping evaluation.
# User 444342 not found in training data. Skipping evaluation.
# User 401453 not found in training data. Skipping evaluation.
# User 344372 not found in training data. Skipping evaluation.
# User 785986 not found in training data. Skipping evaluation.
# User 979179 not found in training data. Skipping evaluation.
# User 909674 not found in training data. Skipping evaluation.
# User 499863 not found in training data. Skipping evaluation.
# User 780746 not found in training data. Skipping evaluation.
# User 281628 not found in training data. Skipping evaluation.
# User 732020 not found in training data. Skipping evaluation.
# User 398506 not found in training data. Skipping evaluation.
# User 518352 not found in training data. Skipping evaluation.
# User 771160 not found in training data. Skipping evaluation.
# User 209090 not found in training data. Skipping evaluation.
# User 28722 not found in training data. Skipping evaluation.
# User 390350 not found in training data. Skipping evaluation.
# User 729567 not found in training data. Skipping evaluation.
# User 557424 not found in training data. Skipping evaluation.
# User 291553 not found in training data. Skipping evaluation.
# User 649070 not found in training data. Skipping evaluation.
# User 120564 not found in training data. Skipping evaluation.
# User 74272 not found in training data. Skipping evaluation.
# User 972737 not found in training data. Skipping evaluation.
# User 179945 not found in training data. Skipping evaluation.
# User 145195 not found in training data. Skipping evaluation.
# User 494387 not found in training data. Skipping evaluation.
# User 477665 not found in training data. Skipping evaluation.
# User 133940 not found in training data. Skipping evaluation.
# User 902797 not found in training data. Skipping evaluation.
# User 178172 not found in training data. Skipping evaluation.
# User 22210 not found in training data. Skipping evaluation.
# User 712393 not found in training data. Skipping evaluation.
# User 846063 not found in training data. Skipping evaluation.
# User 609817 not found in training data. Skipping evaluation.
# User 973954 not found in training data. Skipping evaluation.
# User 121195 not found in training data. Skipping evaluation.
# User 731548 not found in training data. Skipping evaluation.
# User 903500 not found in training data. Skipping evaluation.
# User 502055 not found in training data. Skipping evaluation.
# User 364774 not found in training data. Skipping evaluation.
# User 237114 not found in training data. Skipping evaluation.
# User 845475 not found in training data. Skipping evaluation.
# User 107182 not found in training data. Skipping evaluation.
# User 923483 not found in training data. Skipping evaluation.
# User 322430 not found in training data. Skipping evaluation.
# User 556060 not found in training data. Skipping evaluation.
# User 797532 not found in training data. Skipping evaluation.
# User 453943 not found in training data. Skipping evaluation.
# User 214071 not found in training data. Skipping evaluation.
# User 561460 not found in training data. Skipping evaluation.
# User 257047 not found in training data. Skipping evaluation.
# User 803467 not found in training data. Skipping evaluation.
# User 184719 not found in training data. Skipping evaluation.
# User 638051 not found in training data. Skipping evaluation.
# User 3441 not found in training data. Skipping evaluation.
# User 554757 not found in training data. Skipping evaluation.
# User 954634 not found in training data. Skipping evaluation.
# User 185968 not found in training data. Skipping evaluation.
# User 551294 not found in training data. Skipping evaluation.
# User 854652 not found in training data. Skipping evaluation.
# User 785835 not found in training data. Skipping evaluation.
# User 403865 not found in training data. Skipping evaluation.
# User 344026 not found in training data. Skipping evaluation.
# User 584843 not found in training data. Skipping evaluation.
# User 656383 not found in training data. Skipping evaluation.
# User 404160 not found in training data. Skipping evaluation.
# User 628216 not found in training data. Skipping evaluation.
# User 304095 not found in training data. Skipping evaluation.
# User 727006 not found in training data. Skipping evaluation.
# User 433181 not found in training data. Skipping evaluation.
# User 868645 not found in training data. Skipping evaluation.
# User 243387 not found in training data. Skipping evaluation.
# User 593952 not found in training data. Skipping evaluation.
# User 132755 not found in training data. Skipping evaluation.
# User 732249 not found in training data. Skipping evaluation.
# User 792901 not found in training data. Skipping evaluation.
# User 950162 not found in training data. Skipping evaluation.
# User 711922 not found in training data. Skipping evaluation.
# User 547696 not found in training data. Skipping evaluation.
# User 722585 not found in training data. Skipping evaluation.
# User 370133 not found in training data. Skipping evaluation.
# User 854790 not found in training data. Skipping evaluation.
# User 507543 not found in training data. Skipping evaluation.
# User 859278 not found in training data. Skipping evaluation.
# User 682195 not found in training data. Skipping evaluation.
# User 66464 not found in training data. Skipping evaluation.
# User 773589 not found in training data. Skipping evaluation.
# User 973978 not found in training data. Skipping evaluation.
# User 249370 not found in training data. Skipping evaluation.
# User 421413 not found in training data. Skipping evaluation.
# User 257237 not found in training data. Skipping evaluation.
# User 597876 not found in training data. Skipping evaluation.
# User 724741 not found in training data. Skipping evaluation.
# User 176156 not found in training data. Skipping evaluation.
# User 531129 not found in training data. Skipping evaluation.
# User 188250 not found in training data. Skipping evaluation.
# User 465200 not found in training data. Skipping evaluation.
# User 836108 not found in training data. Skipping evaluation.
# User 863735 not found in training data. Skipping evaluation.
# User 323092 not found in training data. Skipping evaluation.
# User 595907 not found in training data. Skipping evaluation.
# User 496931 not found in training data. Skipping evaluation.
# User 205870 not found in training data. Skipping evaluation.
# User 615780 not found in training data. Skipping evaluation.
# User 252933 not found in training data. Skipping evaluation.
# User 688494 not found in training data. Skipping evaluation.
# User 709675 not found in training data. Skipping evaluation.
# User 376862 not found in training data. Skipping evaluation.
# User 374458 not found in training data. Skipping evaluation.
# User 781046 not found in training data. Skipping evaluation.
# User 244424 not found in training data. Skipping evaluation.
# User 770943 not found in training data. Skipping evaluation.
# User 999052 not found in training data. Skipping evaluation.
# User 330935 not found in training data. Skipping evaluation.
# User 144256 not found in training data. Skipping evaluation.
# User 237047 not found in training data. Skipping evaluation.
# User 666027 not found in training data. Skipping evaluation.
# User 792600 not found in training data. Skipping evaluation.
# User 575668 not found in training data. Skipping evaluation.
# User 287944 not found in training data. Skipping evaluation.
# User 583504 not found in training data. Skipping evaluation.
# User 712050 not found in training data. Skipping evaluation.
# User 185584 not found in training data. Skipping evaluation.
# User 729599 not found in training data. Skipping evaluation.
# User 58462 not found in training data. Skipping evaluation.
# User 265322 not found in training data. Skipping evaluation.
# User 746754 not found in training data. Skipping evaluation.
# User 872252 not found in training data. Skipping evaluation.
# User 171935 not found in training data. Skipping evaluation.
# User 513943 not found in training data. Skipping evaluation.
# User 37752 not found in training data. Skipping evaluation.
# User 287332 not found in training data. Skipping evaluation.
# User 929654 not found in training data. Skipping evaluation.
# User 553284 not found in training data. Skipping evaluation.
# User 144419 not found in training data. Skipping evaluation.
# User 285750 not found in training data. Skipping evaluation.
# User 972667 not found in training data. Skipping evaluation.
# User 901720 not found in training data. Skipping evaluation.
# User 410208 not found in training data. Skipping evaluation.
# User 999843 not found in training data. Skipping evaluation.
# User 685948 not found in training data. Skipping evaluation.
# User 449340 not found in training data. Skipping evaluation.
# User 923998 not found in training data. Skipping evaluation.
# User 303251 not found in training data. Skipping evaluation.
# User 80485 not found in training data. Skipping evaluation.
# User 495786 not found in training data. Skipping evaluation.
# User 454564 not found in training data. Skipping evaluation.
# User 71876 not found in training data. Skipping evaluation.
# User 77108 not found in training data. Skipping evaluation.
# User 736249 not found in training data. Skipping evaluation.
# User 856640 not found in training data. Skipping evaluation.
# User 753556 not found in training data. Skipping evaluation.
# User 990457 not found in training data. Skipping evaluation.
# User 314049 not found in training data. Skipping evaluation.
# User 481730 not found in training data. Skipping evaluation.
# User 93859 not found in training data. Skipping evaluation.
# User 935123 not found in training data. Skipping evaluation.
# User 891871 not found in training data. Skipping evaluation.
# User 209716 not found in training data. Skipping evaluation.
# User 950808 not found in training data. Skipping evaluation.
# User 831150 not found in training data. Skipping evaluation.
# User 216830 not found in training data. Skipping evaluation.
# User 766597 not found in training data. Skipping evaluation.
# User 958984 not found in training data. Skipping evaluation.
# User 806155 not found in training data. Skipping evaluation.
# User 907104 not found in training data. Skipping evaluation.
# User 683442 not found in training data. Skipping evaluation.
# User 512577 not found in training data. Skipping evaluation.
# User 954977 not found in training data. Skipping evaluation.
# User 320403 not found in training data. Skipping evaluation.
# User 391675 not found in training data. Skipping evaluation.
# User 989693 not found in training data. Skipping evaluation.
# User 566617 not found in training data. Skipping evaluation.
# User 134724 not found in training data. Skipping evaluation.
# User 972151 not found in training data. Skipping evaluation.
# User 807232 not found in training data. Skipping evaluation.
# User 752946 not found in training data. Skipping evaluation.
# User 256501 not found in training data. Skipping evaluation.
# User 952830 not found in training data. Skipping evaluation.
# User 771300 not found in training data. Skipping evaluation.
# User 88204 not found in training data. Skipping evaluation.
# User 583255 not found in training data. Skipping evaluation.
# User 683056 not found in training data. Skipping evaluation.
# User 662218 not found in training data. Skipping evaluation.
# User 580190 not found in training data. Skipping evaluation.
# User 433618 not found in training data. Skipping evaluation.
# User 81432 not found in training data. Skipping evaluation.
# User 66767 not found in training data. Skipping evaluation.
# User 716028 not found in training data. Skipping evaluation.
# User 901454 not found in training data. Skipping evaluation.
# User 613436 not found in training data. Skipping evaluation.
# User 881855 not found in training data. Skipping evaluation.
# User 798232 not found in training data. Skipping evaluation.
# User 92693 not found in training data. Skipping evaluation.
# User 343283 not found in training data. Skipping evaluation.
# User 578163 not found in training data. Skipping evaluation.
# User 89315 not found in training data. Skipping evaluation.
# User 693493 not found in training data. Skipping evaluation.
# User 207053 not found in training data. Skipping evaluation.
# User 281956 not found in training data. Skipping evaluation.
# User 153337 not found in training data. Skipping evaluation.
# User 118781 not found in training data. Skipping evaluation.
# User 14636 not found in training data. Skipping evaluation.
# User 104205 not found in training data. Skipping evaluation.
# User 810956 not found in training data. Skipping evaluation.
# User 52452 not found in training data. Skipping evaluation.
# User 489231 not found in training data. Skipping evaluation.
# User 770135 not found in training data. Skipping evaluation.
# User 279303 not found in training data. Skipping evaluation.
# User 347311 not found in training data. Skipping evaluation.
# User 672971 not found in training data. Skipping evaluation.
# User 515460 not found in training data. Skipping evaluation.
# User 31573 not found in training data. Skipping evaluation.
# User 852528 not found in training data. Skipping evaluation.
# User 392607 not found in training data. Skipping evaluation.
# User 780540 not found in training data. Skipping evaluation.
# User 711780 not found in training data. Skipping evaluation.
# User 953676 not found in training data. Skipping evaluation.
# User 649361 not found in training data. Skipping evaluation.
# User 500393 not found in training data. Skipping evaluation.
# User 405712 not found in training data. Skipping evaluation.
# User 867921 not found in training data. Skipping evaluation.
# User 431444 not found in training data. Skipping evaluation.
# User 219635 not found in training data. Skipping evaluation.
# User 336021 not found in training data. Skipping evaluation.
# User 943044 not found in training data. Skipping evaluation.
# User 574777 not found in training data. Skipping evaluation.
# User 845796 not found in training data. Skipping evaluation.
# User 391171 not found in training data. Skipping evaluation.
# User 774431 not found in training data. Skipping evaluation.
# User 816719 not found in training data. Skipping evaluation.
# User 282768 not found in training data. Skipping evaluation.
# User 843684 not found in training data. Skipping evaluation.
# User 469300 not found in training data. Skipping evaluation.
# User 215856 not found in training data. Skipping evaluation.
# User 266560 not found in training data. Skipping evaluation.
# User 412655 not found in training data. Skipping evaluation.
# User 33115 not found in training data. Skipping evaluation.
# User 468552 not found in training data. Skipping evaluation.
# User 634890 not found in training data. Skipping evaluation.
# User 890929 not found in training data. Skipping evaluation.
# User 365272 not found in training data. Skipping evaluation.
# User 12707 not found in training data. Skipping evaluation.
# User 245850 not found in training data. Skipping evaluation.
# User 103064 not found in training data. Skipping evaluation.
# User 526900 not found in training data. Skipping evaluation.
# User 538338 not found in training data. Skipping evaluation.
# User 112469 not found in training data. Skipping evaluation.
# User 915130 not found in training data. Skipping evaluation.
# User 642111 not found in training data. Skipping evaluation.
# User 151039 not found in training data. Skipping evaluation.
# User 592166 not found in training data. Skipping evaluation.
# User 254943 not found in training data. Skipping evaluation.
# User 943682 not found in training data. Skipping evaluation.
# User 958399 not found in training data. Skipping evaluation.
# User 1383 not found in training data. Skipping evaluation.
# User 240370 not found in training data. Skipping evaluation.
# User 113834 not found in training data. Skipping evaluation.
# User 545516 not found in training data. Skipping evaluation.
# User 633015 not found in training data. Skipping evaluation.
# User 515659 not found in training data. Skipping evaluation.
# User 335459 not found in training data. Skipping evaluation.
# User 145548 not found in training data. Skipping evaluation.
# User 464183 not found in training data. Skipping evaluation.
# User 495009 not found in training data. Skipping evaluation.
# User 89875 not found in training data. Skipping evaluation.
# User 597846 not found in training data. Skipping evaluation.
# User 448766 not found in training data. Skipping evaluation.
# User 727193 not found in training data. Skipping evaluation.
# User 459787 not found in training data. Skipping evaluation.
# User 821727 not found in training data. Skipping evaluation.
# User 312002 not found in training data. Skipping evaluation.
# User 734962 not found in training data. Skipping evaluation.
# User 163790 not found in training data. Skipping evaluation.
# Metrics for round 1: {'ndcg@k': np.float64(0.049627805560888846), 'hr@k': np.float64(0.09268537074148296), 'mrr@k': np.float64(0.03556696726786907), 'ndcg_low': np.float64(0.06385123252424016), 'ndcg_moderate_high': np.float64(0.04321149408814475), 'DI_NDCG': np.float64(1.4776446376511199), 'GRU_NDCG': np.float64(0.020639738436095408), 'CV': np.float64(0.18537074148296592), 'cv_low': np.float64(0.22723609991941982), 'cv_moderate_high': np.float64(0.16648491457651762), 'HR_LOW': np.float64(0.11361804995970991), 'HR_MODERATE_HIGH': np.float64(0.08324245728825881), 'MRR_LOW': np.float64(0.04744829438624765), 'MRR_MODERATE_HIGH': np.float64(0.0302071973827699), 'UCV_NDCG': np.float64(3.2016326699527538), 'UCV_HR': np.float64(3.0558505532392504), 'UCV_MRR': np.float64(3.510971668452215), 'DI_HR': np.float64(1.3649050455858602), 'GRU_HR': np.float64(0.030375592671451096), 'DI_MRR': np.float64(1.5707612257107977), 'GRU_MRR': np.float64(0.017241097003477746)}
# User 55 not found in training data mapping. Skipping recommendations.
# Training Round 2...
# User 759686 not found in training data. Skipping evaluation.
# User 633700 not found in training data. Skipping evaluation.
# User 847972 not found in training data. Skipping evaluation.
# User 554236 not found in training data. Skipping evaluation.
# User 867579 not found in training data. Skipping evaluation.
# User 634356 not found in training data. Skipping evaluation.
# User 902075 not found in training data. Skipping evaluation.
# User 716249 not found in training data. Skipping evaluation.
# User 901112 not found in training data. Skipping evaluation.
# User 167789 not found in training data. Skipping evaluation.
# User 608089 not found in training data. Skipping evaluation.
# User 373717 not found in training data. Skipping evaluation.
# User 382674 not found in training data. Skipping evaluation.
# User 688594 not found in training data. Skipping evaluation.
# User 89438 not found in training data. Skipping evaluation.
# User 397724 not found in training data. Skipping evaluation.
# User 632710 not found in training data. Skipping evaluation.
# User 790847 not found in training data. Skipping evaluation.
# User 592065 not found in training data. Skipping evaluation.
# User 413844 not found in training data. Skipping evaluation.
# User 371335 not found in training data. Skipping evaluation.
# User 774863 not found in training data. Skipping evaluation.
# User 384270 not found in training data. Skipping evaluation.
# User 594557 not found in training data. Skipping evaluation.
# User 877323 not found in training data. Skipping evaluation.
# User 913139 not found in training data. Skipping evaluation.
# User 408008 not found in training data. Skipping evaluation.
# User 812798 not found in training data. Skipping evaluation.
# User 253950 not found in training data. Skipping evaluation.
# User 679431 not found in training data. Skipping evaluation.
# User 865033 not found in training data. Skipping evaluation.
# User 446201 not found in training data. Skipping evaluation.
# User 990283 not found in training data. Skipping evaluation.
# User 89500 not found in training data. Skipping evaluation.
# User 750543 not found in training data. Skipping evaluation.
# User 429031 not found in training data. Skipping evaluation.
# User 339 not found in training data. Skipping evaluation.
# User 288435 not found in training data. Skipping evaluation.
# User 41992 not found in training data. Skipping evaluation.
# User 523600 not found in training data. Skipping evaluation.
# User 281723 not found in training data. Skipping evaluation.
# User 775478 not found in training data. Skipping evaluation.
# User 610378 not found in training data. Skipping evaluation.
# User 610200 not found in training data. Skipping evaluation.
# User 532209 not found in training data. Skipping evaluation.
# User 444342 not found in training data. Skipping evaluation.
# User 401453 not found in training data. Skipping evaluation.
# User 344372 not found in training data. Skipping evaluation.
# User 785986 not found in training data. Skipping evaluation.
# User 979179 not found in training data. Skipping evaluation.
# User 909674 not found in training data. Skipping evaluation.
# User 499863 not found in training data. Skipping evaluation.
# User 780746 not found in training data. Skipping evaluation.
# User 281628 not found in training data. Skipping evaluation.
# User 732020 not found in training data. Skipping evaluation.
# User 398506 not found in training data. Skipping evaluation.
# User 518352 not found in training data. Skipping evaluation.
# User 771160 not found in training data. Skipping evaluation.
# User 209090 not found in training data. Skipping evaluation.
# User 28722 not found in training data. Skipping evaluation.
# User 390350 not found in training data. Skipping evaluation.
# User 729567 not found in training data. Skipping evaluation.
# User 557424 not found in training data. Skipping evaluation.
# User 291553 not found in training data. Skipping evaluation.
# User 649070 not found in training data. Skipping evaluation.
# User 120564 not found in training data. Skipping evaluation.
# User 74272 not found in training data. Skipping evaluation.
# User 972737 not found in training data. Skipping evaluation.
# User 179945 not found in training data. Skipping evaluation.
# User 145195 not found in training data. Skipping evaluation.
# User 494387 not found in training data. Skipping evaluation.
# User 477665 not found in training data. Skipping evaluation.
# User 133940 not found in training data. Skipping evaluation.
# User 902797 not found in training data. Skipping evaluation.
# User 178172 not found in training data. Skipping evaluation.
# User 22210 not found in training data. Skipping evaluation.
# User 712393 not found in training data. Skipping evaluation.
# User 846063 not found in training data. Skipping evaluation.
# User 609817 not found in training data. Skipping evaluation.
# User 973954 not found in training data. Skipping evaluation.
# User 121195 not found in training data. Skipping evaluation.
# User 731548 not found in training data. Skipping evaluation.
# User 903500 not found in training data. Skipping evaluation.
# User 502055 not found in training data. Skipping evaluation.
# User 364774 not found in training data. Skipping evaluation.
# User 237114 not found in training data. Skipping evaluation.
# User 845475 not found in training data. Skipping evaluation.
# User 107182 not found in training data. Skipping evaluation.
# User 923483 not found in training data. Skipping evaluation.
# User 322430 not found in training data. Skipping evaluation.
# User 556060 not found in training data. Skipping evaluation.
# User 797532 not found in training data. Skipping evaluation.
# User 453943 not found in training data. Skipping evaluation.
# User 214071 not found in training data. Skipping evaluation.
# User 561460 not found in training data. Skipping evaluation.
# User 257047 not found in training data. Skipping evaluation.
# User 803467 not found in training data. Skipping evaluation.
# User 184719 not found in training data. Skipping evaluation.
# User 638051 not found in training data. Skipping evaluation.
# User 3441 not found in training data. Skipping evaluation.
# User 554757 not found in training data. Skipping evaluation.
# User 954634 not found in training data. Skipping evaluation.
# User 185968 not found in training data. Skipping evaluation.
# User 551294 not found in training data. Skipping evaluation.
# User 854652 not found in training data. Skipping evaluation.
# User 785835 not found in training data. Skipping evaluation.
# User 403865 not found in training data. Skipping evaluation.
# User 344026 not found in training data. Skipping evaluation.
# User 584843 not found in training data. Skipping evaluation.
# User 656383 not found in training data. Skipping evaluation.
# User 404160 not found in training data. Skipping evaluation.
# User 628216 not found in training data. Skipping evaluation.
# User 304095 not found in training data. Skipping evaluation.
# User 727006 not found in training data. Skipping evaluation.
# User 433181 not found in training data. Skipping evaluation.
# User 868645 not found in training data. Skipping evaluation.
# User 243387 not found in training data. Skipping evaluation.
# User 593952 not found in training data. Skipping evaluation.
# User 132755 not found in training data. Skipping evaluation.
# User 732249 not found in training data. Skipping evaluation.
# User 792901 not found in training data. Skipping evaluation.
# User 950162 not found in training data. Skipping evaluation.
# User 711922 not found in training data. Skipping evaluation.
# User 547696 not found in training data. Skipping evaluation.
# User 722585 not found in training data. Skipping evaluation.
# User 370133 not found in training data. Skipping evaluation.
# User 854790 not found in training data. Skipping evaluation.
# User 507543 not found in training data. Skipping evaluation.
# User 859278 not found in training data. Skipping evaluation.
# User 682195 not found in training data. Skipping evaluation.
# User 66464 not found in training data. Skipping evaluation.
# User 773589 not found in training data. Skipping evaluation.
# User 973978 not found in training data. Skipping evaluation.
# User 249370 not found in training data. Skipping evaluation.
# User 421413 not found in training data. Skipping evaluation.
# User 257237 not found in training data. Skipping evaluation.
# User 597876 not found in training data. Skipping evaluation.
# User 724741 not found in training data. Skipping evaluation.
# User 176156 not found in training data. Skipping evaluation.
# User 531129 not found in training data. Skipping evaluation.
# User 188250 not found in training data. Skipping evaluation.
# User 465200 not found in training data. Skipping evaluation.
# User 836108 not found in training data. Skipping evaluation.
# User 863735 not found in training data. Skipping evaluation.
# User 323092 not found in training data. Skipping evaluation.
# User 595907 not found in training data. Skipping evaluation.
# User 496931 not found in training data. Skipping evaluation.
# User 205870 not found in training data. Skipping evaluation.
# User 615780 not found in training data. Skipping evaluation.
# User 252933 not found in training data. Skipping evaluation.
# User 688494 not found in training data. Skipping evaluation.
# User 709675 not found in training data. Skipping evaluation.
# User 376862 not found in training data. Skipping evaluation.
# User 374458 not found in training data. Skipping evaluation.
# User 781046 not found in training data. Skipping evaluation.
# User 244424 not found in training data. Skipping evaluation.
# User 770943 not found in training data. Skipping evaluation.
# User 999052 not found in training data. Skipping evaluation.
# User 330935 not found in training data. Skipping evaluation.
# User 144256 not found in training data. Skipping evaluation.
# User 237047 not found in training data. Skipping evaluation.
# User 666027 not found in training data. Skipping evaluation.
# User 792600 not found in training data. Skipping evaluation.
# User 575668 not found in training data. Skipping evaluation.
# User 287944 not found in training data. Skipping evaluation.
# User 583504 not found in training data. Skipping evaluation.
# User 712050 not found in training data. Skipping evaluation.
# User 185584 not found in training data. Skipping evaluation.
# User 729599 not found in training data. Skipping evaluation.
# User 58462 not found in training data. Skipping evaluation.
# User 265322 not found in training data. Skipping evaluation.
# User 746754 not found in training data. Skipping evaluation.
# User 872252 not found in training data. Skipping evaluation.
# User 171935 not found in training data. Skipping evaluation.
# User 513943 not found in training data. Skipping evaluation.
# User 37752 not found in training data. Skipping evaluation.
# User 287332 not found in training data. Skipping evaluation.
# User 929654 not found in training data. Skipping evaluation.
# User 553284 not found in training data. Skipping evaluation.
# User 144419 not found in training data. Skipping evaluation.
# User 285750 not found in training data. Skipping evaluation.
# User 972667 not found in training data. Skipping evaluation.
# User 901720 not found in training data. Skipping evaluation.
# User 410208 not found in training data. Skipping evaluation.
# User 999843 not found in training data. Skipping evaluation.
# User 685948 not found in training data. Skipping evaluation.
# User 449340 not found in training data. Skipping evaluation.
# User 923998 not found in training data. Skipping evaluation.
# User 303251 not found in training data. Skipping evaluation.
# User 80485 not found in training data. Skipping evaluation.
# User 495786 not found in training data. Skipping evaluation.
# User 454564 not found in training data. Skipping evaluation.
# User 71876 not found in training data. Skipping evaluation.
# User 77108 not found in training data. Skipping evaluation.
# User 736249 not found in training data. Skipping evaluation.
# User 856640 not found in training data. Skipping evaluation.
# User 753556 not found in training data. Skipping evaluation.
# User 990457 not found in training data. Skipping evaluation.
# User 314049 not found in training data. Skipping evaluation.
# User 481730 not found in training data. Skipping evaluation.
# User 93859 not found in training data. Skipping evaluation.
# User 935123 not found in training data. Skipping evaluation.
# User 891871 not found in training data. Skipping evaluation.
# User 209716 not found in training data. Skipping evaluation.
# User 950808 not found in training data. Skipping evaluation.
# User 831150 not found in training data. Skipping evaluation.
# User 216830 not found in training data. Skipping evaluation.
# User 766597 not found in training data. Skipping evaluation.
# User 958984 not found in training data. Skipping evaluation.
# User 806155 not found in training data. Skipping evaluation.
# User 907104 not found in training data. Skipping evaluation.
# User 683442 not found in training data. Skipping evaluation.
# User 512577 not found in training data. Skipping evaluation.
# User 954977 not found in training data. Skipping evaluation.
# User 320403 not found in training data. Skipping evaluation.
# User 391675 not found in training data. Skipping evaluation.
# User 989693 not found in training data. Skipping evaluation.
# User 566617 not found in training data. Skipping evaluation.
# User 134724 not found in training data. Skipping evaluation.
# User 972151 not found in training data. Skipping evaluation.
# User 807232 not found in training data. Skipping evaluation.
# User 752946 not found in training data. Skipping evaluation.
# User 256501 not found in training data. Skipping evaluation.
# User 952830 not found in training data. Skipping evaluation.
# User 771300 not found in training data. Skipping evaluation.
# User 88204 not found in training data. Skipping evaluation.
# User 583255 not found in training data. Skipping evaluation.
# User 683056 not found in training data. Skipping evaluation.
# User 662218 not found in training data. Skipping evaluation.
# User 580190 not found in training data. Skipping evaluation.
# User 433618 not found in training data. Skipping evaluation.
# User 81432 not found in training data. Skipping evaluation.
# User 66767 not found in training data. Skipping evaluation.
# User 716028 not found in training data. Skipping evaluation.
# User 901454 not found in training data. Skipping evaluation.
# User 613436 not found in training data. Skipping evaluation.
# User 881855 not found in training data. Skipping evaluation.
# User 798232 not found in training data. Skipping evaluation.
# User 92693 not found in training data. Skipping evaluation.
# User 343283 not found in training data. Skipping evaluation.
# User 578163 not found in training data. Skipping evaluation.
# User 89315 not found in training data. Skipping evaluation.
# User 693493 not found in training data. Skipping evaluation.
# User 207053 not found in training data. Skipping evaluation.
# User 281956 not found in training data. Skipping evaluation.
# User 153337 not found in training data. Skipping evaluation.
# User 118781 not found in training data. Skipping evaluation.
# User 14636 not found in training data. Skipping evaluation.
# User 104205 not found in training data. Skipping evaluation.
# User 810956 not found in training data. Skipping evaluation.
# User 52452 not found in training data. Skipping evaluation.
# User 489231 not found in training data. Skipping evaluation.
# User 770135 not found in training data. Skipping evaluation.
# User 279303 not found in training data. Skipping evaluation.
# User 347311 not found in training data. Skipping evaluation.
# User 672971 not found in training data. Skipping evaluation.
# User 515460 not found in training data. Skipping evaluation.
# User 31573 not found in training data. Skipping evaluation.
# User 852528 not found in training data. Skipping evaluation.
# User 392607 not found in training data. Skipping evaluation.
# User 780540 not found in training data. Skipping evaluation.
# User 711780 not found in training data. Skipping evaluation.
# User 953676 not found in training data. Skipping evaluation.
# User 649361 not found in training data. Skipping evaluation.
# User 500393 not found in training data. Skipping evaluation.
# User 405712 not found in training data. Skipping evaluation.
# User 867921 not found in training data. Skipping evaluation.
# User 431444 not found in training data. Skipping evaluation.
# User 219635 not found in training data. Skipping evaluation.
# User 336021 not found in training data. Skipping evaluation.
# User 943044 not found in training data. Skipping evaluation.
# User 574777 not found in training data. Skipping evaluation.
# User 845796 not found in training data. Skipping evaluation.
# User 391171 not found in training data. Skipping evaluation.
# User 774431 not found in training data. Skipping evaluation.
# User 816719 not found in training data. Skipping evaluation.
# User 282768 not found in training data. Skipping evaluation.
# User 843684 not found in training data. Skipping evaluation.
# User 469300 not found in training data. Skipping evaluation.
# User 215856 not found in training data. Skipping evaluation.
# User 266560 not found in training data. Skipping evaluation.
# User 412655 not found in training data. Skipping evaluation.
# User 33115 not found in training data. Skipping evaluation.
# User 468552 not found in training data. Skipping evaluation.
# User 634890 not found in training data. Skipping evaluation.
# User 890929 not found in training data. Skipping evaluation.
# User 365272 not found in training data. Skipping evaluation.
# User 12707 not found in training data. Skipping evaluation.
# User 245850 not found in training data. Skipping evaluation.
# User 103064 not found in training data. Skipping evaluation.
# User 526900 not found in training data. Skipping evaluation.
# User 538338 not found in training data. Skipping evaluation.
# User 112469 not found in training data. Skipping evaluation.
# User 915130 not found in training data. Skipping evaluation.
# User 642111 not found in training data. Skipping evaluation.
# User 151039 not found in training data. Skipping evaluation.
# User 592166 not found in training data. Skipping evaluation.
# User 254943 not found in training data. Skipping evaluation.
# User 943682 not found in training data. Skipping evaluation.
# User 958399 not found in training data. Skipping evaluation.
# User 1383 not found in training data. Skipping evaluation.
# User 240370 not found in training data. Skipping evaluation.
# User 113834 not found in training data. Skipping evaluation.
# User 545516 not found in training data. Skipping evaluation.
# User 633015 not found in training data. Skipping evaluation.
# User 515659 not found in training data. Skipping evaluation.
# User 335459 not found in training data. Skipping evaluation.
# User 145548 not found in training data. Skipping evaluation.
# User 464183 not found in training data. Skipping evaluation.
# User 495009 not found in training data. Skipping evaluation.
# User 89875 not found in training data. Skipping evaluation.
# User 597846 not found in training data. Skipping evaluation.
# User 448766 not found in training data. Skipping evaluation.
# User 727193 not found in training data. Skipping evaluation.
# User 459787 not found in training data. Skipping evaluation.
# User 821727 not found in training data. Skipping evaluation.
# User 312002 not found in training data. Skipping evaluation.
# User 734962 not found in training data. Skipping evaluation.
# User 163790 not found in training data. Skipping evaluation.
# Metrics for round 2: {'ndcg@k': np.float64(0.05354725488766322), 'hr@k': np.float64(0.10145290581162325), 'mrr@k': np.float64(0.037913326653306614), 'ndcg_low': np.float64(0.06963513712380502), 'ndcg_moderate_high': np.float64(0.04628987144344223), 'DI_NDCG': np.float64(1.5043277276949547), 'GRU_NDCG': np.float64(0.02334526568036279), 'CV': np.float64(0.2029058116232465), 'cv_low': np.float64(0.25463336019339244), 'cv_moderate_high': np.float64(0.17957106506724826), 'HR_LOW': np.float64(0.12731668009669622), 'HR_MODERATE_HIGH': np.float64(0.08978553253362413), 'MRR_LOW': np.float64(0.050671501477303246), 'MRR_MODERATE_HIGH': np.float64(0.03215800315036956), 'UCV_NDCG': np.float64(3.027129091819404), 'UCV_HR': np.float64(2.9010323230420836), 'UCV_MRR': np.float64(3.301742394071298), 'DI_HR': np.float64(1.4180088540324345), 'GRU_HR': np.float64(0.03753114756307209), 'DI_MRR': np.float64(1.5757042264211896), 'GRU_MRR': np.float64(0.018513498326933685)}
# Training Round 3...
# User 759686 not found in training data. Skipping evaluation.
# User 633700 not found in training data. Skipping evaluation.
# User 847972 not found in training data. Skipping evaluation.
# User 554236 not found in training data. Skipping evaluation.
# User 867579 not found in training data. Skipping evaluation.
# User 634356 not found in training data. Skipping evaluation.
# User 902075 not found in training data. Skipping evaluation.
# User 716249 not found in training data. Skipping evaluation.
# User 901112 not found in training data. Skipping evaluation.
# User 167789 not found in training data. Skipping evaluation.
# User 608089 not found in training data. Skipping evaluation.
# User 373717 not found in training data. Skipping evaluation.
# User 382674 not found in training data. Skipping evaluation.
# User 688594 not found in training data. Skipping evaluation.
# User 89438 not found in training data. Skipping evaluation.
# User 397724 not found in training data. Skipping evaluation.
# User 632710 not found in training data. Skipping evaluation.
# User 790847 not found in training data. Skipping evaluation.
# User 592065 not found in training data. Skipping evaluation.
# User 413844 not found in training data. Skipping evaluation.
# User 371335 not found in training data. Skipping evaluation.
# User 774863 not found in training data. Skipping evaluation.
# User 384270 not found in training data. Skipping evaluation.
# User 594557 not found in training data. Skipping evaluation.
# User 877323 not found in training data. Skipping evaluation.
# User 913139 not found in training data. Skipping evaluation.
# User 408008 not found in training data. Skipping evaluation.
# User 812798 not found in training data. Skipping evaluation.
# User 253950 not found in training data. Skipping evaluation.
# User 679431 not found in training data. Skipping evaluation.
# User 865033 not found in training data. Skipping evaluation.
# User 446201 not found in training data. Skipping evaluation.
# User 990283 not found in training data. Skipping evaluation.
# User 89500 not found in training data. Skipping evaluation.
# User 750543 not found in training data. Skipping evaluation.
# User 429031 not found in training data. Skipping evaluation.
# User 339 not found in training data. Skipping evaluation.
# User 288435 not found in training data. Skipping evaluation.
# User 41992 not found in training data. Skipping evaluation.
# User 523600 not found in training data. Skipping evaluation.
# User 281723 not found in training data. Skipping evaluation.
# User 775478 not found in training data. Skipping evaluation.
# User 610378 not found in training data. Skipping evaluation.
# User 610200 not found in training data. Skipping evaluation.
# User 532209 not found in training data. Skipping evaluation.
# User 444342 not found in training data. Skipping evaluation.
# User 401453 not found in training data. Skipping evaluation.
# User 344372 not found in training data. Skipping evaluation.
# User 785986 not found in training data. Skipping evaluation.
# User 979179 not found in training data. Skipping evaluation.
# User 909674 not found in training data. Skipping evaluation.
# User 499863 not found in training data. Skipping evaluation.
# User 780746 not found in training data. Skipping evaluation.
# User 281628 not found in training data. Skipping evaluation.
# User 732020 not found in training data. Skipping evaluation.
# User 398506 not found in training data. Skipping evaluation.
# User 518352 not found in training data. Skipping evaluation.
# User 771160 not found in training data. Skipping evaluation.
# User 209090 not found in training data. Skipping evaluation.
# User 28722 not found in training data. Skipping evaluation.
# User 390350 not found in training data. Skipping evaluation.
# User 729567 not found in training data. Skipping evaluation.
# User 557424 not found in training data. Skipping evaluation.
# User 291553 not found in training data. Skipping evaluation.
# User 649070 not found in training data. Skipping evaluation.
# User 120564 not found in training data. Skipping evaluation.
# User 74272 not found in training data. Skipping evaluation.
# User 972737 not found in training data. Skipping evaluation.
# User 179945 not found in training data. Skipping evaluation.
# User 145195 not found in training data. Skipping evaluation.
# User 494387 not found in training data. Skipping evaluation.
# User 477665 not found in training data. Skipping evaluation.
# User 133940 not found in training data. Skipping evaluation.
# User 902797 not found in training data. Skipping evaluation.
# User 178172 not found in training data. Skipping evaluation.
# User 22210 not found in training data. Skipping evaluation.
# User 712393 not found in training data. Skipping evaluation.
# User 846063 not found in training data. Skipping evaluation.
# User 609817 not found in training data. Skipping evaluation.
# User 973954 not found in training data. Skipping evaluation.
# User 121195 not found in training data. Skipping evaluation.
# User 731548 not found in training data. Skipping evaluation.
# User 903500 not found in training data. Skipping evaluation.
# User 502055 not found in training data. Skipping evaluation.
# User 364774 not found in training data. Skipping evaluation.
# User 237114 not found in training data. Skipping evaluation.
# User 845475 not found in training data. Skipping evaluation.
# User 107182 not found in training data. Skipping evaluation.
# User 923483 not found in training data. Skipping evaluation.
# User 322430 not found in training data. Skipping evaluation.
# User 556060 not found in training data. Skipping evaluation.
# User 797532 not found in training data. Skipping evaluation.
# User 453943 not found in training data. Skipping evaluation.
# User 214071 not found in training data. Skipping evaluation.
# User 561460 not found in training data. Skipping evaluation.
# User 257047 not found in training data. Skipping evaluation.
# User 803467 not found in training data. Skipping evaluation.
# User 184719 not found in training data. Skipping evaluation.
# User 638051 not found in training data. Skipping evaluation.
# User 3441 not found in training data. Skipping evaluation.
# User 554757 not found in training data. Skipping evaluation.
# User 954634 not found in training data. Skipping evaluation.
# User 185968 not found in training data. Skipping evaluation.
# User 551294 not found in training data. Skipping evaluation.
# User 854652 not found in training data. Skipping evaluation.
# User 785835 not found in training data. Skipping evaluation.
# User 403865 not found in training data. Skipping evaluation.
# User 344026 not found in training data. Skipping evaluation.
# User 584843 not found in training data. Skipping evaluation.
# User 656383 not found in training data. Skipping evaluation.
# User 404160 not found in training data. Skipping evaluation.
# User 628216 not found in training data. Skipping evaluation.
# User 304095 not found in training data. Skipping evaluation.
# User 727006 not found in training data. Skipping evaluation.
# User 433181 not found in training data. Skipping evaluation.
# User 868645 not found in training data. Skipping evaluation.
# ...
# User 792901 not found in training data. Skipping evaluation.
# User 950162 not found in training data. Skipping evaluation.
# User 711922 not found in training data. Skipping evaluation.
# User 547696 not found in training data. Skipping evaluation.
# User 722585 not found in training data. Skipping evaluation.
# User 370133 not found in training data. Skipping evaluation.
# User 854790 not found in training data. Skipping evaluation.
# User 507543 not found in training data. Skipping evaluation.
# User 859278 not found in training data. Skipping evaluation.
# User 682195 not found in training data. Skipping evaluation.
# User 66464 not found in training data. Skipping evaluation.
# User 773589 not found in training data. Skipping evaluation.
# User 973978 not found in training data. Skipping evaluation.
# User 249370 not found in training data. Skipping evaluation.
# User 421413 not found in training data. Skipping evaluation.
# User 257237 not found in training data. Skipping evaluation.
# User 597876 not found in training data. Skipping evaluation.
# User 724741 not found in training data. Skipping evaluation.
# User 176156 not found in training data. Skipping evaluation.
# User 531129 not found in training data. Skipping evaluation.
# User 188250 not found in training data. Skipping evaluation.
# User 465200 not found in training data. Skipping evaluation.
# User 836108 not found in training data. Skipping evaluation.
# User 863735 not found in training data. Skipping evaluation.
# User 323092 not found in training data. Skipping evaluation.
# User 595907 not found in training data. Skipping evaluation.
# User 496931 not found in training data. Skipping evaluation.
# User 205870 not found in training data. Skipping evaluation.
# User 615780 not found in training data. Skipping evaluation.
# User 252933 not found in training data. Skipping evaluation.
# User 688494 not found in training data. Skipping evaluation.
# User 709675 not found in training data. Skipping evaluation.
# User 376862 not found in training data. Skipping evaluation.
# User 374458 not found in training data. Skipping evaluation.
# User 781046 not found in training data. Skipping evaluation.
# User 244424 not found in training data. Skipping evaluation.
# User 770943 not found in training data. Skipping evaluation.
# User 999052 not found in training data. Skipping evaluation.
# User 330935 not found in training data. Skipping evaluation.
# User 144256 not found in training data. Skipping evaluation.
# User 237047 not found in training data. Skipping evaluation.
# User 666027 not found in training data. Skipping evaluation.
# User 792600 not found in training data. Skipping evaluation.
# User 575668 not found in training data. Skipping evaluation.
# User 287944 not found in training data. Skipping evaluation.
# User 583504 not found in training data. Skipping evaluation.
# User 712050 not found in training data. Skipping evaluation.
# User 185584 not found in training data. Skipping evaluation.
# User 729599 not found in training data. Skipping evaluation.
# User 58462 not found in training data. Skipping evaluation.
# User 265322 not found in training data. Skipping evaluation.
# User 746754 not found in training data. Skipping evaluation.
# User 872252 not found in training data. Skipping evaluation.
# User 171935 not found in training data. Skipping evaluation.
# User 513943 not found in training data. Skipping evaluation.
# User 37752 not found in training data. Skipping evaluation.
# User 287332 not found in training data. Skipping evaluation.
# User 929654 not found in training data. Skipping evaluation.
# User 553284 not found in training data. Skipping evaluation.
# User 144419 not found in training data. Skipping evaluation.
# User 285750 not found in training data. Skipping evaluation.
# User 972667 not found in training data. Skipping evaluation.
# User 901720 not found in training data. Skipping evaluation.
# User 410208 not found in training data. Skipping evaluation.
# User 999843 not found in training data. Skipping evaluation.
# User 685948 not found in training data. Skipping evaluation.
# User 449340 not found in training data. Skipping evaluation.
# User 923998 not found in training data. Skipping evaluation.
# User 303251 not found in training data. Skipping evaluation.
# User 80485 not found in training data. Skipping evaluation.
# User 495786 not found in training data. Skipping evaluation.
# User 454564 not found in training data. Skipping evaluation.
# User 71876 not found in training data. Skipping evaluation.
# User 77108 not found in training data. Skipping evaluation.
# User 736249 not found in training data. Skipping evaluation.
# User 856640 not found in training data. Skipping evaluation.
# User 753556 not found in training data. Skipping evaluation.
# User 990457 not found in training data. Skipping evaluation.
# User 314049 not found in training data. Skipping evaluation.
# User 481730 not found in training data. Skipping evaluation.
# User 93859 not found in training data. Skipping evaluation.
# User 935123 not found in training data. Skipping evaluation.
# User 891871 not found in training data. Skipping evaluation.
# User 209716 not found in training data. Skipping evaluation.
# User 950808 not found in training data. Skipping evaluation.
# User 831150 not found in training data. Skipping evaluation.
# User 216830 not found in training data. Skipping evaluation.
# User 766597 not found in training data. Skipping evaluation.
# User 958984 not found in training data. Skipping evaluation.
# User 806155 not found in training data. Skipping evaluation.
# User 907104 not found in training data. Skipping evaluation.
# User 683442 not found in training data. Skipping evaluation.
# User 512577 not found in training data. Skipping evaluation.
# User 954977 not found in training data. Skipping evaluation.
# User 320403 not found in training data. Skipping evaluation.
# User 391675 not found in training data. Skipping evaluation.
# User 989693 not found in training data. Skipping evaluation.
# User 566617 not found in training data. Skipping evaluation.
# User 134724 not found in training data. Skipping evaluation.
# User 972151 not found in training data. Skipping evaluation.
# User 807232 not found in training data. Skipping evaluation.
# User 752946 not found in training data. Skipping evaluation.
# User 256501 not found in training data. Skipping evaluation.
# User 952830 not found in training data. Skipping evaluation.
# User 771300 not found in training data. Skipping evaluation.
# User 88204 not found in training data. Skipping evaluation.
# User 583255 not found in training data. Skipping evaluation.
# User 683056 not found in training data. Skipping evaluation.
# User 662218 not found in training data. Skipping evaluation.
# User 580190 not found in training data. Skipping evaluation.
# User 433618 not found in training data. Skipping evaluation.
# User 81432 not found in training data. Skipping evaluation.
# User 66767 not found in training data. Skipping evaluation.
# User 716028 not found in training data. Skipping evaluation.
# User 901454 not found in training data. Skipping evaluation.
# User 613436 not found in training data. Skipping evaluation.
# User 881855 not found in training data. Skipping evaluation.
# User 798232 not found in training data. Skipping evaluation.
# User 92693 not found in training data. Skipping evaluation.
# User 343283 not found in training data. Skipping evaluation.
# User 578163 not found in training data. Skipping evaluation.
# User 89315 not found in training data. Skipping evaluation.
# User 693493 not found in training data. Skipping evaluation.
# User 207053 not found in training data. Skipping evaluation.
# User 281956 not found in training data. Skipping evaluation.
# User 153337 not found in training data. Skipping evaluation.
# User 118781 not found in training data. Skipping evaluation.
# User 14636 not found in training data. Skipping evaluation.
# User 104205 not found in training data. Skipping evaluation.
# User 810956 not found in training data. Skipping evaluation.
# User 52452 not found in training data. Skipping evaluation.
# User 489231 not found in training data. Skipping evaluation.
# User 770135 not found in training data. Skipping evaluation.
# User 279303 not found in training data. Skipping evaluation.
# User 347311 not found in training data. Skipping evaluation.
# User 672971 not found in training data. Skipping evaluation.
# User 515460 not found in training data. Skipping evaluation.
# User 31573 not found in training data. Skipping evaluation.
# User 852528 not found in training data. Skipping evaluation.
# User 392607 not found in training data. Skipping evaluation.
# User 780540 not found in training data. Skipping evaluation.
# User 711780 not found in training data. Skipping evaluation.
# User 953676 not found in training data. Skipping evaluation.
# User 649361 not found in training data. Skipping evaluation.
# User 500393 not found in training data. Skipping evaluation.
# User 405712 not found in training data. Skipping evaluation.
# User 867921 not found in training data. Skipping evaluation.
# User 431444 not found in training data. Skipping evaluation.
# User 219635 not found in training data. Skipping evaluation.
# User 336021 not found in training data. Skipping evaluation.
# User 943044 not found in training data. Skipping evaluation.
# User 574777 not found in training data. Skipping evaluation.
# User 845796 not found in training data. Skipping evaluation.
# User 391171 not found in training data. Skipping evaluation.
# User 774431 not found in training data. Skipping evaluation.
# User 816719 not found in training data. Skipping evaluation.
# User 282768 not found in training data. Skipping evaluation.
# User 843684 not found in training data. Skipping evaluation.
# User 469300 not found in training data. Skipping evaluation.
# User 215856 not found in training data. Skipping evaluation.
# User 266560 not found in training data. Skipping evaluation.
# User 412655 not found in training data. Skipping evaluation.
# User 33115 not found in training data. Skipping evaluation.
# User 468552 not found in training data. Skipping evaluation.
# User 634890 not found in training data. Skipping evaluation.
# User 890929 not found in training data. Skipping evaluation.
# User 365272 not found in training data. Skipping evaluation.
# User 12707 not found in training data. Skipping evaluation.
# User 245850 not found in training data. Skipping evaluation.
# User 103064 not found in training data. Skipping evaluation.
# User 526900 not found in training data. Skipping evaluation.
# User 538338 not found in training data. Skipping evaluation.
# User 112469 not found in training data. Skipping evaluation.
# User 915130 not found in training data. Skipping evaluation.
# User 642111 not found in training data. Skipping evaluation.
# User 151039 not found in training data. Skipping evaluation.
# User 592166 not found in training data. Skipping evaluation.
# User 254943 not found in training data. Skipping evaluation.
# User 943682 not found in training data. Skipping evaluation.
# User 958399 not found in training data. Skipping evaluation.
# User 1383 not found in training data. Skipping evaluation.
# User 240370 not found in training data. Skipping evaluation.
# User 113834 not found in training data. Skipping evaluation.
# User 545516 not found in training data. Skipping evaluation.
# User 633015 not found in training data. Skipping evaluation.
# User 515659 not found in training data. Skipping evaluation.
# User 335459 not found in training data. Skipping evaluation.
# User 145548 not found in training data. Skipping evaluation.
# User 464183 not found in training data. Skipping evaluation.
# User 495009 not found in training data. Skipping evaluation.
# User 89875 not found in training data. Skipping evaluation.
# User 597846 not found in training data. Skipping evaluation.
# User 448766 not found in training data. Skipping evaluation.
# User 727193 not found in training data. Skipping evaluation.
# User 459787 not found in training data. Skipping evaluation.
# User 821727 not found in training data. Skipping evaluation.
# User 312002 not found in training data. Skipping evaluation.
# User 734962 not found in training data. Skipping evaluation.
# User 163790 not found in training data. Skipping evaluation.
# Metrics for round 3: {'ndcg@k': np.float64(0.050472077823825415), 'hr@k': np.float64(0.09493987975951904), 'mrr@k': np.float64(0.03599699398797595), 'ndcg_low': np.float64(0.060840466616751694), 'ndcg_moderate_high': np.float64(0.04579480756136758), 'DI_NDCG': np.float64(1.3285450874582692), 'GRU_NDCG': np.float64(0.015045659055384117), 'CV': np.float64(0.18987975951903807), 'cv_low': np.float64(0.22240128928283642), 'cv_moderate_high': np.float64(0.17520901490367138), 'HR_LOW': np.float64(0.11120064464141821), 'HR_MODERATE_HIGH': np.float64(0.08760450745183569), 'MRR_LOW': np.float64(0.04437281762019876), 'MRR_MODERATE_HIGH': np.float64(0.03221858718041924), 'UCV_NDCG': np.float64(3.1774683647540645), 'UCV_HR': np.float64(3.0271820567713226), 'UCV_MRR': np.float64(3.4980818486958953), 'DI_HR': np.float64(1.2693484373798403), 'GRU_HR': np.float64(0.02359613718958252), 'DI_MRR': np.float64(1.3772428124088016), 'GRU_MRR': np.float64(0.01215423043977952)}
#
# Overall Results:
# {1: {'ndcg@k': np.float64(0.049627805560888846), 'hr@k': np.float64(0.09268537074148296), 'mrr@k': np.float64(0.03556696726786907), 'ndcg_low': np.float64(0.06385123252424016), 'ndcg_moderate_high': np.float64(0.04321149408814475), 'DI_NDCG': np.float64(1.4776446376511199), 'GRU_NDCG': np.float64(0.020639738436095408), 'CV': np.float64(0.18537074148296592), 'cv_low': np.float64(0.22723609991941982), 'cv_moderate_high': np.float64(0.16648491457651762), 'HR_LOW': np.float64(0.11361804995970991), 'HR_MODERATE_HIGH': np.float64(0.08324245728825881), 'MRR_LOW': np.float64(0.04744829438624765), 'MRR_MODERATE_HIGH': np.float64(0.0302071973827699), 'UCV_NDCG': np.float64(3.2016326699527538), 'UCV_HR': np.float64(3.0558505532392504), 'UCV_MRR': np.float64(3.510971668452215), 'DI_HR': np.float64(1.3649050455858602), 'GRU_HR': np.float64(0.030375592671451096), 'DI_MRR': np.float64(1.5707612257107977), 'GRU_MRR': np.float64(0.017241097003477746)}, 2: {'ndcg@k': np.float64(0.05354725488766322), 'hr@k': np.float64(0.10145290581162325), 'mrr@k': np.float64(0.037913326653306614), 'ndcg_low': np.float64(0.06963513712380502), 'ndcg_moderate_high': np.float64(0.04628987144344223), 'DI_NDCG': np.float64(1.5043277276949547), 'GRU_NDCG': np.float64(0.02334526568036279), 'CV': np.float64(0.2029058116232465), 'cv_low': np.float64(0.25463336019339244), 'cv_moderate_high': np.float64(0.17957106506724826), 'HR_LOW': np.float64(0.12731668009669622), 'HR_MODERATE_HIGH': np.float64(0.08978553253362413), 'MRR_LOW': np.float64(0.050671501477303246), 'MRR_MODERATE_HIGH': np.float64(0.03215800315036956), 'UCV_NDCG': np.float64(3.027129091819404), 'UCV_HR': np.float64(2.9010323230420836), 'UCV_MRR': np.float64(3.301742394071298), 'DI_HR': np.float64(1.4180088540324345), 'GRU_HR': np.float64(0.03753114756307209), 'DI_MRR': np.float64(1.5757042264211896), 'GRU_MRR': np.float64(0.018513498326933685)}, 3: {'ndcg@k': np.float64(0.050472077823825415), 'hr@k': np.float64(0.09493987975951904), 'mrr@k': np.float64(0.03599699398797595), 'ndcg_low': np.float64(0.060840466616751694), 'ndcg_moderate_high': np.float64(0.04579480756136758), 'DI_NDCG': np.float64(1.3285450874582692), 'GRU_NDCG': np.float64(0.015045659055384117), 'CV': np.float64(0.18987975951903807), 'cv_low': np.float64(0.22240128928283642), 'cv_moderate_high': np.float64(0.17520901490367138), 'HR_LOW': np.float64(0.11120064464141821), 'HR_MODERATE_HIGH': np.float64(0.08760450745183569), 'MRR_LOW': np.float64(0.04437281762019876), 'MRR_MODERATE_HIGH': np.float64(0.03221858718041924), 'UCV_NDCG': np.float64(3.1774683647540645), 'UCV_HR': np.float64(3.0271820567713226), 'UCV_MRR': np.float64(3.4980818486958953), 'DI_HR': np.float64(1.2693484373798403), 'GRU_HR': np.float64(0.02359613718958252), 'DI_MRR': np.float64(1.3772428124088016), 'GRU_MRR': np.float64(0.01215423043977952)}}

# %% [markdown]
# {1: {'ndcg@k': np.float64(0.049627805560888846), 'hr@k': np.float64(0.09268537074148296), 'mrr@k': np.float64(0.03556696726786907), 'ndcg_low': np.float64(0.06385123252424016), 'ndcg_moderate_high': np.float64(0.04321149408814475), 'DI_NDCG': np.float64(1.4776446376511199), 'GRU_NDCG': np.float64(0.020639738436095408), 'CV': np.float64(0.18537074148296592), 'cv_low': np.float64(0.22723609991941982), 'cv_moderate_high': np.float64(0.16648491457651762), 'HR_LOW': np.float64(0.11361804995970991), 'HR_MODERATE_HIGH': np.float64(0.08324245728825881), 'MRR_LOW': np.float64(0.04744829438624765), 'MRR_MODERATE_HIGH': np.float64(0.0302071973827699), 'UCV_NDCG': np.float64(3.2016326699527538), 'UCV_HR': np.float64(3.0558505532392504), 'UCV_MRR': np.float64(3.510971668452215), 'DI_HR': np.float64(1.3649050455858602), 'GRU_HR': np.float64(0.030375592671451096), 'DI_MRR': np.float64(1.5707612257107977), 'GRU_MRR': np.float64(0.017241097003477746)}, 2: {'ndcg@k': np.float64(0.05354725488766322), 'hr@k': np.float64(0.10145290581162325), 'mrr@k': np.float64(0.037913326653306614), 'ndcg_low': np.float64(0.06963513712380502), 'ndcg_moderate_high': np.float64(0.04628987144344223), 'DI_NDCG': np.float64(1.5043277276949547), 'GRU_NDCG': np.float64(0.02334526568036279), 'CV': np.float64(0.2029058116232465), 'cv_low': np.float64(0.25463336019339244), 'cv_moderate_high': np.float64(0.17957106506724826), 'HR_LOW': np.float64(0.12731668009669622), 'HR_MODERATE_HIGH': np.float64(0.08978553253362413), 'MRR_LOW': np.float64(0.050671501477303246), 'MRR_MODERATE_HIGH': np.float64(0.03215800315036956), 'UCV_NDCG': np.float64(3.027129091819404), 'UCV_HR': np.float64(2.9010323230420836), 'UCV_MRR': np.float64(3.301742394071298), 'DI_HR': np.float64(1.4180088540324345), 'GRU_HR': np.float64(0.03753114756307209), 'DI_MRR': np.float64(1.5757042264211896), 'GRU_MRR': np.float64(0.018513498326933685)}, 3: {'ndcg@k': np.float64(0.050472077823825415), 'hr@k': np.float64(0.09493987975951904), 'mrr@k': np.float64(0.03599699398797595), 'ndcg_low': np.float64(0.060840466616751694), 'ndcg_moderate_high': np.float64(0.04579480756136758), 'DI_NDCG': np.float64(1.3285450874582692), 'GRU_NDCG': np.float64(0.015045659055384117), 'CV': np.float64(0.18987975951903807), 'cv_low': np.float64(0.22240128928283642), 'cv_moderate_high': np.float64(0.17520901490367138), 'HR_LOW': np.float64(0.11120064464141821), 'HR_MODERATE_HIGH': np.float64(0.08760450745183569), 'MRR_LOW': np.float64(0.04437281762019876), 'MRR_MODERATE_HIGH': np.float64(0.03221858718041924), 'UCV_NDCG': np.float64(3.1774683647540645), 'UCV_HR': np.float64(3.0271820567713226), 'UCV_MRR': np.float64(3.4980818486958953), 'DI_HR': np.float64(1.2693484373798403), 'GRU_HR': np.float64(0.02359613718958252), 'DI_MRR': np.float64(1.3772428124088016), 'GRU_MRR': np.float64(0.01215423043977952)}}

# %%
###############################################
# 3. Hyperparameter tuning BPR
###############################################
from sklearn.model_selection import ParameterGrid
from lightfm.evaluation import auc_score
param_grid = {
    'no_components': [10, 20, 50],
    'learning_rate': [0.01, 0.05, 0.1],
    'item_alpha': [1e-06, 1e-05],
    'user_alpha': [1e-05, 1e-06],
}

best_auc = 0
best_params = {}


grid = ParameterGrid(param_grid)

for params in grid:
  print(f"Training with parameters: {params}")
  model = LightFM(loss='bpr', **params)
  model.fit(interactions, epochs=30, num_threads=2)
  # AUC = The area under the ROC curve (AUC)
  # https://towardsdatascience.com/understanding-the-roc-curve-and-auc-dd4f9a192ecb/

  auc = auc_score(model, interactions, num_threads=2).mean()
  print(f"AUC score: {auc}")

  if auc > best_auc:
    best_auc = auc
    best_params = params


print(f"\nBest parameters: {best_params}, Best AUC: {best_auc}")


best_model = LightFM(loss='bpr', **best_params)
best_model.fit(interactions, epochs=30, num_threads=2)

best_model
# Out:
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.01, 'no_components': 10, 'user_alpha': 1e-05}
# AUC score: 0.7441076636314392
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.01, 'no_components': 10, 'user_alpha': 1e-06}
# AUC score: 0.7489626407623291
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.01, 'no_components': 20, 'user_alpha': 1e-05}
# AUC score: 0.7508640885353088
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.01, 'no_components': 20, 'user_alpha': 1e-06}
# AUC score: 0.7629712224006653
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.01, 'no_components': 50, 'user_alpha': 1e-05}
# AUC score: 0.721182107925415
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.01, 'no_components': 50, 'user_alpha': 1e-06}
# AUC score: 0.7296546697616577
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.05, 'no_components': 10, 'user_alpha': 1e-05}
# AUC score: 0.9691360592842102
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.05, 'no_components': 10, 'user_alpha': 1e-06}
# AUC score: 0.9706486463546753
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.05, 'no_components': 20, 'user_alpha': 1e-05}
# AUC score: 0.980345606803894
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.05, 'no_components': 20, 'user_alpha': 1e-06}
# AUC score: 0.981163740158081
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.05, 'no_components': 50, 'user_alpha': 1e-05}
# AUC score: 0.9843489527702332
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.05, 'no_components': 50, 'user_alpha': 1e-06}
# AUC score: 0.9855668544769287
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.1, 'no_components': 10, 'user_alpha': 1e-05}
# AUC score: 0.9795713424682617
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.1, 'no_components': 10, 'user_alpha': 1e-06}
# AUC score: 0.9799444675445557
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.1, 'no_components': 20, 'user_alpha': 1e-05}
# AUC score: 0.9896500706672668
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.1, 'no_components': 20, 'user_alpha': 1e-06}
# AUC score: 0.9910012483596802
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.1, 'no_components': 50, 'user_alpha': 1e-05}
# AUC score: 0.9927472472190857
# Training with parameters: {'item_alpha': 1e-06, 'learning_rate': 0.1, 'no_components': 50, 'user_alpha': 1e-06}
# AUC score: 0.9942927360534668
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.01, 'no_components': 10, 'user_alpha': 1e-05}
# AUC score: 0.7541590332984924
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.01, 'no_components': 10, 'user_alpha': 1e-06}
# AUC score: 0.7515189051628113
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.01, 'no_components': 20, 'user_alpha': 1e-05}
# AUC score: 0.7389940023422241
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.01, 'no_components': 20, 'user_alpha': 1e-06}
# AUC score: 0.7473459839820862
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.01, 'no_components': 50, 'user_alpha': 1e-05}
# AUC score: 0.6908073425292969
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.01, 'no_components': 50, 'user_alpha': 1e-06}
# AUC score: 0.7162361145019531
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.05, 'no_components': 10, 'user_alpha': 1e-05}
# AUC score: 0.969411313533783
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.05, 'no_components': 10, 'user_alpha': 1e-06}
# AUC score: 0.9694762229919434
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.05, 'no_components': 20, 'user_alpha': 1e-05}
# AUC score: 0.9803864359855652
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.05, 'no_components': 20, 'user_alpha': 1e-06}
# AUC score: 0.9817549586296082
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.05, 'no_components': 50, 'user_alpha': 1e-05}
# AUC score: 0.9846586585044861
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.05, 'no_components': 50, 'user_alpha': 1e-06}
# AUC score: 0.9855667948722839
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.1, 'no_components': 10, 'user_alpha': 1e-05}
# AUC score: 0.9790027141571045
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.1, 'no_components': 10, 'user_alpha': 1e-06}
# AUC score: 0.979557991027832
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.1, 'no_components': 20, 'user_alpha': 1e-05}
# AUC score: 0.9898702502250671
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.1, 'no_components': 20, 'user_alpha': 1e-06}
# AUC score: 0.9911546111106873
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.1, 'no_components': 50, 'user_alpha': 1e-05}
# AUC score: 0.9930383563041687
# Training with parameters: {'item_alpha': 1e-05, 'learning_rate': 0.1, 'no_components': 50, 'user_alpha': 1e-06}
# AUC score: 0.9944227337837219
#
# Best parameters: {'item_alpha': 1e-05, 'learning_rate': 0.1, 'no_components': 50, 'user_alpha': 1e-06}, Best AUC: 0.9944227337837219

# %%
#Best parameters: {'item_alpha': 1e-05, 'learning_rate': 0.1, 'no_components': 50, 'user_alpha': 1e-06}, Best AUC: 0.9944227337837219
#<lightfm.lightfm.LightFM at 0x7bd2a2df34d0>

best_model_bpr = LightFM(loss='bpr', no_components=50, learning_rate=0.1, item_alpha=1e-05, user_alpha=1e-06)
best_model_bpr.fit(interactions, epochs=30, num_threads=2)

# %%
###############################################
# 3. BPR Model
###############################################
import numpy as np
from lightfm import LightFM
from scipy.sparse import coo_matrix
from lightfm.evaluation import precision_at_k, recall_at_k


interactions = coo_matrix(train_user_item_matrix.values)

model = LightFM(loss='bpr')
 # https://making.lyst.com/lightfm/docs/lightfm.html


model.fit(interactions, epochs=30, num_threads=2)

train_precision = precision_at_k(model, interactions, k=5).mean()
train_recall = recall_at_k(model, interactions, k=5).mean()


print(f"Train Precision at k=5: {train_precision}")
print(f"Train Recall at k=5: {train_recall}")


user_id = 55
scores = model.predict(user_id, np.arange(interactions.shape[1]))
top_items = np.argsort(-scores)

print("Top 10 recommended items for user 55:", top_items[:10])
# Out:
# Train Precision at k=5: 0.2809772491455078
# Train Recall at k=5: 0.6442635265769372
# Top 10 recommended items for user 55: [397 460 838 698 399  74 415 743 827 751]

# %%
test_items = test_df.groupby("user_id")["item_id"].first().to_dict()

def calculate_metrics_for_user(user, actual_item, recs, group):
    relevance_scores = [1 if item == actual_item else 0 for item in recs]
    ndcg = ndcg_at_k(relevance_scores, k=6)
    hr = hr_at_k([actual_item], recs, k=5)
    mrr = mrr_at_k([actual_item], recs, k=5)
    cv = coefficient_of_variance(relevance_scores)
    return [user, ndcg, hr, mrr, cv, group]

metrics_lightfm = []
for user_id in train_user_item_matrix.index:
    actual_item = test_items.get(user_id, None)
    if actual_item is None:
        continue

    engagement_level = df_modcloth_clean[df_modcloth_clean["user_id"] == user_id][
        "user_activity"
    ].values[0]
    try:
        user_id_internal = train_user_item_matrix.index.get_loc(user_id)
    except KeyError:
        print(f"User {user_id} not found in training data. Skipping.")
        continue

    scores = best_model_bpr.predict(user_id_internal, np.arange(interactions.shape[1]))
    top_items = np.argsort(-scores)
    recs = [train_user_item_matrix.columns[i] for i in top_items]


    metrics_lightfm.append(
        calculate_metrics_for_user(user_id, actual_item, recs, engagement_level)
    )

metrics_lightfm_df = pd.DataFrame(
    metrics_lightfm, columns=["User", "NDCG@K", "HR@K", "MRR@K","CV", "Engagement Group"]
)
metrics_lightfm_df['User'] = pd.to_numeric(metrics_lightfm_df['User'], errors='coerce')


grouped_metrics_lightfm = metrics_lightfm_df.groupby("Engagement Group").agg(
    {"NDCG@K": "mean", "HR@K": "mean", "MRR@K": "mean", "CV":"mean"}
)
print("\nLightFM Metrics by User Engagement Level:")
grouped_metrics_lightfm
# Out:
# LightFM Metrics by User Engagement Level:
#                     NDCG@K      HR@K     MRR@K         CV
# Engagement Group
# High              0.027698  0.049437  0.014074  30.777480
# Low               0.036172  0.063658  0.023274  30.698086

# %%
###############################################
# 3. Multiple rounds BPR
###############################################
from lightfm import LightFM
from scipy.sparse import csr_matrix
from lightfm.evaluation import precision_at_k, recall_at_k, auc_score
from lightfm.cross_validation import random_train_test_split
from sklearn.metrics import ndcg_score



def evaluate_lightfm_multiple_rounds(
    interactions, test_df, df_rent_clean, num_rounds=3, k=5, epochs=30, user_id_to_print=55
):
    """
    Evaluates LightFM model with multiple training rounds, fairness metrics, and prints recommendations for a user.

    Args:
        interactions: The user-item interaction matrix (sparse).
        test_df: The test DataFrame.
        df_rent_clean: The cleaned main DataFrame with user activity.
        num_rounds: The number of training rounds.
        k: The value of k for precision@k, recall@k metrics.
        epochs: The number of epochs for each training round.
        user_id_to_print: The user ID for which recommendations will be printed.

    Returns:
        A dictionary containing metrics for each round.
    """

    train_interactions, test_interactions = random_train_test_split(
        interactions, test_percentage=0.2, random_state=42
    )

    round_metrics = {}
    model = LightFM(loss='bpr', no_components=50, learning_rate=0.1, item_alpha=1e-05, user_alpha=1e-06)# best model

    test_items = test_df.groupby("user_id")["item_id"].first().to_dict()

    user_id_map = {user: i for i, user in enumerate(train_user_item_matrix.index)}


    for round_num in range(num_rounds):
        print(f"Training Round {round_num + 1}...")
        model.fit(train_interactions, epochs=epochs)

        test_user_ids = test_df['user_id'].unique()


        ndcg_scores = []
        hr_scores = []
        mrr_scores = []
        cv_scores = [] #<- IGNORE
        engagement_levels_list = []

        for user_id in test_user_ids:
            actual_item = test_items.get(user_id, None)
            if actual_item is None:
                continue
            user_id_internal = user_id_map.get(user_id, None)
            if user_id_internal is None:
                print(f"User {user_id} not found in training data. Skipping evaluation.")
                continue
            engagement_level_row = df_modcloth_clean[df_modcloth_clean["user_id"] == user_id]
            if engagement_level_row.empty:
                 print(f"User {user_id} not found in df_rent_clean for engagement level. Skipping.")
                 continue
            engagement_level = engagement_level_row["user_activity"].values[0]
            engagement_levels_list.append(engagement_level)
            scores = model.predict(user_id_internal, np.arange(interactions.shape[1]))
            top_k_indices = np.argsort(-scores)[:k]
            top_k_items_predicted = [train_user_item_matrix.columns[i] for i in top_k_indices]
            relevance_scores = [1 if item == actual_item else 0 for item in top_k_items_predicted]
            ndcg_scores.append(ndcg_at_k(relevance_scores, k))

            hr_scores.append(hr_at_k([actual_item], top_k_items_predicted, k))
            mrr_scores.append(mrr_at_k([actual_item], top_k_items_predicted, k))
            cv_scores.append(coefficient_of_variance(np.array(relevance_scores)))
        ndcg = np.mean(ndcg_scores) if ndcg_scores else 0
        hr = np.mean(hr_scores) if hr_scores else 0
        mrr = np.mean(mrr_scores) if mrr_scores else 0
        cv = np.mean(cv_scores) if cv_scores else 0
        ndcg_low = [
            ndcg_scores[i]
            for i in range(len(ndcg_scores))
            if engagement_levels_list[i] == "Low"
        ]
        ndcg_moderate_high = [
            ndcg_scores[i]
            for i in range(len(ndcg_scores))
            if engagement_levels_list[i] == "High"
        ]
        cv_low = [
            cv_scores[i]
            for i in range(len(cv_scores))
            if engagement_levels_list[i] == "Low"
        ]
        cv_moderate_high = [
            cv_scores[i]
            for i in range(len(cv_scores))
            if engagement_levels_list[i] == "High"
        ]
        hr_low = [
            hr_scores[i]
            for i in range(len(hr_scores))
            if engagement_levels_list[i] == "Low"
        ]
        hr_moderate_high = [
            hr_scores[i]
            for i in range(len(hr_scores))
            if engagement_levels_list[i] == "High"
        ]
        mrr_low = [
            mrr_scores[i]
            for i in range(len(mrr_scores))
            if engagement_levels_list[i] == "Low"
        ]
        mrr_moderate_high = [
            mrr_scores[i]
            for i in range(len(mrr_scores))
            if engagement_levels_list[i] == "High"
        ]

        ucv_ndcg = calculate_ucv(ndcg_low, ndcg_moderate_high)

        ucv_hr = calculate_ucv(hr_low, hr_moderate_high)
        ucv_mrr = calculate_ucv(mrr_low, mrr_moderate_high)
        cv_low_mean = np.mean(cv_low) if cv_low else 0
        cv_moderate_high_mean = np.mean(cv_moderate_high) if cv_moderate_high else 0
        hr_low_mean = np.mean(hr_low) if hr_low else 0
        hr_moderate_high_mean = np.mean(hr_moderate_high) if hr_moderate_high else 0
        mrr_low_mean = np.mean(mrr_low) if mrr_low else 0
        mrr_moderate_high_mean = np.mean(mrr_moderate_high) if mrr_moderate_high else 0
        di_ndcg = calculate_disparate_impact(ndcg_low, ndcg_moderate_high) if ndcg_moderate_high else np.inf
        gru_ndcg = calculate_group_recommender_unfairness(ndcg_low, ndcg_moderate_high)
        ndcg_low = np.mean(ndcg_low) if ndcg_low else 0
        ndcg_moderate_high = np.mean(ndcg_moderate_high) if ndcg_moderate_high else 0
        di_hr = calculate_disparate_impact(hr_low, hr_moderate_high) if hr_moderate_high else np.inf
        gru_hr = calculate_group_recommender_unfairness(hr_low, hr_moderate_high)
        di_mrr = calculate_disparate_impact(mrr_low, mrr_moderate_high) if mrr_moderate_high else np.inf
        gru_mrr = calculate_group_recommender_unfairness(mrr_low, mrr_moderate_high)
        round_metrics[round_num + 1] = {
            "ndcg@k": ndcg,
            "hr@k": hr,
            "mrr@k": mrr,
            "DI_NDCG": di_ndcg,
            "GRU_NDCG": gru_ndcg,
            "ndcg_low": ndcg_low,
            "ndcg_moderate_high": ndcg_moderate_high,
            "CV": cv,
            "cv_low": cv_low_mean,
            "cv_moderate_high": cv_moderate_high_mean,
            "HR_LOW": hr_low_mean,
            "HR_MODERATE_HIGH": hr_moderate_high_mean,
            "MRR_LOW": mrr_low_mean,
            "MRR_MODERATE_HIGH": mrr_moderate_high_mean,
            "UCV_NDCG": ucv_ndcg,
            "UCV_HR": ucv_hr,
            "UCV_MRR": ucv_mrr,
            "DI_HR": di_hr,
            "GRU_HR": gru_hr,
            "DI_MRR": di_mrr,
            "GRU_MRR": gru_mrr
        }

        print(f"Metrics for round {round_num + 1}: {round_metrics[round_num + 1]}")


        if round_num == 0 and user_id_to_print in user_id_map:
            user_index = user_id_map[user_id_to_print]
            scores = model.predict(user_index, np.arange(interactions.shape[1]))
            top_items_indices = np.argsort(-scores)[:k]
            top_items_actual_ids = [train_user_item_matrix.columns[i] for i in top_items_indices]
            print(
                f"Top {k} recommendations for user {user_id_to_print}: {top_items_actual_ids}"
            )
        elif round_num == 0 and user_id_to_print not in user_id_map:
            print(
                f"User {user_id_to_print} not found in training data mapping. Skipping recommendations."
            )

    return round_metrics

interactions = csr_matrix(train_user_item_matrix.values)

round_results = evaluate_lightfm_multiple_rounds(interactions, test_df, df_modcloth_clean)

print("\nOverall Results:")
print(round_results)
# Out:
# Training Round 1...
# User 759686 not found in training data. Skipping evaluation.
# User 633700 not found in training data. Skipping evaluation.
# User 847972 not found in training data. Skipping evaluation.
# User 554236 not found in training data. Skipping evaluation.
# User 867579 not found in training data. Skipping evaluation.
# User 634356 not found in training data. Skipping evaluation.
# User 902075 not found in training data. Skipping evaluation.
# User 716249 not found in training data. Skipping evaluation.
# User 901112 not found in training data. Skipping evaluation.
# User 167789 not found in training data. Skipping evaluation.
# User 608089 not found in training data. Skipping evaluation.
# User 373717 not found in training data. Skipping evaluation.
# User 382674 not found in training data. Skipping evaluation.
# User 688594 not found in training data. Skipping evaluation.
# User 89438 not found in training data. Skipping evaluation.
# User 397724 not found in training data. Skipping evaluation.
# User 632710 not found in training data. Skipping evaluation.
# User 790847 not found in training data. Skipping evaluation.
# User 592065 not found in training data. Skipping evaluation.
# User 413844 not found in training data. Skipping evaluation.
# User 371335 not found in training data. Skipping evaluation.
# User 774863 not found in training data. Skipping evaluation.
# User 384270 not found in training data. Skipping evaluation.
# User 594557 not found in training data. Skipping evaluation.
# User 877323 not found in training data. Skipping evaluation.
# User 913139 not found in training data. Skipping evaluation.
# User 408008 not found in training data. Skipping evaluation.
# User 812798 not found in training data. Skipping evaluation.
# User 253950 not found in training data. Skipping evaluation.
# User 679431 not found in training data. Skipping evaluation.
# User 865033 not found in training data. Skipping evaluation.
# User 446201 not found in training data. Skipping evaluation.
# User 990283 not found in training data. Skipping evaluation.
# User 89500 not found in training data. Skipping evaluation.
# User 750543 not found in training data. Skipping evaluation.
# User 429031 not found in training data. Skipping evaluation.
# User 339 not found in training data. Skipping evaluation.
# User 288435 not found in training data. Skipping evaluation.
# User 41992 not found in training data. Skipping evaluation.
# User 523600 not found in training data. Skipping evaluation.
# User 281723 not found in training data. Skipping evaluation.
# User 775478 not found in training data. Skipping evaluation.
# User 610378 not found in training data. Skipping evaluation.
# User 610200 not found in training data. Skipping evaluation.
# User 532209 not found in training data. Skipping evaluation.
# User 444342 not found in training data. Skipping evaluation.
# User 401453 not found in training data. Skipping evaluation.
# User 344372 not found in training data. Skipping evaluation.
# User 785986 not found in training data. Skipping evaluation.
# User 979179 not found in training data. Skipping evaluation.
# User 909674 not found in training data. Skipping evaluation.
# User 499863 not found in training data. Skipping evaluation.
# User 780746 not found in training data. Skipping evaluation.
# User 281628 not found in training data. Skipping evaluation.
# User 732020 not found in training data. Skipping evaluation.
# User 398506 not found in training data. Skipping evaluation.
# User 518352 not found in training data. Skipping evaluation.
# User 771160 not found in training data. Skipping evaluation.
# User 209090 not found in training data. Skipping evaluation.
# User 28722 not found in training data. Skipping evaluation.
# User 390350 not found in training data. Skipping evaluation.
# User 729567 not found in training data. Skipping evaluation.
# User 557424 not found in training data. Skipping evaluation.
# User 291553 not found in training data. Skipping evaluation.
# User 649070 not found in training data. Skipping evaluation.
# User 120564 not found in training data. Skipping evaluation.
# User 74272 not found in training data. Skipping evaluation.
# User 972737 not found in training data. Skipping evaluation.
# User 179945 not found in training data. Skipping evaluation.
# User 145195 not found in training data. Skipping evaluation.
# User 494387 not found in training data. Skipping evaluation.
# User 477665 not found in training data. Skipping evaluation.
# User 133940 not found in training data. Skipping evaluation.
# User 902797 not found in training data. Skipping evaluation.
# User 178172 not found in training data. Skipping evaluation.
# User 22210 not found in training data. Skipping evaluation.
# User 712393 not found in training data. Skipping evaluation.
# User 846063 not found in training data. Skipping evaluation.
# User 609817 not found in training data. Skipping evaluation.
# User 973954 not found in training data. Skipping evaluation.
# User 121195 not found in training data. Skipping evaluation.
# User 731548 not found in training data. Skipping evaluation.
# User 903500 not found in training data. Skipping evaluation.
# User 502055 not found in training data. Skipping evaluation.
# User 364774 not found in training data. Skipping evaluation.
# User 237114 not found in training data. Skipping evaluation.
# User 845475 not found in training data. Skipping evaluation.
# User 107182 not found in training data. Skipping evaluation.
# User 923483 not found in training data. Skipping evaluation.
# User 322430 not found in training data. Skipping evaluation.
# User 556060 not found in training data. Skipping evaluation.
# User 797532 not found in training data. Skipping evaluation.
# User 453943 not found in training data. Skipping evaluation.
# User 214071 not found in training data. Skipping evaluation.
# User 561460 not found in training data. Skipping evaluation.
# User 257047 not found in training data. Skipping evaluation.
# User 803467 not found in training data. Skipping evaluation.
# User 184719 not found in training data. Skipping evaluation.
# User 638051 not found in training data. Skipping evaluation.
# User 3441 not found in training data. Skipping evaluation.
# User 554757 not found in training data. Skipping evaluation.
# User 954634 not found in training data. Skipping evaluation.
# User 185968 not found in training data. Skipping evaluation.
# User 551294 not found in training data. Skipping evaluation.
# User 854652 not found in training data. Skipping evaluation.
# User 785835 not found in training data. Skipping evaluation.
# User 403865 not found in training data. Skipping evaluation.
# User 344026 not found in training data. Skipping evaluation.
# User 584843 not found in training data. Skipping evaluation.
# User 656383 not found in training data. Skipping evaluation.
# User 404160 not found in training data. Skipping evaluation.
# User 628216 not found in training data. Skipping evaluation.
# User 304095 not found in training data. Skipping evaluation.
# User 727006 not found in training data. Skipping evaluation.
# User 433181 not found in training data. Skipping evaluation.
# User 868645 not found in training data. Skipping evaluation.
# User 243387 not found in training data. Skipping evaluation.
# User 593952 not found in training data. Skipping evaluation.
# User 132755 not found in training data. Skipping evaluation.
# User 732249 not found in training data. Skipping evaluation.
# User 792901 not found in training data. Skipping evaluation.
# User 950162 not found in training data. Skipping evaluation.
# User 711922 not found in training data. Skipping evaluation.
# User 547696 not found in training data. Skipping evaluation.
# User 722585 not found in training data. Skipping evaluation.
# User 370133 not found in training data. Skipping evaluation.
# User 854790 not found in training data. Skipping evaluation.
# User 507543 not found in training data. Skipping evaluation.
# User 859278 not found in training data. Skipping evaluation.
# User 682195 not found in training data. Skipping evaluation.
# User 66464 not found in training data. Skipping evaluation.
# User 773589 not found in training data. Skipping evaluation.
# User 973978 not found in training data. Skipping evaluation.
# User 249370 not found in training data. Skipping evaluation.
# User 421413 not found in training data. Skipping evaluation.
# User 257237 not found in training data. Skipping evaluation.
# User 597876 not found in training data. Skipping evaluation.
# User 724741 not found in training data. Skipping evaluation.
# User 176156 not found in training data. Skipping evaluation.
# User 531129 not found in training data. Skipping evaluation.
# User 188250 not found in training data. Skipping evaluation.
# User 465200 not found in training data. Skipping evaluation.
# User 836108 not found in training data. Skipping evaluation.
# User 863735 not found in training data. Skipping evaluation.
# User 323092 not found in training data. Skipping evaluation.
# User 595907 not found in training data. Skipping evaluation.
# User 496931 not found in training data. Skipping evaluation.
# User 205870 not found in training data. Skipping evaluation.
# User 615780 not found in training data. Skipping evaluation.
# User 252933 not found in training data. Skipping evaluation.
# User 688494 not found in training data. Skipping evaluation.
# User 709675 not found in training data. Skipping evaluation.
# User 376862 not found in training data. Skipping evaluation.
# User 374458 not found in training data. Skipping evaluation.
# User 781046 not found in training data. Skipping evaluation.
# User 244424 not found in training data. Skipping evaluation.
# User 770943 not found in training data. Skipping evaluation.
# User 999052 not found in training data. Skipping evaluation.
# User 330935 not found in training data. Skipping evaluation.
# User 144256 not found in training data. Skipping evaluation.
# User 237047 not found in training data. Skipping evaluation.
# User 666027 not found in training data. Skipping evaluation.
# User 792600 not found in training data. Skipping evaluation.
# User 575668 not found in training data. Skipping evaluation.
# User 287944 not found in training data. Skipping evaluation.
# User 583504 not found in training data. Skipping evaluation.
# User 712050 not found in training data. Skipping evaluation.
# User 185584 not found in training data. Skipping evaluation.
# User 729599 not found in training data. Skipping evaluation.
# User 58462 not found in training data. Skipping evaluation.
# User 265322 not found in training data. Skipping evaluation.
# User 746754 not found in training data. Skipping evaluation.
# User 872252 not found in training data. Skipping evaluation.
# User 171935 not found in training data. Skipping evaluation.
# User 513943 not found in training data. Skipping evaluation.
# User 37752 not found in training data. Skipping evaluation.
# User 287332 not found in training data. Skipping evaluation.
# User 929654 not found in training data. Skipping evaluation.
# User 553284 not found in training data. Skipping evaluation.
# User 144419 not found in training data. Skipping evaluation.
# User 285750 not found in training data. Skipping evaluation.
# User 972667 not found in training data. Skipping evaluation.
# User 901720 not found in training data. Skipping evaluation.
# User 410208 not found in training data. Skipping evaluation.
# User 999843 not found in training data. Skipping evaluation.
# User 685948 not found in training data. Skipping evaluation.
# User 449340 not found in training data. Skipping evaluation.
# User 923998 not found in training data. Skipping evaluation.
# User 303251 not found in training data. Skipping evaluation.
# User 80485 not found in training data. Skipping evaluation.
# User 495786 not found in training data. Skipping evaluation.
# User 454564 not found in training data. Skipping evaluation.
# User 71876 not found in training data. Skipping evaluation.
# User 77108 not found in training data. Skipping evaluation.
# User 736249 not found in training data. Skipping evaluation.
# User 856640 not found in training data. Skipping evaluation.
# User 753556 not found in training data. Skipping evaluation.
# User 990457 not found in training data. Skipping evaluation.
# User 314049 not found in training data. Skipping evaluation.
# User 481730 not found in training data. Skipping evaluation.
# User 93859 not found in training data. Skipping evaluation.
# User 935123 not found in training data. Skipping evaluation.
# User 891871 not found in training data. Skipping evaluation.
# User 209716 not found in training data. Skipping evaluation.
# User 950808 not found in training data. Skipping evaluation.
# User 831150 not found in training data. Skipping evaluation.
# User 216830 not found in training data. Skipping evaluation.
# User 766597 not found in training data. Skipping evaluation.
# User 958984 not found in training data. Skipping evaluation.
# User 806155 not found in training data. Skipping evaluation.
# User 907104 not found in training data. Skipping evaluation.
# User 683442 not found in training data. Skipping evaluation.
# User 512577 not found in training data. Skipping evaluation.
# User 954977 not found in training data. Skipping evaluation.
# User 320403 not found in training data. Skipping evaluation.
# User 391675 not found in training data. Skipping evaluation.
# User 989693 not found in training data. Skipping evaluation.
# User 566617 not found in training data. Skipping evaluation.
# User 134724 not found in training data. Skipping evaluation.
# User 972151 not found in training data. Skipping evaluation.
# User 807232 not found in training data. Skipping evaluation.
# User 752946 not found in training data. Skipping evaluation.
# User 256501 not found in training data. Skipping evaluation.
# User 952830 not found in training data. Skipping evaluation.
# User 771300 not found in training data. Skipping evaluation.
# User 88204 not found in training data. Skipping evaluation.
# User 583255 not found in training data. Skipping evaluation.
# User 683056 not found in training data. Skipping evaluation.
# User 662218 not found in training data. Skipping evaluation.
# User 580190 not found in training data. Skipping evaluation.
# User 433618 not found in training data. Skipping evaluation.
# User 81432 not found in training data. Skipping evaluation.
# User 66767 not found in training data. Skipping evaluation.
# User 716028 not found in training data. Skipping evaluation.
# User 901454 not found in training data. Skipping evaluation.
# User 613436 not found in training data. Skipping evaluation.
# User 881855 not found in training data. Skipping evaluation.
# User 798232 not found in training data. Skipping evaluation.
# User 92693 not found in training data. Skipping evaluation.
# User 343283 not found in training data. Skipping evaluation.
# User 578163 not found in training data. Skipping evaluation.
# User 89315 not found in training data. Skipping evaluation.
# User 693493 not found in training data. Skipping evaluation.
# User 207053 not found in training data. Skipping evaluation.
# User 281956 not found in training data. Skipping evaluation.
# User 153337 not found in training data. Skipping evaluation.
# User 118781 not found in training data. Skipping evaluation.
# User 14636 not found in training data. Skipping evaluation.
# User 104205 not found in training data. Skipping evaluation.
# User 810956 not found in training data. Skipping evaluation.
# User 52452 not found in training data. Skipping evaluation.
# User 489231 not found in training data. Skipping evaluation.
# User 770135 not found in training data. Skipping evaluation.
# User 279303 not found in training data. Skipping evaluation.
# User 347311 not found in training data. Skipping evaluation.
# User 672971 not found in training data. Skipping evaluation.
# User 515460 not found in training data. Skipping evaluation.
# User 31573 not found in training data. Skipping evaluation.
# User 852528 not found in training data. Skipping evaluation.
# User 392607 not found in training data. Skipping evaluation.
# User 780540 not found in training data. Skipping evaluation.
# User 711780 not found in training data. Skipping evaluation.
# User 953676 not found in training data. Skipping evaluation.
# User 649361 not found in training data. Skipping evaluation.
# User 500393 not found in training data. Skipping evaluation.
# User 405712 not found in training data. Skipping evaluation.
# User 867921 not found in training data. Skipping evaluation.
# User 431444 not found in training data. Skipping evaluation.
# User 219635 not found in training data. Skipping evaluation.
# User 336021 not found in training data. Skipping evaluation.
# User 943044 not found in training data. Skipping evaluation.
# User 574777 not found in training data. Skipping evaluation.
# User 845796 not found in training data. Skipping evaluation.
# User 391171 not found in training data. Skipping evaluation.
# User 774431 not found in training data. Skipping evaluation.
# User 816719 not found in training data. Skipping evaluation.
# User 282768 not found in training data. Skipping evaluation.
# User 843684 not found in training data. Skipping evaluation.
# User 469300 not found in training data. Skipping evaluation.
# User 215856 not found in training data. Skipping evaluation.
# User 266560 not found in training data. Skipping evaluation.
# User 412655 not found in training data. Skipping evaluation.
# User 33115 not found in training data. Skipping evaluation.
# User 468552 not found in training data. Skipping evaluation.
# User 634890 not found in training data. Skipping evaluation.
# User 890929 not found in training data. Skipping evaluation.
# User 365272 not found in training data. Skipping evaluation.
# User 12707 not found in training data. Skipping evaluation.
# User 245850 not found in training data. Skipping evaluation.
# User 103064 not found in training data. Skipping evaluation.
# User 526900 not found in training data. Skipping evaluation.
# User 538338 not found in training data. Skipping evaluation.
# User 112469 not found in training data. Skipping evaluation.
# User 915130 not found in training data. Skipping evaluation.
# User 642111 not found in training data. Skipping evaluation.
# User 151039 not found in training data. Skipping evaluation.
# User 592166 not found in training data. Skipping evaluation.
# User 254943 not found in training data. Skipping evaluation.
# User 943682 not found in training data. Skipping evaluation.
# User 958399 not found in training data. Skipping evaluation.
# User 1383 not found in training data. Skipping evaluation.
# User 240370 not found in training data. Skipping evaluation.
# User 113834 not found in training data. Skipping evaluation.
# User 545516 not found in training data. Skipping evaluation.
# User 633015 not found in training data. Skipping evaluation.
# User 515659 not found in training data. Skipping evaluation.
# User 335459 not found in training data. Skipping evaluation.
# User 145548 not found in training data. Skipping evaluation.
# User 464183 not found in training data. Skipping evaluation.
# User 495009 not found in training data. Skipping evaluation.
# User 89875 not found in training data. Skipping evaluation.
# User 597846 not found in training data. Skipping evaluation.
# User 448766 not found in training data. Skipping evaluation.
# User 727193 not found in training data. Skipping evaluation.
# User 459787 not found in training data. Skipping evaluation.
# User 821727 not found in training data. Skipping evaluation.
# User 312002 not found in training data. Skipping evaluation.
# User 734962 not found in training data. Skipping evaluation.
# User 163790 not found in training data. Skipping evaluation.
# Metrics for round 1: {'ndcg@k': np.float64(0.023029307258231557), 'hr@k': np.float64(0.04809619238476954), 'mrr@k': np.float64(0.014946559786239147), 'DI_NDCG': np.float64(1.4778814623636856), 'GRU_NDCG': np.float64(0.009581807245977642), 'ndcg_low': np.float64(0.029632401379896006), 'ndcg_moderate_high': np.float64(0.020050594133918364), 'CV': np.float64(0.09619238476953908), 'cv_low': np.float64(0.11281224818694602), 'cv_moderate_high': np.float64(0.08869501999272991), 'HR_LOW': np.float64(0.05640612409347301), 'HR_MODERATE_HIGH': np.float64(0.044347509996364956), 'MRR_LOW': np.float64(0.02078968573730862), 'MRR_MODERATE_HIGH': np.float64(0.012310674906094754), 'UCV_NDCG': np.float64(4.438319338649441), 'UCV_HR': np.float64(4.366083550530732), 'UCV_MRR': np.float64(4.6124678917020905), 'DI_HR': np.float64(1.271911863779871), 'GRU_HR': np.float64(0.012058614097108053), 'DI_MRR': np.float64(1.6887527203740949), 'GRU_MRR': np.float64(0.008479010831213865)}
# User 55 not found in training data mapping. Skipping recommendations.
# Training Round 2...
# User 759686 not found in training data. Skipping evaluation.
# User 633700 not found in training data. Skipping evaluation.
# User 847972 not found in training data. Skipping evaluation.
# User 554236 not found in training data. Skipping evaluation.
# User 867579 not found in training data. Skipping evaluation.
# User 634356 not found in training data. Skipping evaluation.
# User 902075 not found in training data. Skipping evaluation.
# User 716249 not found in training data. Skipping evaluation.
# User 901112 not found in training data. Skipping evaluation.
# User 167789 not found in training data. Skipping evaluation.
# User 608089 not found in training data. Skipping evaluation.
# User 373717 not found in training data. Skipping evaluation.
# User 382674 not found in training data. Skipping evaluation.
# User 688594 not found in training data. Skipping evaluation.
# User 89438 not found in training data. Skipping evaluation.
# User 397724 not found in training data. Skipping evaluation.
# User 632710 not found in training data. Skipping evaluation.
# User 790847 not found in training data. Skipping evaluation.
# User 592065 not found in training data. Skipping evaluation.
# User 413844 not found in training data. Skipping evaluation.
# User 371335 not found in training data. Skipping evaluation.
# User 774863 not found in training data. Skipping evaluation.
# User 384270 not found in training data. Skipping evaluation.
# User 594557 not found in training data. Skipping evaluation.
# User 877323 not found in training data. Skipping evaluation.
# User 913139 not found in training data. Skipping evaluation.
# User 408008 not found in training data. Skipping evaluation.
# User 812798 not found in training data. Skipping evaluation.
# User 253950 not found in training data. Skipping evaluation.
# User 679431 not found in training data. Skipping evaluation.
# User 865033 not found in training data. Skipping evaluation.
# User 446201 not found in training data. Skipping evaluation.
# User 990283 not found in training data. Skipping evaluation.
# User 89500 not found in training data. Skipping evaluation.
# User 750543 not found in training data. Skipping evaluation.
# User 429031 not found in training data. Skipping evaluation.
# User 339 not found in training data. Skipping evaluation.
# User 288435 not found in training data. Skipping evaluation.
# User 41992 not found in training data. Skipping evaluation.
# User 523600 not found in training data. Skipping evaluation.
# User 281723 not found in training data. Skipping evaluation.
# User 775478 not found in training data. Skipping evaluation.
# User 610378 not found in training data. Skipping evaluation.
# User 610200 not found in training data. Skipping evaluation.
# User 532209 not found in training data. Skipping evaluation.
# User 444342 not found in training data. Skipping evaluation.
# User 401453 not found in training data. Skipping evaluation.
# User 344372 not found in training data. Skipping evaluation.
# User 785986 not found in training data. Skipping evaluation.
# User 979179 not found in training data. Skipping evaluation.
# User 909674 not found in training data. Skipping evaluation.
# User 499863 not found in training data. Skipping evaluation.
# User 780746 not found in training data. Skipping evaluation.
# User 281628 not found in training data. Skipping evaluation.
# User 732020 not found in training data. Skipping evaluation.
# User 398506 not found in training data. Skipping evaluation.
# User 518352 not found in training data. Skipping evaluation.
# User 771160 not found in training data. Skipping evaluation.
# User 209090 not found in training data. Skipping evaluation.
# User 28722 not found in training data. Skipping evaluation.
# User 390350 not found in training data. Skipping evaluation.
# User 729567 not found in training data. Skipping evaluation.
# User 557424 not found in training data. Skipping evaluation.
# User 291553 not found in training data. Skipping evaluation.
# User 649070 not found in training data. Skipping evaluation.
# User 120564 not found in training data. Skipping evaluation.
# User 74272 not found in training data. Skipping evaluation.
# User 972737 not found in training data. Skipping evaluation.
# User 179945 not found in training data. Skipping evaluation.
# User 145195 not found in training data. Skipping evaluation.
# User 494387 not found in training data. Skipping evaluation.
# User 477665 not found in training data. Skipping evaluation.
# User 133940 not found in training data. Skipping evaluation.
# User 902797 not found in training data. Skipping evaluation.
# User 178172 not found in training data. Skipping evaluation.
# User 22210 not found in training data. Skipping evaluation.
# User 712393 not found in training data. Skipping evaluation.
# User 846063 not found in training data. Skipping evaluation.
# User 609817 not found in training data. Skipping evaluation.
# User 973954 not found in training data. Skipping evaluation.
# User 121195 not found in training data. Skipping evaluation.
# User 731548 not found in training data. Skipping evaluation.
# User 903500 not found in training data. Skipping evaluation.
# User 502055 not found in training data. Skipping evaluation.
# User 364774 not found in training data. Skipping evaluation.
# User 237114 not found in training data. Skipping evaluation.
# User 845475 not found in training data. Skipping evaluation.
# User 107182 not found in training data. Skipping evaluation.
# User 923483 not found in training data. Skipping evaluation.
# User 322430 not found in training data. Skipping evaluation.
# User 556060 not found in training data. Skipping evaluation.
# User 797532 not found in training data. Skipping evaluation.
# User 453943 not found in training data. Skipping evaluation.
# User 214071 not found in training data. Skipping evaluation.
# User 561460 not found in training data. Skipping evaluation.
# User 257047 not found in training data. Skipping evaluation.
# User 803467 not found in training data. Skipping evaluation.
# User 184719 not found in training data. Skipping evaluation.
# User 638051 not found in training data. Skipping evaluation.
# User 3441 not found in training data. Skipping evaluation.
# User 554757 not found in training data. Skipping evaluation.
# User 954634 not found in training data. Skipping evaluation.
# User 185968 not found in training data. Skipping evaluation.
# User 551294 not found in training data. Skipping evaluation.
# User 854652 not found in training data. Skipping evaluation.
# User 785835 not found in training data. Skipping evaluation.
# User 403865 not found in training data. Skipping evaluation.
# User 344026 not found in training data. Skipping evaluation.
# User 584843 not found in training data. Skipping evaluation.
# User 656383 not found in training data. Skipping evaluation.
# User 404160 not found in training data. Skipping evaluation.
# User 628216 not found in training data. Skipping evaluation.
# User 304095 not found in training data. Skipping evaluation.
# User 727006 not found in training data. Skipping evaluation.
# User 433181 not found in training data. Skipping evaluation.
# User 868645 not found in training data. Skipping evaluation.
# User 243387 not found in training data. Skipping evaluation.
# User 593952 not found in training data. Skipping evaluation.
# User 132755 not found in training data. Skipping evaluation.
# User 732249 not found in training data. Skipping evaluation.
# User 792901 not found in training data. Skipping evaluation.
# User 950162 not found in training data. Skipping evaluation.
# User 711922 not found in training data. Skipping evaluation.
# User 547696 not found in training data. Skipping evaluation.
# User 722585 not found in training data. Skipping evaluation.
# User 370133 not found in training data. Skipping evaluation.
# User 854790 not found in training data. Skipping evaluation.
# User 507543 not found in training data. Skipping evaluation.
# User 859278 not found in training data. Skipping evaluation.
# User 682195 not found in training data. Skipping evaluation.
# User 66464 not found in training data. Skipping evaluation.
# User 773589 not found in training data. Skipping evaluation.
# User 973978 not found in training data. Skipping evaluation.
# User 249370 not found in training data. Skipping evaluation.
# User 421413 not found in training data. Skipping evaluation.
# User 257237 not found in training data. Skipping evaluation.
# User 597876 not found in training data. Skipping evaluation.
# User 724741 not found in training data. Skipping evaluation.
# User 176156 not found in training data. Skipping evaluation.
# User 531129 not found in training data. Skipping evaluation.
# User 188250 not found in training data. Skipping evaluation.
# User 465200 not found in training data. Skipping evaluation.
# User 836108 not found in training data. Skipping evaluation.
# User 863735 not found in training data. Skipping evaluation.
# User 323092 not found in training data. Skipping evaluation.
# User 595907 not found in training data. Skipping evaluation.
# User 496931 not found in training data. Skipping evaluation.
# User 205870 not found in training data. Skipping evaluation.
# User 615780 not found in training data. Skipping evaluation.
# User 252933 not found in training data. Skipping evaluation.
# User 688494 not found in training data. Skipping evaluation.
# User 709675 not found in training data. Skipping evaluation.
# User 376862 not found in training data. Skipping evaluation.
# User 374458 not found in training data. Skipping evaluation.
# User 781046 not found in training data. Skipping evaluation.
# User 244424 not found in training data. Skipping evaluation.
# User 770943 not found in training data. Skipping evaluation.
# User 999052 not found in training data. Skipping evaluation.
# User 330935 not found in training data. Skipping evaluation.
# User 144256 not found in training data. Skipping evaluation.
# User 237047 not found in training data. Skipping evaluation.
# User 666027 not found in training data. Skipping evaluation.
# User 792600 not found in training data. Skipping evaluation.
# User 575668 not found in training data. Skipping evaluation.
# User 287944 not found in training data. Skipping evaluation.
# User 583504 not found in training data. Skipping evaluation.
# User 712050 not found in training data. Skipping evaluation.
# User 185584 not found in training data. Skipping evaluation.
# User 729599 not found in training data. Skipping evaluation.
# User 58462 not found in training data. Skipping evaluation.
# User 265322 not found in training data. Skipping evaluation.
# User 746754 not found in training data. Skipping evaluation.
# User 872252 not found in training data. Skipping evaluation.
# User 171935 not found in training data. Skipping evaluation.
# User 513943 not found in training data. Skipping evaluation.
# User 37752 not found in training data. Skipping evaluation.
# User 287332 not found in training data. Skipping evaluation.
# User 929654 not found in training data. Skipping evaluation.
# User 553284 not found in training data. Skipping evaluation.
# User 144419 not found in training data. Skipping evaluation.
# User 285750 not found in training data. Skipping evaluation.
# User 972667 not found in training data. Skipping evaluation.
# User 901720 not found in training data. Skipping evaluation.
# User 410208 not found in training data. Skipping evaluation.
# User 999843 not found in training data. Skipping evaluation.
# User 685948 not found in training data. Skipping evaluation.
# User 449340 not found in training data. Skipping evaluation.
# User 923998 not found in training data. Skipping evaluation.
# User 303251 not found in training data. Skipping evaluation.
# User 80485 not found in training data. Skipping evaluation.
# User 495786 not found in training data. Skipping evaluation.
# User 454564 not found in training data. Skipping evaluation.
# User 71876 not found in training data. Skipping evaluation.
# User 77108 not found in training data. Skipping evaluation.
# User 736249 not found in training data. Skipping evaluation.
# User 856640 not found in training data. Skipping evaluation.
# User 753556 not found in training data. Skipping evaluation.
# User 990457 not found in training data. Skipping evaluation.
# User 314049 not found in training data. Skipping evaluation.
# User 481730 not found in training data. Skipping evaluation.
# User 93859 not found in training data. Skipping evaluation.
# User 935123 not found in training data. Skipping evaluation.
# User 891871 not found in training data. Skipping evaluation.
# User 209716 not found in training data. Skipping evaluation.
# User 950808 not found in training data. Skipping evaluation.
# User 831150 not found in training data. Skipping evaluation.
# User 216830 not found in training data. Skipping evaluation.
# User 766597 not found in training data. Skipping evaluation.
# User 958984 not found in training data. Skipping evaluation.
# User 806155 not found in training data. Skipping evaluation.
# User 907104 not found in training data. Skipping evaluation.
# User 683442 not found in training data. Skipping evaluation.
# User 512577 not found in training data. Skipping evaluation.
# User 954977 not found in training data. Skipping evaluation.
# User 320403 not found in training data. Skipping evaluation.
# User 391675 not found in training data. Skipping evaluation.
# User 989693 not found in training data. Skipping evaluation.
# User 566617 not found in training data. Skipping evaluation.
# User 134724 not found in training data. Skipping evaluation.
# User 972151 not found in training data. Skipping evaluation.
# User 807232 not found in training data. Skipping evaluation.
# User 752946 not found in training data. Skipping evaluation.
# User 256501 not found in training data. Skipping evaluation.
# User 952830 not found in training data. Skipping evaluation.
# User 771300 not found in training data. Skipping evaluation.
# User 88204 not found in training data. Skipping evaluation.
# User 583255 not found in training data. Skipping evaluation.
# User 683056 not found in training data. Skipping evaluation.
# User 662218 not found in training data. Skipping evaluation.
# User 580190 not found in training data. Skipping evaluation.
# User 433618 not found in training data. Skipping evaluation.
# User 81432 not found in training data. Skipping evaluation.
# User 66767 not found in training data. Skipping evaluation.
# User 716028 not found in training data. Skipping evaluation.
# User 901454 not found in training data. Skipping evaluation.
# User 613436 not found in training data. Skipping evaluation.
# User 881855 not found in training data. Skipping evaluation.
# User 798232 not found in training data. Skipping evaluation.
# User 92693 not found in training data. Skipping evaluation.
# User 343283 not found in training data. Skipping evaluation.
# User 578163 not found in training data. Skipping evaluation.
# User 89315 not found in training data. Skipping evaluation.
# User 693493 not found in training data. Skipping evaluation.
# User 207053 not found in training data. Skipping evaluation.
# User 281956 not found in training data. Skipping evaluation.
# User 153337 not found in training data. Skipping evaluation.
# User 118781 not found in training data. Skipping evaluation.
# User 14636 not found in training data. Skipping evaluation.
# User 104205 not found in training data. Skipping evaluation.
# User 810956 not found in training data. Skipping evaluation.
# User 52452 not found in training data. Skipping evaluation.
# User 489231 not found in training data. Skipping evaluation.
# User 770135 not found in training data. Skipping evaluation.
# User 279303 not found in training data. Skipping evaluation.
# User 347311 not found in training data. Skipping evaluation.
# User 672971 not found in training data. Skipping evaluation.
# User 515460 not found in training data. Skipping evaluation.
# User 31573 not found in training data. Skipping evaluation.
# User 852528 not found in training data. Skipping evaluation.
# User 392607 not found in training data. Skipping evaluation.
# User 780540 not found in training data. Skipping evaluation.
# User 711780 not found in training data. Skipping evaluation.
# User 953676 not found in training data. Skipping evaluation.
# User 649361 not found in training data. Skipping evaluation.
# User 500393 not found in training data. Skipping evaluation.
# User 405712 not found in training data. Skipping evaluation.
# User 867921 not found in training data. Skipping evaluation.
# User 431444 not found in training data. Skipping evaluation.
# User 219635 not found in training data. Skipping evaluation.
# User 336021 not found in training data. Skipping evaluation.
# User 943044 not found in training data. Skipping evaluation.
# User 574777 not found in training data. Skipping evaluation.
# User 845796 not found in training data. Skipping evaluation.
# User 391171 not found in training data. Skipping evaluation.
# User 774431 not found in training data. Skipping evaluation.
# User 816719 not found in training data. Skipping evaluation.
# User 282768 not found in training data. Skipping evaluation.
# User 843684 not found in training data. Skipping evaluation.
# User 469300 not found in training data. Skipping evaluation.
# User 215856 not found in training data. Skipping evaluation.
# User 266560 not found in training data. Skipping evaluation.
# User 412655 not found in training data. Skipping evaluation.
# User 33115 not found in training data. Skipping evaluation.
# User 468552 not found in training data. Skipping evaluation.
# User 634890 not found in training data. Skipping evaluation.
# User 890929 not found in training data. Skipping evaluation.
# User 365272 not found in training data. Skipping evaluation.
# User 12707 not found in training data. Skipping evaluation.
# User 245850 not found in training data. Skipping evaluation.
# User 103064 not found in training data. Skipping evaluation.
# User 526900 not found in training data. Skipping evaluation.
# User 538338 not found in training data. Skipping evaluation.
# User 112469 not found in training data. Skipping evaluation.
# User 915130 not found in training data. Skipping evaluation.
# User 642111 not found in training data. Skipping evaluation.
# User 151039 not found in training data. Skipping evaluation.
# User 592166 not found in training data. Skipping evaluation.
# User 254943 not found in training data. Skipping evaluation.
# User 943682 not found in training data. Skipping evaluation.
# User 958399 not found in training data. Skipping evaluation.
# User 1383 not found in training data. Skipping evaluation.
# User 240370 not found in training data. Skipping evaluation.
# User 113834 not found in training data. Skipping evaluation.
# User 545516 not found in training data. Skipping evaluation.
# User 633015 not found in training data. Skipping evaluation.
# User 515659 not found in training data. Skipping evaluation.
# User 335459 not found in training data. Skipping evaluation.
# User 145548 not found in training data. Skipping evaluation.
# User 464183 not found in training data. Skipping evaluation.
# User 495009 not found in training data. Skipping evaluation.
# User 89875 not found in training data. Skipping evaluation.
# User 597846 not found in training data. Skipping evaluation.
# User 448766 not found in training data. Skipping evaluation.
# User 727193 not found in training data. Skipping evaluation.
# User 459787 not found in training data. Skipping evaluation.
# User 821727 not found in training data. Skipping evaluation.
# User 312002 not found in training data. Skipping evaluation.
# User 734962 not found in training data. Skipping evaluation.
# User 163790 not found in training data. Skipping evaluation.
# Metrics for round 2: {'ndcg@k': np.float64(0.021655243444802148), 'hr@k': np.float64(0.04433867735470942), 'mrr@k': np.float64(0.014307782231128923), 'DI_NDCG': np.float64(1.611799830483096), 'GRU_NDCG': np.float64(0.011131550442012954), 'ndcg_low': np.float64(0.029326309393193337), 'ndcg_moderate_high': np.float64(0.018194758951180383), 'CV': np.float64(0.08867735470941884), 'cv_low': np.float64(0.11281224818694602), 'cv_moderate_high': np.float64(0.07778989458378771), 'HR_LOW': np.float64(0.05640612409347301), 'HR_MODERATE_HIGH': np.float64(0.038894947291893855), 'MRR_LOW': np.float64(0.020413644910018798), 'MRR_MODERATE_HIGH': np.float64(0.011553374530473767), 'UCV_NDCG': np.float64(4.622166768507222), 'UCV_HR': np.float64(4.530500620725936), 'UCV_MRR': np.float64(4.8448774469366835), 'DI_HR': np.float64(1.4502172652443388), 'GRU_HR': np.float64(0.017511176801579154), 'DI_MRR': np.float64(1.7668989139211866), 'GRU_MRR': np.float64(0.00886027037954503)}
# Training Round 3...
# User 759686 not found in training data. Skipping evaluation.
# User 633700 not found in training data. Skipping evaluation.
# User 847972 not found in training data. Skipping evaluation.
# User 554236 not found in training data. Skipping evaluation.
# User 867579 not found in training data. Skipping evaluation.
# User 634356 not found in training data. Skipping evaluation.
# User 902075 not found in training data. Skipping evaluation.
# User 716249 not found in training data. Skipping evaluation.
# User 901112 not found in training data. Skipping evaluation.
# User 167789 not found in training data. Skipping evaluation.
# User 608089 not found in training data. Skipping evaluation.
# User 373717 not found in training data. Skipping evaluation.
# User 382674 not found in training data. Skipping evaluation.
# User 688594 not found in training data. Skipping evaluation.
# User 89438 not found in training data. Skipping evaluation.
# User 397724 not found in training data. Skipping evaluation.
# User 632710 not found in training data. Skipping evaluation.
# User 790847 not found in training data. Skipping evaluation.
# User 592065 not found in training data. Skipping evaluation.
# User 413844 not found in training data. Skipping evaluation.
# User 371335 not found in training data. Skipping evaluation.
# User 774863 not found in training data. Skipping evaluation.
# User 384270 not found in training data. Skipping evaluation.
# User 594557 not found in training data. Skipping evaluation.
# User 877323 not found in training data. Skipping evaluation.
# User 913139 not found in training data. Skipping evaluation.
# User 408008 not found in training data. Skipping evaluation.
# User 812798 not found in training data. Skipping evaluation.
# User 253950 not found in training data. Skipping evaluation.
# User 679431 not found in training data. Skipping evaluation.
# User 865033 not found in training data. Skipping evaluation.
# User 446201 not found in training data. Skipping evaluation.
# User 990283 not found in training data. Skipping evaluation.
# User 89500 not found in training data. Skipping evaluation.
# User 750543 not found in training data. Skipping evaluation.
# User 429031 not found in training data. Skipping evaluation.
# User 339 not found in training data. Skipping evaluation.
# User 288435 not found in training data. Skipping evaluation.
# User 41992 not found in training data. Skipping evaluation.
# User 523600 not found in training data. Skipping evaluation.
# User 281723 not found in training data. Skipping evaluation.
# User 775478 not found in training data. Skipping evaluation.
# User 610378 not found in training data. Skipping evaluation.
# User 610200 not found in training data. Skipping evaluation.
# User 532209 not found in training data. Skipping evaluation.
# User 444342 not found in training data. Skipping evaluation.
# User 401453 not found in training data. Skipping evaluation.
# User 344372 not found in training data. Skipping evaluation.
# User 785986 not found in training data. Skipping evaluation.
# User 979179 not found in training data. Skipping evaluation.
# User 909674 not found in training data. Skipping evaluation.
# User 499863 not found in training data. Skipping evaluation.
# User 780746 not found in training data. Skipping evaluation.
# User 281628 not found in training data. Skipping evaluation.
# User 732020 not found in training data. Skipping evaluation.
# User 398506 not found in training data. Skipping evaluation.
# User 518352 not found in training data. Skipping evaluation.
# User 771160 not found in training data. Skipping evaluation.
# User 209090 not found in training data. Skipping evaluation.
# User 28722 not found in training data. Skipping evaluation.
# User 390350 not found in training data. Skipping evaluation.
# User 729567 not found in training data. Skipping evaluation.
# User 557424 not found in training data. Skipping evaluation.
# User 291553 not found in training data. Skipping evaluation.
# User 649070 not found in training data. Skipping evaluation.
# User 120564 not found in training data. Skipping evaluation.
# User 74272 not found in training data. Skipping evaluation.
# User 972737 not found in training data. Skipping evaluation.
# User 179945 not found in training data. Skipping evaluation.
# User 145195 not found in training data. Skipping evaluation.
# User 494387 not found in training data. Skipping evaluation.
# User 477665 not found in training data. Skipping evaluation.
# User 133940 not found in training data. Skipping evaluation.
# User 902797 not found in training data. Skipping evaluation.
# User 178172 not found in training data. Skipping evaluation.
# User 22210 not found in training data. Skipping evaluation.
# User 712393 not found in training data. Skipping evaluation.
# User 846063 not found in training data. Skipping evaluation.
# User 609817 not found in training data. Skipping evaluation.
# User 973954 not found in training data. Skipping evaluation.
# User 121195 not found in training data. Skipping evaluation.
# User 731548 not found in training data. Skipping evaluation.
# User 903500 not found in training data. Skipping evaluation.
# User 502055 not found in training data. Skipping evaluation.
# User 364774 not found in training data. Skipping evaluation.
# User 237114 not found in training data. Skipping evaluation.
# User 845475 not found in training data. Skipping evaluation.
# User 107182 not found in training data. Skipping evaluation.
# User 923483 not found in training data. Skipping evaluation.
# User 322430 not found in training data. Skipping evaluation.
# User 556060 not found in training data. Skipping evaluation.
# User 797532 not found in training data. Skipping evaluation.
# User 453943 not found in training data. Skipping evaluation.
# User 214071 not found in training data. Skipping evaluation.
# User 561460 not found in training data. Skipping evaluation.
# User 257047 not found in training data. Skipping evaluation.
# User 803467 not found in training data. Skipping evaluation.
# User 184719 not found in training data. Skipping evaluation.
# User 638051 not found in training data. Skipping evaluation.
# User 3441 not found in training data. Skipping evaluation.
# User 554757 not found in training data. Skipping evaluation.
# User 954634 not found in training data. Skipping evaluation.
# User 185968 not found in training data. Skipping evaluation.
# User 551294 not found in training data. Skipping evaluation.
# User 854652 not found in training data. Skipping evaluation.
# User 785835 not found in training data. Skipping evaluation.
# User 403865 not found in training data. Skipping evaluation.
# User 344026 not found in training data. Skipping evaluation.
# User 584843 not found in training data. Skipping evaluation.
# User 656383 not found in training data. Skipping evaluation.
# User 404160 not found in training data. Skipping evaluation.
# User 628216 not found in training data. Skipping evaluation.
# User 304095 not found in training data. Skipping evaluation.
# User 727006 not found in training data. Skipping evaluation.
# User 433181 not found in training data. Skipping evaluation.
# User 868645 not found in training data. Skipping evaluation.
# ...
# User 792901 not found in training data. Skipping evaluation.
# User 950162 not found in training data. Skipping evaluation.
# User 711922 not found in training data. Skipping evaluation.
# User 547696 not found in training data. Skipping evaluation.
# User 722585 not found in training data. Skipping evaluation.
# User 370133 not found in training data. Skipping evaluation.
# User 854790 not found in training data. Skipping evaluation.
# User 507543 not found in training data. Skipping evaluation.
# User 859278 not found in training data. Skipping evaluation.
# User 682195 not found in training data. Skipping evaluation.
# User 66464 not found in training data. Skipping evaluation.
# User 773589 not found in training data. Skipping evaluation.
# User 973978 not found in training data. Skipping evaluation.
# User 249370 not found in training data. Skipping evaluation.
# User 421413 not found in training data. Skipping evaluation.
# User 257237 not found in training data. Skipping evaluation.
# User 597876 not found in training data. Skipping evaluation.
# User 724741 not found in training data. Skipping evaluation.
# User 176156 not found in training data. Skipping evaluation.
# User 531129 not found in training data. Skipping evaluation.
# User 188250 not found in training data. Skipping evaluation.
# User 465200 not found in training data. Skipping evaluation.
# User 836108 not found in training data. Skipping evaluation.
# User 863735 not found in training data. Skipping evaluation.
# User 323092 not found in training data. Skipping evaluation.
# User 595907 not found in training data. Skipping evaluation.
# User 496931 not found in training data. Skipping evaluation.
# User 205870 not found in training data. Skipping evaluation.
# User 615780 not found in training data. Skipping evaluation.
# User 252933 not found in training data. Skipping evaluation.
# User 688494 not found in training data. Skipping evaluation.
# User 709675 not found in training data. Skipping evaluation.
# User 376862 not found in training data. Skipping evaluation.
# User 374458 not found in training data. Skipping evaluation.
# User 781046 not found in training data. Skipping evaluation.
# User 244424 not found in training data. Skipping evaluation.
# User 770943 not found in training data. Skipping evaluation.
# User 999052 not found in training data. Skipping evaluation.
# User 330935 not found in training data. Skipping evaluation.
# User 144256 not found in training data. Skipping evaluation.
# User 237047 not found in training data. Skipping evaluation.
# User 666027 not found in training data. Skipping evaluation.
# User 792600 not found in training data. Skipping evaluation.
# User 575668 not found in training data. Skipping evaluation.
# User 287944 not found in training data. Skipping evaluation.
# User 583504 not found in training data. Skipping evaluation.
# User 712050 not found in training data. Skipping evaluation.
# User 185584 not found in training data. Skipping evaluation.
# User 729599 not found in training data. Skipping evaluation.
# User 58462 not found in training data. Skipping evaluation.
# User 265322 not found in training data. Skipping evaluation.
# User 746754 not found in training data. Skipping evaluation.
# User 872252 not found in training data. Skipping evaluation.
# User 171935 not found in training data. Skipping evaluation.
# User 513943 not found in training data. Skipping evaluation.
# User 37752 not found in training data. Skipping evaluation.
# User 287332 not found in training data. Skipping evaluation.
# User 929654 not found in training data. Skipping evaluation.
# User 553284 not found in training data. Skipping evaluation.
# User 144419 not found in training data. Skipping evaluation.
# User 285750 not found in training data. Skipping evaluation.
# User 972667 not found in training data. Skipping evaluation.
# User 901720 not found in training data. Skipping evaluation.
# User 410208 not found in training data. Skipping evaluation.
# User 999843 not found in training data. Skipping evaluation.
# User 685948 not found in training data. Skipping evaluation.
# User 449340 not found in training data. Skipping evaluation.
# User 923998 not found in training data. Skipping evaluation.
# User 303251 not found in training data. Skipping evaluation.
# User 80485 not found in training data. Skipping evaluation.
# User 495786 not found in training data. Skipping evaluation.
# User 454564 not found in training data. Skipping evaluation.
# User 71876 not found in training data. Skipping evaluation.
# User 77108 not found in training data. Skipping evaluation.
# User 736249 not found in training data. Skipping evaluation.
# User 856640 not found in training data. Skipping evaluation.
# User 753556 not found in training data. Skipping evaluation.
# User 990457 not found in training data. Skipping evaluation.
# User 314049 not found in training data. Skipping evaluation.
# User 481730 not found in training data. Skipping evaluation.
# User 93859 not found in training data. Skipping evaluation.
# User 935123 not found in training data. Skipping evaluation.
# User 891871 not found in training data. Skipping evaluation.
# User 209716 not found in training data. Skipping evaluation.
# User 950808 not found in training data. Skipping evaluation.
# User 831150 not found in training data. Skipping evaluation.
# User 216830 not found in training data. Skipping evaluation.
# User 766597 not found in training data. Skipping evaluation.
# User 958984 not found in training data. Skipping evaluation.
# User 806155 not found in training data. Skipping evaluation.
# User 907104 not found in training data. Skipping evaluation.
# User 683442 not found in training data. Skipping evaluation.
# User 512577 not found in training data. Skipping evaluation.
# User 954977 not found in training data. Skipping evaluation.
# User 320403 not found in training data. Skipping evaluation.
# User 391675 not found in training data. Skipping evaluation.
# User 989693 not found in training data. Skipping evaluation.
# User 566617 not found in training data. Skipping evaluation.
# User 134724 not found in training data. Skipping evaluation.
# User 972151 not found in training data. Skipping evaluation.
# User 807232 not found in training data. Skipping evaluation.
# User 752946 not found in training data. Skipping evaluation.
# User 256501 not found in training data. Skipping evaluation.
# User 952830 not found in training data. Skipping evaluation.
# User 771300 not found in training data. Skipping evaluation.
# User 88204 not found in training data. Skipping evaluation.
# User 583255 not found in training data. Skipping evaluation.
# User 683056 not found in training data. Skipping evaluation.
# User 662218 not found in training data. Skipping evaluation.
# User 580190 not found in training data. Skipping evaluation.
# User 433618 not found in training data. Skipping evaluation.
# User 81432 not found in training data. Skipping evaluation.
# User 66767 not found in training data. Skipping evaluation.
# User 716028 not found in training data. Skipping evaluation.
# User 901454 not found in training data. Skipping evaluation.
# User 613436 not found in training data. Skipping evaluation.
# User 881855 not found in training data. Skipping evaluation.
# User 798232 not found in training data. Skipping evaluation.
# User 92693 not found in training data. Skipping evaluation.
# User 343283 not found in training data. Skipping evaluation.
# User 578163 not found in training data. Skipping evaluation.
# User 89315 not found in training data. Skipping evaluation.
# User 693493 not found in training data. Skipping evaluation.
# User 207053 not found in training data. Skipping evaluation.
# User 281956 not found in training data. Skipping evaluation.
# User 153337 not found in training data. Skipping evaluation.
# User 118781 not found in training data. Skipping evaluation.
# User 14636 not found in training data. Skipping evaluation.
# User 104205 not found in training data. Skipping evaluation.
# User 810956 not found in training data. Skipping evaluation.
# User 52452 not found in training data. Skipping evaluation.
# User 489231 not found in training data. Skipping evaluation.
# User 770135 not found in training data. Skipping evaluation.
# User 279303 not found in training data. Skipping evaluation.
# User 347311 not found in training data. Skipping evaluation.
# User 672971 not found in training data. Skipping evaluation.
# User 515460 not found in training data. Skipping evaluation.
# User 31573 not found in training data. Skipping evaluation.
# User 852528 not found in training data. Skipping evaluation.
# User 392607 not found in training data. Skipping evaluation.
# User 780540 not found in training data. Skipping evaluation.
# User 711780 not found in training data. Skipping evaluation.
# User 953676 not found in training data. Skipping evaluation.
# User 649361 not found in training data. Skipping evaluation.
# User 500393 not found in training data. Skipping evaluation.
# User 405712 not found in training data. Skipping evaluation.
# User 867921 not found in training data. Skipping evaluation.
# User 431444 not found in training data. Skipping evaluation.
# User 219635 not found in training data. Skipping evaluation.
# User 336021 not found in training data. Skipping evaluation.
# User 943044 not found in training data. Skipping evaluation.
# User 574777 not found in training data. Skipping evaluation.
# User 845796 not found in training data. Skipping evaluation.
# User 391171 not found in training data. Skipping evaluation.
# User 774431 not found in training data. Skipping evaluation.
# User 816719 not found in training data. Skipping evaluation.
# User 282768 not found in training data. Skipping evaluation.
# User 843684 not found in training data. Skipping evaluation.
# User 469300 not found in training data. Skipping evaluation.
# User 215856 not found in training data. Skipping evaluation.
# User 266560 not found in training data. Skipping evaluation.
# User 412655 not found in training data. Skipping evaluation.
# User 33115 not found in training data. Skipping evaluation.
# User 468552 not found in training data. Skipping evaluation.
# User 634890 not found in training data. Skipping evaluation.
# User 890929 not found in training data. Skipping evaluation.
# User 365272 not found in training data. Skipping evaluation.
# User 12707 not found in training data. Skipping evaluation.
# User 245850 not found in training data. Skipping evaluation.
# User 103064 not found in training data. Skipping evaluation.
# User 526900 not found in training data. Skipping evaluation.
# User 538338 not found in training data. Skipping evaluation.
# User 112469 not found in training data. Skipping evaluation.
# User 915130 not found in training data. Skipping evaluation.
# User 642111 not found in training data. Skipping evaluation.
# User 151039 not found in training data. Skipping evaluation.
# User 592166 not found in training data. Skipping evaluation.
# User 254943 not found in training data. Skipping evaluation.
# User 943682 not found in training data. Skipping evaluation.
# User 958399 not found in training data. Skipping evaluation.
# User 1383 not found in training data. Skipping evaluation.
# User 240370 not found in training data. Skipping evaluation.
# User 113834 not found in training data. Skipping evaluation.
# User 545516 not found in training data. Skipping evaluation.
# User 633015 not found in training data. Skipping evaluation.
# User 515659 not found in training data. Skipping evaluation.
# User 335459 not found in training data. Skipping evaluation.
# User 145548 not found in training data. Skipping evaluation.
# User 464183 not found in training data. Skipping evaluation.
# User 495009 not found in training data. Skipping evaluation.
# User 89875 not found in training data. Skipping evaluation.
# User 597846 not found in training data. Skipping evaluation.
# User 448766 not found in training data. Skipping evaluation.
# User 727193 not found in training data. Skipping evaluation.
# User 459787 not found in training data. Skipping evaluation.
# User 821727 not found in training data. Skipping evaluation.
# User 312002 not found in training data. Skipping evaluation.
# User 734962 not found in training data. Skipping evaluation.
# User 163790 not found in training data. Skipping evaluation.
# Metrics for round 3: {'ndcg@k': np.float64(0.022192185883416222), 'hr@k': np.float64(0.04534068136272545), 'mrr@k': np.float64(0.014679358717434868), 'DI_NDCG': np.float64(1.225991274950039), 'GRU_NDCG': np.float64(0.004686026838629655), 'ndcg_low': np.float64(0.025421459388694324), 'ndcg_moderate_high': np.float64(0.02073543255006467), 'CV': np.float64(0.0906813627254509), 'cv_low': np.float64(0.09669621273166801), 'cv_moderate_high': np.float64(0.08796801163213377), 'HR_LOW': np.float64(0.048348106365834004), 'HR_MODERATE_HIGH': np.float64(0.04398400581606689), 'MRR_LOW': np.float64(0.01786193929626645), 'MRR_MODERATE_HIGH': np.float64(0.01324366896885981), 'UCV_NDCG': np.float64(4.639134903641675), 'UCV_HR': np.float64(4.549364487524867), 'UCV_MRR': np.float64(4.849305358356572), 'DI_HR': np.float64(1.0992201703504905), 'GRU_HR': np.float64(0.0043641005497671165), 'DI_MRR': np.float64(1.34871532490473), 'GRU_MRR': np.float64(0.004618270327406639)}
#
# Overall Results:
# {1: {'ndcg@k': np.float64(0.023029307258231557), 'hr@k': np.float64(0.04809619238476954), 'mrr@k': np.float64(0.014946559786239147), 'DI_NDCG': np.float64(1.4778814623636856), 'GRU_NDCG': np.float64(0.009581807245977642), 'ndcg_low': np.float64(0.029632401379896006), 'ndcg_moderate_high': np.float64(0.020050594133918364), 'CV': np.float64(0.09619238476953908), 'cv_low': np.float64(0.11281224818694602), 'cv_moderate_high': np.float64(0.08869501999272991), 'HR_LOW': np.float64(0.05640612409347301), 'HR_MODERATE_HIGH': np.float64(0.044347509996364956), 'MRR_LOW': np.float64(0.02078968573730862), 'MRR_MODERATE_HIGH': np.float64(0.012310674906094754), 'UCV_NDCG': np.float64(4.438319338649441), 'UCV_HR': np.float64(4.366083550530732), 'UCV_MRR': np.float64(4.6124678917020905), 'DI_HR': np.float64(1.271911863779871), 'GRU_HR': np.float64(0.012058614097108053), 'DI_MRR': np.float64(1.6887527203740949), 'GRU_MRR': np.float64(0.008479010831213865)}, 2: {'ndcg@k': np.float64(0.021655243444802148), 'hr@k': np.float64(0.04433867735470942), 'mrr@k': np.float64(0.014307782231128923), 'DI_NDCG': np.float64(1.611799830483096), 'GRU_NDCG': np.float64(0.011131550442012954), 'ndcg_low': np.float64(0.029326309393193337), 'ndcg_moderate_high': np.float64(0.018194758951180383), 'CV': np.float64(0.08867735470941884), 'cv_low': np.float64(0.11281224818694602), 'cv_moderate_high': np.float64(0.07778989458378771), 'HR_LOW': np.float64(0.05640612409347301), 'HR_MODERATE_HIGH': np.float64(0.038894947291893855), 'MRR_LOW': np.float64(0.020413644910018798), 'MRR_MODERATE_HIGH': np.float64(0.011553374530473767), 'UCV_NDCG': np.float64(4.622166768507222), 'UCV_HR': np.float64(4.530500620725936), 'UCV_MRR': np.float64(4.8448774469366835), 'DI_HR': np.float64(1.4502172652443388), 'GRU_HR': np.float64(0.017511176801579154), 'DI_MRR': np.float64(1.7668989139211866), 'GRU_MRR': np.float64(0.00886027037954503)}, 3: {'ndcg@k': np.float64(0.022192185883416222), 'hr@k': np.float64(0.04534068136272545), 'mrr@k': np.float64(0.014679358717434868), 'DI_NDCG': np.float64(1.225991274950039), 'GRU_NDCG': np.float64(0.004686026838629655), 'ndcg_low': np.float64(0.025421459388694324), 'ndcg_moderate_high': np.float64(0.02073543255006467), 'CV': np.float64(0.0906813627254509), 'cv_low': np.float64(0.09669621273166801), 'cv_moderate_high': np.float64(0.08796801163213377), 'HR_LOW': np.float64(0.048348106365834004), 'HR_MODERATE_HIGH': np.float64(0.04398400581606689), 'MRR_LOW': np.float64(0.01786193929626645), 'MRR_MODERATE_HIGH': np.float64(0.01324366896885981), 'UCV_NDCG': np.float64(4.639134903641675), 'UCV_HR': np.float64(4.549364487524867), 'UCV_MRR': np.float64(4.849305358356572), 'DI_HR': np.float64(1.0992201703504905), 'GRU_HR': np.float64(0.0043641005497671165), 'DI_MRR': np.float64(1.34871532490473), 'GRU_MRR': np.float64(0.004618270327406639)}}

# %% [markdown]
# {1: {'ndcg@k': np.float64(0.023029307258231557), 'hr@k': np.float64(0.04809619238476954), 'mrr@k': np.float64(0.014946559786239147), 'DI_NDCG': np.float64(1.4778814623636856), 'GRU_NDCG': np.float64(0.009581807245977642), 'ndcg_low': np.float64(0.029632401379896006), 'ndcg_moderate_high': np.float64(0.020050594133918364), 'CV': np.float64(0.09619238476953908), 'cv_low': np.float64(0.11281224818694602), 'cv_moderate_high': np.float64(0.08869501999272991), 'HR_LOW': np.float64(0.05640612409347301), 'HR_MODERATE_HIGH': np.float64(0.044347509996364956), 'MRR_LOW': np.float64(0.02078968573730862), 'MRR_MODERATE_HIGH': np.float64(0.012310674906094754), 'UCV_NDCG': np.float64(4.438319338649441), 'UCV_HR': np.float64(4.366083550530732), 'UCV_MRR': np.float64(4.6124678917020905), 'DI_HR': np.float64(1.271911863779871), 'GRU_HR': np.float64(0.012058614097108053), 'DI_MRR': np.float64(1.6887527203740949), 'GRU_MRR': np.float64(0.008479010831213865)}, 2: {'ndcg@k': np.float64(0.021655243444802148), 'hr@k': np.float64(0.04433867735470942), 'mrr@k': np.float64(0.014307782231128923), 'DI_NDCG': np.float64(1.611799830483096), 'GRU_NDCG': np.float64(0.011131550442012954), 'ndcg_low': np.float64(0.029326309393193337), 'ndcg_moderate_high': np.float64(0.018194758951180383), 'CV': np.float64(0.08867735470941884), 'cv_low': np.float64(0.11281224818694602), 'cv_moderate_high': np.float64(0.07778989458378771), 'HR_LOW': np.float64(0.05640612409347301), 'HR_MODERATE_HIGH': np.float64(0.038894947291893855), 'MRR_LOW': np.float64(0.020413644910018798), 'MRR_MODERATE_HIGH': np.float64(0.011553374530473767), 'UCV_NDCG': np.float64(4.622166768507222), 'UCV_HR': np.float64(4.530500620725936), 'UCV_MRR': np.float64(4.8448774469366835), 'DI_HR': np.float64(1.4502172652443388), 'GRU_HR': np.float64(0.017511176801579154), 'DI_MRR': np.float64(1.7668989139211866), 'GRU_MRR': np.float64(0.00886027037954503)}, 3: {'ndcg@k': np.float64(0.022192185883416222), 'hr@k': np.float64(0.04534068136272545), 'mrr@k': np.float64(0.014679358717434868), 'DI_NDCG': np.float64(1.225991274950039), 'GRU_NDCG': np.float64(0.004686026838629655), 'ndcg_low': np.float64(0.025421459388694324), 'ndcg_moderate_high': np.float64(0.02073543255006467), 'CV': np.float64(0.0906813627254509), 'cv_low': np.float64(0.09669621273166801), 'cv_moderate_high': np.float64(0.08796801163213377), 'HR_LOW': np.float64(0.048348106365834004), 'HR_MODERATE_HIGH': np.float64(0.04398400581606689), 'MRR_LOW': np.float64(0.01786193929626645), 'MRR_MODERATE_HIGH': np.float64(0.01324366896885981), 'UCV_NDCG': np.float64(4.639134903641675), 'UCV_HR': np.float64(4.549364487524867), 'UCV_MRR': np.float64(4.849305358356572), 'DI_HR': np.float64(1.0992201703504905), 'GRU_HR': np.float64(0.0043641005497671165), 'DI_MRR': np.float64(1.34871532490473), 'GRU_MRR': np.float64(0.004618270327406639)}}
