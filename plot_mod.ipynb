# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

avg_data = {
    'cf': {
        'di_ndcg': [0.376084, 0.931499, 0.48946], # DONE
        'gru_ndcg': [0.007923, 0.00135, 0.010491], # DONE
        'ucv_ndcg': [9.776048, 5.916920, 7.065049], # DONE
        'avg_ndcg': [0.010236, 0.019285, 0.017288] # DONE
    },
    'cb': {
        'di_ndcg': [ 2.6509, 2.5014, 2.5014], # DONE
        'gru_ndcg': [ 0.0181, 0.0179, 0.0179],# DONE
        'ucv_ndcg': [7.547848, 7.315473, 7.315473],# DONE
        'avg_ndcg': [0.019548, 0.020377, 0.020377]# DONE
    },
    'hybrid': {
        'di_ndcg': [0.790652, 0.648318, 0.764929],# DONE
        'gru_ndcg': [0.001484,  0.002745, 0.001736 ],# DONE
        'ucv_ndcg': [11.3506, 11.3980, 11.2046],# DONE
        'avg_ndcg': [0.006347, 0.006434, 0.006516]# DONE
    },
    'warp': {
        'di_ndcg': [1.477645, 1.504328, 1.328545], # DONE
        'gru_ndcg': [0.020640, 0.023345, 0.015046], # DONE
        'ucv_ndcg': [3.201633, 3.027129, 3.177468], # DONE
        'avg_ndcg': [0.049628, 0.053547, 0.050472]# DONE
    },
    'bpr': {
        'di_ndcg': [1.477881, 1.611800, 1.225991],# DONE
        'gru_ndcg': [0.009582, 0.011132, 0.004686],# DONE
        'ucv_ndcg': [4.438319, 4.622167, 4.639135],# DONE
        'avg_ndcg': [0.023029, 0.021655, 0.022192]# DONE
    }
}

low_data = {
    'cf': {
        'di_ndcg': [0.0, 0.0, 0.0],
        'gru_ndcg': [0.0, 0.0, 0.0],
        'ucv_ndcg': [0.0, 0.0, 0.0],
        'avg_ndcg': [0.004776, 0.018354, 0.010058]# DONE
    },
    'cb': {
        'di_ndcg': [0.0, 0.0, 0.0],
        'gru_ndcg': [0.0, 0.0, 0.0],
        'ucv_ndcg': [0.0, 0.0, 0.0],
        'avg_ndcg': [0.029052, 0.029760,  0.029760]# DONE
    },
    'hybrid': {
        'di_ndcg': [0.0, 0.0, 0.0],
        'gru_ndcg': [0.0, 0.0, 0.0],
        'ucv_ndcg': [0.0, 0.0, 0.0],
        'avg_ndcg': [0.005605, 0.005061, 0.005648]# DONE
    },
    'warp': {
        'di_ndcg': [0.0, 0.0, 0.0],
        'gru_ndcg': [0.0, 0.0, 0.0],
        'ucv_ndcg':[0.0, 0.0, 0.0],
        'avg_ndcg': [0.063851, 0.069635, 0.060840]# DONE
    },
    'bpr': {
        'di_ndcg': [0.0, 0.0, 0.0],
        'gru_ndcg': [0.0, 0.0, 0.0],
        'ucv_ndcg': [0.0, 0.0, 0.0],
        'avg_ndcg': [0.029632, 0.029326, 0.025421]# DONE
    }
}

high_data = {
    'cf': {
        'di_ndcg': [0.0, 0.0, 0.0],
        'gru_ndcg': [0.0, 0.0, 0.0],
        'ucv_ndcg': [0.0, 0.0, 0.0],
        'avg_ndcg': [0.012699, 0.019704, 0.02055]# DONE
    },
    'cb': {
        'di_ndcg': [0.0, 0.0, 0.0],
        'gru_ndcg': [0.0, 0.0, 0.0],
        'ucv_ndcg': [0.0, 0.0, 0.0],
        'avg_ndcg': [ 0.010959, 0.011897, 0.011897]# DONE
    },
    'hybrid': {
        'di_ndcg': [0.0, 0.0, 0.0],
        'gru_ndcg': [0.0, 0.0, 0.0],
        'ucv_ndcg': [0.0, 0.0, 0.0],
        'avg_ndcg': [0.007089, 0.007807, 0.007384]# DONE
    },
    'warp': {
        'di_ndcg': [0.0, 0.0, 0.0],
        'gru_ndcg': [0.0, 0.0, 0.0],
        'ucv_ndcg': [0.0, 0.0, 0.0],
        'avg_ndcg': [0.043211, 0.046290, 0.045795]# DONE
    },
    'bpr': {
        'di_ndcg': [0.0, 0.0, 0.0],
        'gru_ndcg': [0.0, 0.0, 0.0],
        'ucv_ndcg': [0.0, 0.0, 0.0],
        'avg_ndcg': [0.020051, 0.018195, 0.020735]# DONE
    }
}

models = ['cf', 'cb', 'hybrid', 'warp', 'bpr']
metrics = ['avg_ndcg', 'di_ndcg', 'gru_ndcg', 'ucv_ndcg']

models = ['cf', 'cb', 'hybrid', 'warp', 'bpr']
metrics = ['avg_ndcg', 'di_ndcg', 'gru_ndcg', 'ucv_ndcg']

from matplotlib.ticker import FuncFormatter

def plot_metrics(avg_d, low_d, high_d, model_name, axs, metrics):
    rounds = [1, 2, 3]
    colors = {'avg': '#1f77b4', 'low': '#2ca02c', 'high': '#d62728'}
    labels = {'avg': 'Average', 'low': 'Low', 'high': 'High'}

    formatter = FuncFormatter(lambda x, _: f'{x:.6f}')

    for i, metric in enumerate(metrics):
        ax = axs[i]
        ax.plot(rounds, avg_d[metric], label=labels['avg'], marker='o', color=colors['avg'])
        ax.plot(rounds, low_d[metric], label=labels['low'], marker='o', color=colors['low'])
        ax.plot(rounds, high_d[metric], label=labels['high'], marker='o', color=colors['high'])
        ax.set_title(f'{metric.upper()} over Rounds')
        ax.set_xlabel('Round', fontsize=10)
        ax.set_ylabel(metric.upper(), fontsize=10)
        ax.yaxis.set_major_formatter(formatter)
        ax.set_xticks(rounds)
        ax.tick_params(axis='both', which='major', labelsize=8)
        ax.legend(fontsize=9)


fig, axes = plt.subplots(len(models), len(metrics), figsize=(14, 14), sharex=True)

for row_idx, model in enumerate(models):
    plot_metrics(
        avg_data.get(model, {m: [0,0,0] for m in metrics}),
        low_data.get(model, {m: [0,0,0] for m in metrics}),
        high_data.get(model, {m: [0,0,0] for m in metrics}),
        model,
        axes[row_idx],
        metrics
    )
    axes[row_idx][0].set_ylabel(f'{model.upper()}', rotation=90, size='large')

fig.add_artist(plt.Line2D([[0.255, 0.255]], [0, 0.95],
                          transform=fig.transFigure, color='gray', linestyle='--', linewidth=2))


#plt.suptitle('NDCG-related Metrics (AVG, DI, GRU, UCV) over 3 Rounds for Models (Average, Low, High)', fontsize=18)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('ndcg_metrics.png')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
avg_data_hr = {
    'cf': {
        'di_hr': [0.541874, 0.891523, 0.509600], # DONE
        'gru_hr': [0.007493, 0.003628, 0.015509],# DONE
        'ucv_hr': [9.164490, 5.540253, 6.673523],# DONE
        'avg_hr': [0.014028, 0.032315, 0.026804]# DONE
    },
    'cb': {
        'di_hr': [2.4479, 2.2843, 2.2843],# DONE
        'gru_hr': [0.0176, 0.0172, 0.0172],# DONE
        'ucv_hr': [7.3646, 7.1106, 7.1106], # DONE
        'avg_hr': [0.020499, 0.021530, 0.021530]# DONE
    },
    'hybrid': {
        'di_hr': [0.870525, 0.661416, 0.802285],# DONE
        'gru_hr': [0.001192, 0.003615 , 0.001941],# DONE
        'ucv_hr': [10.7514, 10.7422, 10.6332],# DONE
        'avg_hr': [0.008608, 0.008869,0.008847]# DONE
    },
    'warp': {
        'di_hr': [1.364905, 1.418009, 1.269348],# DONE
        'gru_hr': [0.030376, 0.037531, 0.023596],# DONE
        'ucv_hr': [3.055851, 2.901032, 3.027182],# DONE
        'avg_hr': [0.092685, 0.101453, 0.094940]# DONE
    },
    'bpr': {
        'di_hr': [1.271912, 1.450217, 1.099220],# DONE
        'gru_hr': [0.012059, 0.017511, 0.004364],# DONE
        'ucv_hr': [4.366084, 4.530501, 4.549364],# DONE
        'avg_hr': [0.048096, 0.044339, 0.045341]# DONE
    }
}

low_data_hr = {
    'cf': {
        'di_hr': [0.0, 0.0, 0.0],
        'gru_hr': [0.0, 0.0, 0.0],
        'ucv_hr': [0.0, 0.0, 0.0],
        'avg_hr': [0.008864, 0.029815, 0.029009]# DONE
    },
    'cb': {
        'di_hr': [0.0, 0.0, 0.0],
        'gru_hr': [0.0, 0.0, 0.0],
        'ucv_hr': [0.0, 0.0, 0.0],
        'avg_hr': [0.029739,  0.030554,  0.030554]# DONE
    },
    'hybrid': {
        'di_hr': [0.0, 0.0, 0.0],
        'gru_hr': [0.0, 0.0, 0.0],
        'ucv_hr': [0.0, 0.0, 0.0],
        'avg_hr': [0.008012 , 0.007061, 0.007876]# DONE
    },
    'warp': {
        'di_hr': [0.0, 0.0, 0.0],
        'gru_hr':[0.0, 0.0, 0.0],
        'ucv_hr': [0.0, 0.0, 0.0],
        'avg_hr': [0.113618, 0.127317, 0.111201]# DONE
    },
    'bpr': {
        'di_hr': [0.0, 0.0, 0.0],
        'gru_hr': [0.0, 0.0, 0.0],
        'ucv_hr': [0.0, 0.0, 0.0],
        'avg_hr': [0.056406, 0.056406, 0.048348]# DONE
    }
}

high_data_hr = {
    'cf': {
        'di_hr': [0.0, 0.0, 0.0],
        'gru_hr': [0.0, 0.0, 0.0],
        'ucv_hr': [0.0, 0.0, 0.0],
        'avg_hr': [0.016358, 0.035623, 0.033442]# DONE
    },
    'cb': {
        'di_hr': [0.0, 0.0, 0.0],
        'gru_hr': [0.0, 0.0, 0.0],
        'ucv_hr': [0.0, 0.0, 0.0],
        'avg_hr': [0.012149, 0.013376 ,0.013376 ]# DONE
    },
    'hybrid': {
        'di_hr': [0.0, 0.0, 0.0],
        'gru_hr': [0.0, 0.0, 0.0],
        'ucv_hr': [0.0, 0.0, 0.0],
        'avg_hr': [0.009204, 0.010676,  0.009817]# DONE
    },
    'warp': {
        'di_hr': [0.0, 0.0, 0.0],
        'gru_hr':[0.0, 0.0, 0.0],
        'ucv_hr': [0.0, 0.0, 0.0],
        'avg_hr': [0.083242, 0.089786, 0.087605]# DONE
    },
    'bpr': {
        'di_hr': [0.0, 0.0, 0.0],
        'gru_hr': [0.0, 0.0, 0.0],
        'ucv_hr': [0.0, 0.0, 0.0],
        'avg_hr': [0.044348, 0.038895, 0.043984]# DONE
    }
}

def plot_hr_metrics(avg_d, low_d, high_d, model_name, axs, metrics):
    rounds = [1, 2, 3]
    colors = {'avg': '#1f77b4', 'low': '#2ca02c', 'high': '#d62728'}
    labels = {'avg': 'Average', 'low': 'Low', 'high': 'High'}
    from matplotlib.ticker import FuncFormatter
    formatter = FuncFormatter(lambda x, _: f'{x:.6f}')

    for i, metric in enumerate(metrics):
        ax = axs[i]
        ax.plot(rounds, avg_d[metric], label=labels['avg'], marker='o', color=colors['avg'])
        ax.plot(rounds, low_d[metric], label=labels['low'], marker='o', color=colors['low'])
        ax.plot(rounds, high_d[metric], label=labels['high'], marker='o', color=colors['high'])
        ax.set_title(f'{metric.upper()} over Rounds')
        ax.set_xlabel('Round', fontsize=10)
        ax.set_ylabel(metric.upper(), fontsize=10)
        ax.yaxis.set_major_formatter(formatter)
        ax.set_xticks(rounds)
        ax.tick_params(axis='both', which='major', labelsize=8)
        ax.legend(fontsize=9)

models = ['cf', 'cb', 'hybrid', 'warp', 'bpr']
metrics_hr = ['avg_hr', 'di_hr', 'gru_hr', 'ucv_hr']

fig, axes = plt.subplots(len(models), len(metrics_hr), figsize=(14, 14), sharex=True)

for row_idx, model in enumerate(models):
    plot_hr_metrics(
        avg_data_hr.get(model, {m: [0, 0, 0] for m in metrics_hr}),
        low_data_hr.get(model, {m: [0, 0, 0] for m in metrics_hr}),
        high_data_hr.get(model, {m: [0, 0, 0] for m in metrics_hr}),
        model,
        axes[row_idx],
        metrics_hr
    )
    axes[row_idx][0].set_ylabel(f'{model.upper()}', rotation=90, size='large')
fig.add_artist(plt.Line2D([0.255, 0.255], [0, 0.95],
                          transform=fig.transFigure, color='gray', linestyle='--', linewidth=2))
#plt.suptitle('HR-related Metrics (AVG, DI, GRU, UCV) over 3 Rounds for Models (Average, Low, High)', fontsize=18)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('hr_metrics.png')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
avg_data_mrr = {
    'cf': {
        'di_mrr': [0.302977, 0.960626, 0.475928],#DONE
        'gru_mrr': [0.008002, 0.000599, 0.008858],#DONE
        'ucv_mrr': [10.841026, 6.539858, 7.667539],#DONE
        'avg_mrr': [0.008993, 0.015038, 0.014149]#DONE
    },
    'cb': {
        'di_mrr': [ 2.5490, 2.3965, 2.3965],#DONE
        'gru_mrr': [ 0.0178,  0.0175,  0.0175],#DONE
        'ucv_mrr': [7.4426, 7.1956, 7.1956],#DONE
        'avg_mrr': [0.01995, 0.020856, 0.020856]#DONE
    },
    'hybrid': {
        'di_mrr': [0.7542, 0.6434, 0.7462],#DONE
        'gru_mrr': [0.0016, 0.0024, 0.0017],#DONE
        'ucv_mrr': [12.0771, 12.1876, 11.8942],#DONE
        'avg_mrr': [0.005599, 0.005633, 0.005741]#DONE
    },
    'warp': {
        'di_mrr': [1.570761, 1.575704, 1.377243],# DONE
        'gru_mrr': [0.017241, 0.018513, 0.012154],# DONE
        'ucv_mrr': [3.510972, 3.301742, 3.498082],#DONE
        'avg_mrr': [0.035567, 0.037913, 0.035997]# DONE
    },
    'bpr': {
        'di_mrr': [1.688753, 1.766899, 1.348715],#DONE
        'gru_mrr': [0.008480, 0.008860, 0.004618],# DONE
        'ucv_mrr': [4.612468, 4.844877, 4.849305],# DONE
        'avg_mrr': [0.014947, 0.014308, 0.014679]# DONE
    }
}

low_data_mrr = {
    'cf': {
        'di_mrr': [0.0, 0.0, 0.0],
        'gru_mrr': [0.0, 0.0, 0.0],
        'ucv_mrr': [0.0, 0.0, 0.0],
        'avg_mrr': [0.003478, 0.014625, 0.008045]#DONE
    },
    'cb': {
        'di_mrr': [0.0, 0.0, 0.0],
        'gru_mrr': [0.0, 0.0, 0.0],
        'ucv_mrr': [0.0, 0.0, 0.0],
        'avg_mrr': [0.029309 ,0.030056 , 0.030056]#DONE
    },
    'hybrid': {
        'di_mrr': [0.0, 0.0, 0.0],
        'gru_mrr': [0.0, 0.0, 0.0],
        'ucv_mrr': [0.0, 0.0, 0.0],
        'avg_mrr': [0.004814, 0.004411, 0.004907]#DONE
    },
    'warp': {
        'di_mrr': [0.0, 0.0, 0.0],
        'gru_mrr': [0.0, 0.0, 0.0],
        'ucv_mrr': [0.0, 0.0, 0.0],
        'avg_mrr': [0.047448, 0.050672, 0.044373]# DONE
    },
    'bpr': {
        'di_mrr': [0.0, 0.0, 0.0],
        'gru_mrr': [0.0, 0.0, 0.0],
        'ucv_mrr': [0.0, 0.0, 0.0],
        'avg_mrr': [0.020790, 0.020414, 0.017862]# DONE
    }
}

high_data_mrr = {
    'cf': {
        'di_mrr': [0.0, 0.0, 0.0],
        'gru_mrr': [0.0, 0.0, 0.0],
        'ucv_mrr': [0.0, 0.0, 0.0],
        'avg_mrr': [0.011481, 0.015225, 0.016903]#DONE
    },
    'cb': {
        'di_mrr': [0.0, 0.0, 0.0],
        'gru_mrr': [0.0, 0.0, 0.0],
        'ucv_mrr': [0.0, 0.0, 0.0],
        'avg_mrr': [0.011498, 0.012541, 0.012541]#DONE
    },
    'hybrid': {
        'di_mrr': [0.0, 0.0, 0.0],
        'gru_mrr': [0.0, 0.0, 0.0],
        'ucv_mrr': [0.0, 0.0, 0.0],
        'avg_mrr': [0.006383, 0.006856 , 0.006575]#DONE
    },
    'warp': {
        'di_mrr': [0.0, 0.0, 0.0],
        'gru_mrr': [0.0, 0.0, 0.0],
        'ucv_mrr': [0.0, 0.0, 0.0],
        'avg_mrr': [0.030207, 0.032158, 0.032219]# DONE
    },
    'bpr': {
        'di_mrr': [0.0, 0.0, 0.0],
        'gru_mrr': [0.0, 0.0, 0.0],
        'ucv_mrr': [0.0, 0.0, 0.0],
        'avg_mrr': [0.012311, 0.011553, 0.013244]# DONE
    }
}

def plot_mrr_metrics(avg_d, low_d, high_d, model_name, axs, metrics):
    rounds = [1, 2, 3]
    colors = {'avg': '#1f77b4', 'low': '#2ca02c', 'high': '#d62728'}
    labels = {'avg': 'Average', 'low': 'Low', 'high': 'High'}
    from matplotlib.ticker import FuncFormatter
    formatter = FuncFormatter(lambda x, _: f'{x:.6f}')

    for i, metric in enumerate(metrics):
        ax = axs[i]
        ax.plot(rounds, avg_d[metric], label=labels['avg'], marker='o', color=colors['avg'])
        ax.plot(rounds, low_d[metric], label=labels['low'], marker='o', color=colors['low'])
        ax.plot(rounds, high_d[metric], label=labels['high'], marker='o', color=colors['high'])
        ax.set_title(f'{metric.upper()} over Rounds')
        ax.set_xlabel('Round', fontsize=10)
        ax.set_ylabel(metric.upper(), fontsize=10)
        ax.yaxis.set_major_formatter(formatter)
        ax.set_xticks(rounds)
        ax.tick_params(axis='both', which='major', labelsize=8)
        ax.legend(fontsize=9)

models = ['cf', 'cb', 'hybrid', 'warp', 'bpr']
metrics_mrr = ['avg_mrr','di_mrr', 'gru_mrr', 'ucv_mrr']

fig, axes = plt.subplots(len(models), len(metrics_mrr), figsize=(14, 14), sharex=True)

for row_idx, model in enumerate(models):
    plot_mrr_metrics(
        avg_data_mrr.get(model, {m: [0, 0, 0] for m in metrics_mrr}),
        low_data_mrr.get(model, {m: [0, 0, 0] for m in metrics_mrr}),
        high_data_mrr.get(model, {m: [0, 0, 0] for m in metrics_mrr}),
        model,
        axes[row_idx],
        metrics_mrr
    )
    axes[row_idx][0].set_ylabel(f'{model.upper()}', rotation=90, size='large')

fig.add_artist(plt.Line2D([0.255, 0.255], [0, 0.95],
                          transform=fig.transFigure, color='gray', linestyle='--', linewidth=2))

#plt.suptitle('MRR-related Metrics (AVG, DI, GRU, UCV) over 3 Rounds for Models (Average, Low, High)', fontsize=18)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('mrr_metrics.png')
plt.show()
