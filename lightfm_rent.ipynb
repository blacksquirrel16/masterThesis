# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity

# %%
file_path = 'renttherunway_final_data.json' 
df_rent = pd.read_json(file_path, lines=True)

# %% [markdown]
# # Preprocessing

# %%
df_rent_clean = df_rent.dropna(subset=["user_id", "item_id", "rating","age"]).drop_duplicates()

# %%
###############################################
# 3. Explicit Feedback
###############################################

df_rent_clean['interaction'] = df_rent_clean['rating']

# %%
def calculate_sparsity(df):
    """Calculates sparsity for each numerical feature in the DataFrame."""
    numerical_features = df.select_dtypes(include=np.number).columns
    sparsity_results = {}

    for feature in numerical_features:
        sparsity = df[feature].isnull().sum() / len(df) 
        sparsity_results[feature] = sparsity

    return sparsity_results


sparsity_dict = calculate_sparsity(df_rent_clean)
print(sparsity_dict)
# Out:
# {'user_id': 0.0, 'item_id': 0.0, 'rating': 0.0, 'size': 0.0, 'age': 0.0, 'interaction': 0.0}

# %%
def preprocess_data(df, sparsity_threshold=0.50):
    """Preprocesses the data by removing numerical features with high sparsity."""
    for col in df.select_dtypes(include=np.number).columns:
        sparsity = df[col].isnull().sum() / len(df)
        if sparsity > sparsity_threshold:
            print(f"Dropping sparse feature: {col} (Sparsity: {sparsity:.2f})")
            df = df.drop(col, axis=1)
    return df

# %%
df_rent_clean = preprocess_data(df_rent_clean, sparsity_threshold=0.50)


user_interaction_counts = df_rent_clean.groupby('user_id')['rating'].count()
users_with_enough_interactions = user_interaction_counts[user_interaction_counts >= 2].index
df_rent_clean = df_rent_clean[df_rent_clean["user_id"].isin(users_with_enough_interactions)]
print(f"Number of users with more than 2 interactions: {len(users_with_enough_interactions)}")
# Out:
# Number of users with more than 2 interactions: 33544

# %%
median_interaction_strength = df_rent_clean.groupby('user_id')['interaction'].sum().median()

df_rent_clean['user_activity'] = df_rent_clean.groupby('user_id')['interaction'].transform('sum').map(
    lambda x: 'Low' if x < median_interaction_strength else 'High'
)

print(df_rent_clean['user_activity'].value_counts())
# Out:
# user_activity
# High    99471
# Low     20515
# Name: count, dtype: int64

# %%
df_rent_clean = df_rent_clean.sort_values('review_date')


train_size = int(0.6 * len(df_rent_clean)) # 60 %
val_size = int(0.2 * len(df_rent_clean))


train_df = df_rent_clean[:train_size]
val_df = df_rent_clean[train_size:train_size + val_size]
test_df = df_rent_clean[train_size + val_size:]


print("Train set shape:", train_df.shape)
print("Validation set shape:", val_df.shape)
print("Test set shape:", test_df.shape)
# Out:
# Train set shape: (71991, 17)
# Validation set shape: (23997, 17)
# Test set shape: (23998, 17)

# %%
###############################################
# 3. User Item Matrix -Train
###############################################

train_user_item_matrix = train_df.pivot_table(
    index="user_id",
    columns="item_id",
    values="interaction",
    aggfunc="sum",
    fill_value=0
)

# %% [markdown]
# #Definition effectiveness

# %%
###############################################
# 3. Utility/Ranking metrics
###############################################
def dcg_at_k_recursive(relevance_scores, k, b=2):
    """
    Calculate the Discounted Cumulative Gain at rank k recursively.

    :param relevance_scores: A list or array of relevance scores for the ranked items.
    :param k: The rank at which to stop (k items to evaluate).
    :param b: The base of the logarithm (typically 2).
    :return: DCG at rank k.
    """
    
    k = min(k, len(relevance_scores))

    if k == 0:
        return 0.0

    if k < b:
        return np.sum([rel / np.log2(idx + 2) for idx, rel in enumerate(relevance_scores[:k])])

    else:
        dcg_k_minus_1 = dcg_at_k_recursive(relevance_scores, k - 1, b)
        rel_k = relevance_scores[k - 1] 
        return dcg_k_minus_1 + (rel_k / np.log2(k + 1))

def dcg_at_k(relevance_scores, k, b=2):
    """
    Calculate the Discounted Cumulative Gain at rank k (non-recursive).
    """
    dcg = 0
    for idx, rel in enumerate(relevance_scores[:k]):
        dcg += rel / np.log2(idx + 2)
    return dcg
def idcg_at_k(relevance_scores, k):
    """
    Calculate the Ideal Discounted Cumulative Gain at rank k.
    :param relevance_scores: A list or array of relevance scores for the ranked items.
    :param k: The rank at which to stop (k items to evaluate).
    :return: Ideal DCG at rank k.
    """
    relevance_scores = sorted(relevance_scores, reverse=True)
    return dcg_at_k(relevance_scores, k)

def ndcg_at_k(relevance_scores, k):
    """
    Calculate the Normalized Discounted Cumulative Gain at rank k.
    :param relevance_scores: A list or array of relevance scores for the ranked items.
    :param k: The rank at which to stop (k items to evaluate).
    :return: nDCG at rank k.
    """
    dcg = dcg_at_k_recursive(relevance_scores, k)
    idcg = idcg_at_k(relevance_scores, k)
    if idcg == 0:
        return 0
    return dcg / idcg

# %%
def hr_at_k(actual, predicted, k=5):
    """
    Computes Hit Rate (HR) at rank k.

    Args:
        actual: list of relevant items
        predicted: ranked list of items
        k: rank cutoff (default is 5)

    Returns:
        Hit Rate at rank k.
    """

    for item in predicted[:k]:  
        if item in actual:
            return 1 
    return 0


def hit_rate_at_k(actual, predicted, k=5):
    """
    Computes Mean Hit Rate (HR) at rank k for all users.

    Args:
        actual: list of relevant items for each user
        predicted: list of predicted ranked items for each user
        k: rank cutoff (default is 5)

    Returns:
        HR at rank k.
    """

    if not actual or len(predicted) == 0:
        return 0.0

    hr_scores = []
    for user_actual, user_predicted in zip(actual, predicted):
        hr = hr_at_k(user_actual, user_predicted, k)
        hr_scores.append(hr)

    return np.mean(hr_scores)

# %%
def rr_at_k(actual, predicted, k=5):
    """
    Computes Reciprocal Rank at rank k.

    Args:
        actual: the relevant item(s)
        predicted: the ranked list of items
        k: rank cutoff (default is 5)

    Returns:
        Reciprocal Rank at rank k.
    """

    for i, item in enumerate(predicted[:k]):
        if item == actual:
            return 1 / (i + 1) 
    return 0.0  


def mrr_at_k(actual, predicted, k=5):
    """
    Computes Mean Reciprocal Rank (MRR) at rank k.

    Args:
        actual: list of relevant items (can be multiple)
        predicted: ranked list of items
        k: rank cutoff (default is 5)

    Returns:
        MRR at rank k.
    """

    if actual is None or len(predicted) == 0:
        return 0.0


    rr_scores = []
    for item in actual:
        rr = rr_at_k(item, predicted, k)
        rr_scores.append(rr)

   
    return np.mean(rr_scores)

# %% [markdown]
# #DEfinition Fairness metrics

# %%
def calculate_disparate_impact(protected_outcomes, privileged_outcomes):
    """
    Args:
        protected_outcomes: List of binary outcomes (1=favorable) for the protected group.
        privileged_outcomes: List of binary outcomes for the privileged group.
    Returns:
        Disparate impact ratio.
    """
    protected_rate = np.mean(protected_outcomes)
    privileged_rate = np.mean(privileged_outcomes)

    if privileged_rate == 0:
        return np.inf  

    return protected_rate / privileged_rate


def calculate_group_recommender_unfairness(group1_metrics, group2_metrics):
  """
    Calculates the absolute difference in mean metrics between two groups.
    This metric quantifies the unfairness of a recommender system by examining
    the absolute difference in average performance between different user groups.

    Args:
        group1_metrics (list or numpy.ndarray): A list or numpy array of metrics for group 1.
        group2_metrics (list or numpy.ndarray): A list or numpy array of metrics for group 2.

    Returns:
        float: The absolute difference in mean metrics between the two groups.
  """
  return np.abs(np.mean(group1_metrics) - np.mean(group2_metrics))

# %%
def coefficient_of_variance(group):
    """Calculates the coefficient of variance for a group."""
    return np.std(group) / np.mean(group) if np.mean(group) != 0 else 0
def coefficient_of_variation(arr):
    mean_val = np.mean(arr)
    if mean_val == 0:
        return 0
    return np.std(arr) / mean_val

def calculate_ucv(metric_low_group, metric_high_group):
    
    cv_low = coefficient_of_variation(metric_low_group) if len(metric_low_group) > 0 else 0
    cv_high = coefficient_of_variation(metric_high_group) if len(metric_high_group) > 0 else 0
    return (cv_low + cv_high) / 2

# %% [markdown]
# # MEtrics

# %%
pip install lightfm # install lightfm in terminal
# Out:
# Requirement already satisfied: lightfm in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.17)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lightfm) (1.25.2)
# Requirement already satisfied: scipy>=0.17.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lightfm) (1.11.3)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lightfm) (2.31.0)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lightfm) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->lightfm) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->lightfm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->lightfm) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->lightfm) (2023.7.22)
# Requirement already satisfied: joblib>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn->lightfm) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn->lightfm) (3.2.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: pip3.11 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from lightfm import LightFM
from scipy.sparse import coo_matrix # sparse matrix
from lightfm.evaluation import precision_at_k, recall_at_k

interactions = coo_matrix(train_user_item_matrix.values)


model = LightFM(loss='warp')
 # https://making.lyst.com/lightfm/docs/lightfm.html


model.fit(interactions, epochs=30, num_threads=2)

train_precision = precision_at_k(model, interactions, k=5).mean()
train_recall = recall_at_k(model, interactions, k=5).mean()


print(f"Train Precision at k=5: {train_precision}")
print(f"Train Recall at k=5: {train_recall}")


user_id = 55
scores = model.predict(user_id, np.arange(interactions.shape[1]))

#descending order
top_items = np.argsort(-scores)

print("Top 10 recommended items for user 55:", top_items[:10])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/lightfm/_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(
# Train Precision at k=5: 0.09307190775871277
# Train Recall at k=5: 0.3034202631760367
# Top 10 recommended items for user 55: [  82 1795 1552 2844    1 2859  356  159 2253 2063]

# %%
#Best parameters: {'item_alpha': 1e-06, 'learning_rate': 0.01, 'loss': 'warp', 'no_components': 50, 'user_alpha': 1e-05}, Best AUC: 0.775144100189209
#<lightfm.lightfm.LightFM at 0x7b035c2baf10>

best_model = LightFM(loss='warp', no_components=50, learning_rate=0.01, item_alpha=1e-06, user_alpha=0.0)
best_model.fit(interactions, epochs=30, num_threads=2)

# %%
test_items = test_df.groupby("user_id")["item_id"].first().to_dict()

def calculate_metrics_for_user(user, actual_item, recs, group):
    relevance_scores = [1 if item == actual_item else 0 for item in recs]
    ndcg = ndcg_at_k(relevance_scores, k=6)
    hr = hr_at_k([actual_item], recs, k=5)
    mrr = mrr_at_k([actual_item], recs, k=5)
    cv = coefficient_of_variance(relevance_scores)
    return [user, ndcg, hr, mrr, cv, group]



metrics_lightfm = []
for user_id in train_user_item_matrix.index:
    actual_item = test_items.get(user_id, None)
    if actual_item is None:
        continue

    
    engagement_level = df_rent_clean[df_rent_clean["user_id"] == user_id][
        "user_activity"
    ].values[0]
    try:
        user_id_internal = train_user_item_matrix.index.get_loc(user_id)
    except KeyError:
        
        print(f"User {user_id} not found in training data. Skipping.")
        continue

   
    scores = best_model.predict(user_id_internal, np.arange(interactions.shape[1])) 
    top_items = np.argsort(-scores)
    recs = [train_user_item_matrix.columns[i] for i in top_items]

    
    metrics_lightfm.append(
        calculate_metrics_for_user(user_id, actual_item, recs, engagement_level)
    )

metrics_lightfm_df = pd.DataFrame(
    metrics_lightfm, columns=["User", "NDCG@K", "HR@K", "MRR@K","CV", "Engagement Group"]
)
metrics_lightfm_df['User'] = pd.to_numeric(metrics_lightfm_df['User'], errors='coerce')


grouped_metrics_lightfm = metrics_lightfm_df.groupby("Engagement Group").agg(
    {"NDCG@K": "mean", "HR@K": "mean", "MRR@K": "mean", "CV":"mean"}
)
print("\nLightFM Metrics by User Engagement Level:")
grouped_metrics_lightfm
# Out:
# LightFM Metrics by User Engagement Level:
#                     NDCG@K      HR@K    MRR@K         CV
# Engagement Group
# High              0.012781  0.020487  0.00835  71.879668
# Low               0.029863  0.045179  0.02105  72.809042

# %%
def calculate_average_metrics(metrics_df):
  """
  Calculates the average of NDCG, HR, and MRR from a DataFrame.

  Args:
    metrics_df: A pandas DataFrame with 'NDCG@K', 'HR@K', and 'MRR@K' columns.

  Returns:
    A dictionary containing the average NDCG, HR, and MRR.
  """
  average_ndcg = metrics_df['NDCG@K'].mean()
  average_hr = metrics_df['HR@K'].mean()
  average_mrr = metrics_df['MRR@K'].mean()
  average_cv = metrics_df['CV'].mean()
  return {
      'Average NDCG@K': average_ndcg,
      'Average HR@K': average_hr,
      'Average MRR@K': average_mrr,
      'Average CV': average_cv
  }


overall_avg_metrics_lightfm = calculate_average_metrics(metrics_lightfm_df)
print("\nOverall Average LightFM Metrics:")
overall_avg_metrics_lightfm
# Out:
# Overall Average LightFM Metrics:
# {'Average NDCG@K': 0.015596212795900101,
#  'Average HR@K': 0.024555555555555556,
#  'Average MRR@K': 0.010442592592592592,
#  'Average CV': 72.03280793268206}

# %%
ndcg_low = grouped_metrics_lightfm.loc["Low", "NDCG@K"]
ndcg_moderate_high = grouped_metrics_lightfm.loc["High", "NDCG@K"]


di_ndcg = calculate_disparate_impact(ndcg_low, ndcg_moderate_high)
gru_ndcg = calculate_group_recommender_unfairness(ndcg_low, ndcg_moderate_high)

cv_low_ndcg = coefficient_of_variance(ndcg_low)
cv_moderate_high_ndcg = coefficient_of_variance(ndcg_moderate_high)


print(f"\nLightFM - NDCG Metrics:")
print(f"Disparate Impact: {di_ndcg}")
print(f"Group Recommender Unfairness: {gru_ndcg}")
print(f"Coefficient of Variance Low: {cv_low_ndcg}")
print(f"Coefficient of Variance High: {cv_moderate_high_ndcg}")


hr_low = grouped_metrics_lightfm.loc["Low", "HR@K"]
hr_moderate_high = grouped_metrics_lightfm.loc["High", "HR@K"]


di_hr = calculate_disparate_impact(hr_low, hr_moderate_high)
gru_hr = calculate_group_recommender_unfairness(hr_low, hr_moderate_high)

cv_low_hr = coefficient_of_variance(hr_low)
cv_moderate_high_hr = coefficient_of_variance(hr_moderate_high)


print(f"\nLightFM - HR@K Metrics:")
print(f"Disparate Impact: {di_hr}")
print(f"Group Recommender Unfairness: {gru_hr}")
print(f"Coefficient of Variance Low: {cv_low_hr}")
print(f"Coefficient of Variance High: {cv_moderate_high_hr}")



mrr_low = grouped_metrics_lightfm.loc["Low", "MRR@K"]
mrr_moderate_high = grouped_metrics_lightfm.loc["High", "MRR@K"]

di_mrr = calculate_disparate_impact(mrr_low, mrr_moderate_high)
gru_mrr = calculate_group_recommender_unfairness(mrr_low, mrr_moderate_high)

cv_low_mrr = coefficient_of_variance(mrr_low)
cv_moderate_high_mrr = coefficient_of_variance(mrr_moderate_high)


print(f"\nLightFM - MRR@K Metrics:")
print(f"Disparate Impact: {di_mrr}")
print(f"Group Recommender Unfairness: {gru_mrr}")
print(f"Coefficient of Variance Low: {cv_low_mrr}")
print(f"Coefficient of Variance High: {cv_moderate_high_mrr}")
# Out:
# LightFM - NDCG Metrics:
# Disparate Impact: 2.336459514210217
# Group Recommender Unfairness: 0.017081941766557376
# Coefficient of Variance Low: 0.0
# Coefficient of Variance High: 0.0
#
# LightFM - HR@K Metrics:
# Disparate Impact: 2.2052482244660263
# Group Recommender Unfairness: 0.024691795472631107
# Coefficient of Variance Low: 0.0
# Coefficient of Variance High: 0.0
#
# LightFM - MRR@K Metrics:
# Disparate Impact: 2.5209304315970447
# Group Recommender Unfairness: 0.012699711776405637
# Coefficient of Variance Low: 0.0
# Coefficient of Variance High: 0.0

# %% [markdown]
# # CAN CRASH

# %%
import numpy as np
from lightfm import LightFM
from scipy.sparse import csr_matrix  # sparse matrix
from lightfm.evaluation import precision_at_k, recall_at_k, auc_score
from lightfm.cross_validation import random_train_test_split
from sklearn.metrics import ndcg_score
import pandas as pd 


def evaluate_lightfm_multiple_rounds(
    interactions, test_df, df_rent_clean, num_rounds=3, k=5, epochs=30, user_id_to_print=55
):
    """
    Evaluates LightFM model with multiple training rounds, fairness metrics, and prints recommendations for a user.

    Args:
        interactions: The user-item interaction matrix (sparse).
        test_df: The test DataFrame.
        df_rent_clean: The cleaned main DataFrame with user activity.
        num_rounds: The number of training rounds.
        k: The value of k for precision@k, recall@k metrics.
        epochs: The number of epochs for each training round.
        user_id_to_print: The user ID for which recommendations will be printed.

    Returns:
        A dictionary containing metrics for each round.
    """

    train_interactions, test_interactions = random_train_test_split(
        interactions, test_percentage=0.2, random_state=42
    )

    round_metrics = {}
    model = LightFM(loss='warp', no_components=50, learning_rate=0.1, item_alpha=1e-05, user_alpha=1e-06)


    test_items = test_df.groupby("user_id")["item_id"].first().to_dict()


    user_id_map = {user: i for i, user in enumerate(train_user_item_matrix.index)}


    for round_num in range(num_rounds):
        print(f"Training Round {round_num + 1}...")
        model.fit(train_interactions, epochs=epochs)

        test_user_ids = test_df['user_id'].unique()

        ndcg_scores = []
        hr_scores = []
        mrr_scores = []
        cv_scores = []
        engagement_levels_list = []

        for user_id in test_user_ids:
            actual_item = test_items.get(user_id, None)
            if actual_item is None:
                continue


            user_id_internal = user_id_map.get(user_id, None)
            if user_id_internal is None:
                
                print(f"User {user_id} not found in training data. Skipping evaluation.")
                continue

            engagement_level_row = df_rent_clean[df_rent_clean["user_id"] == user_id]
            if engagement_level_row.empty:
                 print(f"User {user_id} not found in df_rent_clean for engagement level. Skipping.")
                 continue
            engagement_level = engagement_level_row["user_activity"].values[0]
            engagement_levels_list.append(engagement_level)


            scores = model.predict(user_id_internal, np.arange(interactions.shape[1]))
            top_k_indices = np.argsort(-scores)[:k]
            top_k_items_predicted = [train_user_item_matrix.columns[i] for i in top_k_indices]

            relevance_scores = [1 if item == actual_item else 0 for item in top_k_items_predicted]

            
            ndcg_scores.append(ndcg_at_k(relevance_scores, k))

            hr_scores.append(hr_at_k([actual_item], top_k_items_predicted, k))
            mrr_scores.append(mrr_at_k([actual_item], top_k_items_predicted, k))
            cv_scores.append(coefficient_of_variance(np.array(relevance_scores))) 


        ndcg = np.mean(ndcg_scores) if ndcg_scores else 0
        hr = np.mean(hr_scores) if hr_scores else 0
        mrr = np.mean(mrr_scores) if mrr_scores else 0
        cv = np.mean(cv_scores) if cv_scores else 0


        ndcg_low = [
            ndcg_scores[i]
            for i in range(len(ndcg_scores))
            if engagement_levels_list[i] == "Low"
        ]
        ndcg_moderate_high = [
            ndcg_scores[i]
            for i in range(len(ndcg_scores))
            if engagement_levels_list[i] == "High" 
        ]
    
       

        cv_low = [
            cv_scores[i]
            for i in range(len(cv_scores))
            if engagement_levels_list[i] == "Low"
        ]
        cv_moderate_high = [
            cv_scores[i]
            for i in range(len(cv_scores))
            if engagement_levels_list[i] == "High"
        ]
        hr_low = [
            hr_scores[i]
            for i in range(len(hr_scores))
            if engagement_levels_list[i] == "Low"
        ]
        hr_moderate_high = [
            hr_scores[i]
            for i in range(len(hr_scores))
            if engagement_levels_list[i] == "High" 
        ]
        mrr_low = [
            mrr_scores[i]
            for i in range(len(mrr_scores))
            if engagement_levels_list[i] == "Low"
        ]
        mrr_moderate_high = [
            mrr_scores[i]
            for i in range(len(mrr_scores))
            if engagement_levels_list[i] == "High" 
        ]
        ucv_ndcg = calculate_ucv(ndcg_low, ndcg_moderate_high)
        
        ucv_hr = calculate_ucv(hr_low, hr_moderate_high)
        ucv_mrr = calculate_ucv(mrr_low, mrr_moderate_high)
        cv_low_mean = np.mean(cv_low) if cv_low else 0
        cv_moderate_high_mean = np.mean(cv_moderate_high) if cv_moderate_high else 0
        hr_low_mean = np.mean(hr_low) if hr_low else 0
        hr_moderate_high_mean = np.mean(hr_moderate_high) if hr_moderate_high else 0
        mrr_low_mean = np.mean(mrr_low) if mrr_low else 0
        mrr_moderate_high_mean = np.mean(mrr_moderate_high) if mrr_moderate_high else 0
        di_ndcg = calculate_disparate_impact(ndcg_low, ndcg_moderate_high) if ndcg_moderate_high else np.inf 
        gru_ndcg = calculate_group_recommender_unfairness(ndcg_low, ndcg_moderate_high)
        ndcg_low = np.mean(ndcg_low) if ndcg_low else 0
        ndcg_moderate_high = np.mean(ndcg_moderate_high) if ndcg_moderate_high else 0
        di_hr = calculate_disparate_impact(hr_low, hr_moderate_high) if hr_moderate_high else np.inf 
        gru_hr = calculate_group_recommender_unfairness(hr_low, hr_moderate_high)
        di_mrr = calculate_disparate_impact(mrr_low, mrr_moderate_high) if mrr_moderate_high else np.inf
        gru_mrr = calculate_group_recommender_unfairness(mrr_low, mrr_moderate_high)

        
        round_metrics[round_num + 1] = {
            "ndcg@k": ndcg,
            "hr@k": hr,
            "mrr@k": mrr,
            "ndcg_low": ndcg_low,
            "ndcg_moderate_high": ndcg_moderate_high,
            "DI_NDCG": di_ndcg,
            "GRU_NDCG": gru_ndcg,
            "CV": cv,
            "cv_low": cv_low_mean,
            "cv_moderate_high": cv_moderate_high_mean,
            "HR_LOW": hr_low_mean,
            "HR_MODERATE_HIGH": hr_moderate_high_mean,
            "MRR_LOW": mrr_low_mean,
            "MRR_MODERATE_HIGH": mrr_moderate_high_mean,
            "UCV_NDCG": ucv_ndcg,
            "UCV_HR": ucv_hr,
            "UCV_MRR": ucv_mrr,
            "DI_HR": di_hr,
            "GRU_HR": gru_hr,
            "DI_MRR": di_mrr,
            "GRU_MRR": gru_mrr
        }

        print(f"Metrics for round {round_num + 1}: {round_metrics[round_num + 1]}")


        if round_num == 0 and user_id_to_print in user_id_map:
            user_index = user_id_map[user_id_to_print]
            scores = model.predict(user_index, np.arange(interactions.shape[1]))
            top_items_indices = np.argsort(-scores)[:k]
            top_items_actual_ids = [train_user_item_matrix.columns[i] for i in top_items_indices]
            print(
                f"Top {k} recommendations for user {user_id_to_print}: {top_items_actual_ids}"
            )
        elif round_num == 0 and user_id_to_print not in user_id_map:
            print(
                f"User {user_id_to_print} not found in training data mapping. Skipping recommendations."
            )

    return round_metrics

interactions = csr_matrix(train_user_item_matrix.values)


round_results = evaluate_lightfm_multiple_rounds(interactions, test_df, df_rent_clean)

print("\nOverall Results:")
print(round_results)
# Out:
# Training Round 1...
# User 696430 not found in training data. Skipping evaluation.
# User 987390 not found in training data. Skipping evaluation.
# User 405715 not found in training data. Skipping evaluation.
# User 436933 not found in training data. Skipping evaluation.
# User 522905 not found in training data. Skipping evaluation.
# User 751887 not found in training data. Skipping evaluation.
# User 854188 not found in training data. Skipping evaluation.
# User 818665 not found in training data. Skipping evaluation.
# User 750491 not found in training data. Skipping evaluation.
# User 387463 not found in training data. Skipping evaluation.
# User 160450 not found in training data. Skipping evaluation.
# User 523458 not found in training data. Skipping evaluation.
# User 791921 not found in training data. Skipping evaluation.
# User 214592 not found in training data. Skipping evaluation.
# User 24811 not found in training data. Skipping evaluation.
# User 418034 not found in training data. Skipping evaluation.
# User 459541 not found in training data. Skipping evaluation.
# User 975280 not found in training data. Skipping evaluation.
# User 704568 not found in training data. Skipping evaluation.
# User 731615 not found in training data. Skipping evaluation.
# User 585687 not found in training data. Skipping evaluation.
# User 796991 not found in training data. Skipping evaluation.
# User 623671 not found in training data. Skipping evaluation.
# User 372105 not found in training data. Skipping evaluation.
# User 31024 not found in training data. Skipping evaluation.
# User 560182 not found in training data. Skipping evaluation.
# User 365115 not found in training data. Skipping evaluation.
# User 475721 not found in training data. Skipping evaluation.
# User 962756 not found in training data. Skipping evaluation.
# User 339207 not found in training data. Skipping evaluation.
# User 873528 not found in training data. Skipping evaluation.
# User 611488 not found in training data. Skipping evaluation.
# User 741505 not found in training data. Skipping evaluation.
# User 539451 not found in training data. Skipping evaluation.
# User 742898 not found in training data. Skipping evaluation.
# User 873155 not found in training data. Skipping evaluation.
# User 581492 not found in training data. Skipping evaluation.
# User 139884 not found in training data. Skipping evaluation.
# User 655705 not found in training data. Skipping evaluation.
# User 174111 not found in training data. Skipping evaluation.
# User 467351 not found in training data. Skipping evaluation.
# User 235056 not found in training data. Skipping evaluation.
# User 352845 not found in training data. Skipping evaluation.
# User 414346 not found in training data. Skipping evaluation.
# User 880569 not found in training data. Skipping evaluation.
# User 667471 not found in training data. Skipping evaluation.
# User 786634 not found in training data. Skipping evaluation.
# User 877590 not found in training data. Skipping evaluation.
# User 700797 not found in training data. Skipping evaluation.
# User 104655 not found in training data. Skipping evaluation.
# User 698525 not found in training data. Skipping evaluation.
# User 181428 not found in training data. Skipping evaluation.
# User 826711 not found in training data. Skipping evaluation.
# User 223943 not found in training data. Skipping evaluation.
# User 482893 not found in training data. Skipping evaluation.
# User 327999 not found in training data. Skipping evaluation.
# User 806600 not found in training data. Skipping evaluation.
# User 936344 not found in training data. Skipping evaluation.
# User 6178 not found in training data. Skipping evaluation.
# User 601310 not found in training data. Skipping evaluation.
# User 560652 not found in training data. Skipping evaluation.
# User 339899 not found in training data. Skipping evaluation.
# User 251985 not found in training data. Skipping evaluation.
# User 508336 not found in training data. Skipping evaluation.
# User 25841 not found in training data. Skipping evaluation.
# User 288610 not found in training data. Skipping evaluation.
# User 807581 not found in training data. Skipping evaluation.
# User 621541 not found in training data. Skipping evaluation.
# User 847369 not found in training data. Skipping evaluation.
# User 392466 not found in training data. Skipping evaluation.
# User 540165 not found in training data. Skipping evaluation.
# User 939959 not found in training data. Skipping evaluation.
# User 131913 not found in training data. Skipping evaluation.
# User 470696 not found in training data. Skipping evaluation.
# User 375558 not found in training data. Skipping evaluation.
# User 387613 not found in training data. Skipping evaluation.
# User 811271 not found in training data. Skipping evaluation.
# User 223897 not found in training data. Skipping evaluation.
# User 364919 not found in training data. Skipping evaluation.
# User 511023 not found in training data. Skipping evaluation.
# User 137298 not found in training data. Skipping evaluation.
# User 7754 not found in training data. Skipping evaluation.
# User 493357 not found in training data. Skipping evaluation.
# User 66954 not found in training data. Skipping evaluation.
# User 784726 not found in training data. Skipping evaluation.
# User 100457 not found in training data. Skipping evaluation.
# User 166678 not found in training data. Skipping evaluation.
# User 750282 not found in training data. Skipping evaluation.
# User 623946 not found in training data. Skipping evaluation.
# User 963146 not found in training data. Skipping evaluation.
# User 115744 not found in training data. Skipping evaluation.
# User 220840 not found in training data. Skipping evaluation.
# User 880436 not found in training data. Skipping evaluation.
# User 225070 not found in training data. Skipping evaluation.
# User 736552 not found in training data. Skipping evaluation.
# User 353326 not found in training data. Skipping evaluation.
# User 66079 not found in training data. Skipping evaluation.
# User 266717 not found in training data. Skipping evaluation.
# User 520730 not found in training data. Skipping evaluation.
# User 96762 not found in training data. Skipping evaluation.
# User 766971 not found in training data. Skipping evaluation.
# User 560294 not found in training data. Skipping evaluation.
# User 281229 not found in training data. Skipping evaluation.
# User 655536 not found in training data. Skipping evaluation.
# User 453024 not found in training data. Skipping evaluation.
# User 295627 not found in training data. Skipping evaluation.
# User 371892 not found in training data. Skipping evaluation.
# User 272690 not found in training data. Skipping evaluation.
# User 717181 not found in training data. Skipping evaluation.
# User 242042 not found in training data. Skipping evaluation.
# User 952119 not found in training data. Skipping evaluation.
# User 536050 not found in training data. Skipping evaluation.
# User 959160 not found in training data. Skipping evaluation.
# User 845030 not found in training data. Skipping evaluation.
# User 942618 not found in training data. Skipping evaluation.
# User 225435 not found in training data. Skipping evaluation.
# User 376304 not found in training data. Skipping evaluation.
# User 250828 not found in training data. Skipping evaluation.
# User 777291 not found in training data. Skipping evaluation.
# User 664388 not found in training data. Skipping evaluation.
# User 44523 not found in training data. Skipping evaluation.
# User 988691 not found in training data. Skipping evaluation.
# User 34768 not found in training data. Skipping evaluation.
# User 232640 not found in training data. Skipping evaluation.
# User 202639 not found in training data. Skipping evaluation.
# User 42515 not found in training data. Skipping evaluation.
# User 298694 not found in training data. Skipping evaluation.
# User 653594 not found in training data. Skipping evaluation.
# User 817290 not found in training data. Skipping evaluation.
# User 424138 not found in training data. Skipping evaluation.
# User 100362 not found in training data. Skipping evaluation.
# User 313355 not found in training data. Skipping evaluation.
# User 733152 not found in training data. Skipping evaluation.
# User 307440 not found in training data. Skipping evaluation.
# User 801364 not found in training data. Skipping evaluation.
# User 914606 not found in training data. Skipping evaluation.
# User 898726 not found in training data. Skipping evaluation.
# User 454572 not found in training data. Skipping evaluation.
# User 619349 not found in training data. Skipping evaluation.
# User 895448 not found in training data. Skipping evaluation.
# User 788678 not found in training data. Skipping evaluation.
# User 293351 not found in training data. Skipping evaluation.
# User 630306 not found in training data. Skipping evaluation.
# User 700181 not found in training data. Skipping evaluation.
# User 963136 not found in training data. Skipping evaluation.
# User 691104 not found in training data. Skipping evaluation.
# User 516831 not found in training data. Skipping evaluation.
# User 35836 not found in training data. Skipping evaluation.
# User 756638 not found in training data. Skipping evaluation.
# User 893654 not found in training data. Skipping evaluation.
# User 132995 not found in training data. Skipping evaluation.
# User 560820 not found in training data. Skipping evaluation.
# User 726884 not found in training data. Skipping evaluation.
# User 753824 not found in training data. Skipping evaluation.
# User 806423 not found in training data. Skipping evaluation.
# User 147361 not found in training data. Skipping evaluation.
# User 748215 not found in training data. Skipping evaluation.
# User 824111 not found in training data. Skipping evaluation.
# User 35 not found in training data. Skipping evaluation.
# User 566072 not found in training data. Skipping evaluation.
# User 326277 not found in training data. Skipping evaluation.
# User 463778 not found in training data. Skipping evaluation.
# User 191221 not found in training data. Skipping evaluation.
# User 695982 not found in training data. Skipping evaluation.
# User 407462 not found in training data. Skipping evaluation.
# User 829604 not found in training data. Skipping evaluation.
# User 332102 not found in training data. Skipping evaluation.
# User 913611 not found in training data. Skipping evaluation.
# User 756059 not found in training data. Skipping evaluation.
# User 554489 not found in training data. Skipping evaluation.
# User 714088 not found in training data. Skipping evaluation.
# User 677822 not found in training data. Skipping evaluation.
# User 49557 not found in training data. Skipping evaluation.
# User 70799 not found in training data. Skipping evaluation.
# User 753639 not found in training data. Skipping evaluation.
# User 230804 not found in training data. Skipping evaluation.
# User 44237 not found in training data. Skipping evaluation.
# User 640674 not found in training data. Skipping evaluation.
# User 231864 not found in training data. Skipping evaluation.
# User 868840 not found in training data. Skipping evaluation.
# User 987986 not found in training data. Skipping evaluation.
# User 582900 not found in training data. Skipping evaluation.
# User 59692 not found in training data. Skipping evaluation.
# User 182068 not found in training data. Skipping evaluation.
# User 499929 not found in training data. Skipping evaluation.
# User 428762 not found in training data. Skipping evaluation.
# User 614955 not found in training data. Skipping evaluation.
# User 107876 not found in training data. Skipping evaluation.
# User 542911 not found in training data. Skipping evaluation.
# User 446896 not found in training data. Skipping evaluation.
# User 262557 not found in training data. Skipping evaluation.
# User 529649 not found in training data. Skipping evaluation.
# User 883596 not found in training data. Skipping evaluation.
# User 687849 not found in training data. Skipping evaluation.
# User 940158 not found in training data. Skipping evaluation.
# User 352754 not found in training data. Skipping evaluation.
# User 590474 not found in training data. Skipping evaluation.
# User 337541 not found in training data. Skipping evaluation.
# User 288353 not found in training data. Skipping evaluation.
# User 318179 not found in training data. Skipping evaluation.
# User 776529 not found in training data. Skipping evaluation.
# User 545560 not found in training data. Skipping evaluation.
# User 758632 not found in training data. Skipping evaluation.
# User 372933 not found in training data. Skipping evaluation.
# User 819746 not found in training data. Skipping evaluation.
# User 398417 not found in training data. Skipping evaluation.
# User 657865 not found in training data. Skipping evaluation.
# User 160229 not found in training data. Skipping evaluation.
# User 249896 not found in training data. Skipping evaluation.
# User 597555 not found in training data. Skipping evaluation.
# User 976904 not found in training data. Skipping evaluation.
# User 433396 not found in training data. Skipping evaluation.
# User 368014 not found in training data. Skipping evaluation.
# User 345652 not found in training data. Skipping evaluation.
# User 716440 not found in training data. Skipping evaluation.
# User 4914 not found in training data. Skipping evaluation.
# User 878032 not found in training data. Skipping evaluation.
# User 355937 not found in training data. Skipping evaluation.
# User 810527 not found in training data. Skipping evaluation.
# User 600430 not found in training data. Skipping evaluation.
# User 206179 not found in training data. Skipping evaluation.
# User 199055 not found in training data. Skipping evaluation.
# User 203965 not found in training data. Skipping evaluation.
# User 401565 not found in training data. Skipping evaluation.
# User 87400 not found in training data. Skipping evaluation.
# User 488148 not found in training data. Skipping evaluation.
# User 697165 not found in training data. Skipping evaluation.
# User 630678 not found in training data. Skipping evaluation.
# User 63659 not found in training data. Skipping evaluation.
# User 632017 not found in training data. Skipping evaluation.
# User 204149 not found in training data. Skipping evaluation.
# User 105428 not found in training data. Skipping evaluation.
# User 888818 not found in training data. Skipping evaluation.
# User 303943 not found in training data. Skipping evaluation.
# User 496456 not found in training data. Skipping evaluation.
# User 351722 not found in training data. Skipping evaluation.
# User 638947 not found in training data. Skipping evaluation.
# User 836346 not found in training data. Skipping evaluation.
# User 974966 not found in training data. Skipping evaluation.
# User 507270 not found in training data. Skipping evaluation.
# User 511943 not found in training data. Skipping evaluation.
# User 146235 not found in training data. Skipping evaluation.
# User 221737 not found in training data. Skipping evaluation.
# User 412650 not found in training data. Skipping evaluation.
# User 109577 not found in training data. Skipping evaluation.
# User 80805 not found in training data. Skipping evaluation.
# User 859964 not found in training data. Skipping evaluation.
# User 721851 not found in training data. Skipping evaluation.
# User 887111 not found in training data. Skipping evaluation.
# User 809077 not found in training data. Skipping evaluation.
# User 550361 not found in training data. Skipping evaluation.
# User 518289 not found in training data. Skipping evaluation.
# User 492698 not found in training data. Skipping evaluation.
# User 253863 not found in training data. Skipping evaluation.
# User 158214 not found in training data. Skipping evaluation.
# User 792619 not found in training data. Skipping evaluation.
# User 234668 not found in training data. Skipping evaluation.
# User 326171 not found in training data. Skipping evaluation.
# User 537790 not found in training data. Skipping evaluation.
# User 564829 not found in training data. Skipping evaluation.
# User 304660 not found in training data. Skipping evaluation.
# User 145305 not found in training data. Skipping evaluation.
# User 182490 not found in training data. Skipping evaluation.
# User 682532 not found in training data. Skipping evaluation.
# User 644297 not found in training data. Skipping evaluation.
# User 779798 not found in training data. Skipping evaluation.
# User 629898 not found in training data. Skipping evaluation.
# User 74777 not found in training data. Skipping evaluation.
# User 573164 not found in training data. Skipping evaluation.
# User 462553 not found in training data. Skipping evaluation.
# User 402385 not found in training data. Skipping evaluation.
# User 659747 not found in training data. Skipping evaluation.
# User 52573 not found in training data. Skipping evaluation.
# User 371038 not found in training data. Skipping evaluation.
# User 735923 not found in training data. Skipping evaluation.
# User 429827 not found in training data. Skipping evaluation.
# User 628834 not found in training data. Skipping evaluation.
# User 679250 not found in training data. Skipping evaluation.
# User 939432 not found in training data. Skipping evaluation.
# User 10861 not found in training data. Skipping evaluation.
# User 628022 not found in training data. Skipping evaluation.
# User 315223 not found in training data. Skipping evaluation.
# User 800626 not found in training data. Skipping evaluation.
# User 685128 not found in training data. Skipping evaluation.
# User 819897 not found in training data. Skipping evaluation.
# User 204312 not found in training data. Skipping evaluation.
# User 759112 not found in training data. Skipping evaluation.
# User 386826 not found in training data. Skipping evaluation.
# User 129277 not found in training data. Skipping evaluation.
# User 418491 not found in training data. Skipping evaluation.
# User 878239 not found in training data. Skipping evaluation.
# User 321 not found in training data. Skipping evaluation.
# User 854638 not found in training data. Skipping evaluation.
# User 546038 not found in training data. Skipping evaluation.
# User 328714 not found in training data. Skipping evaluation.
# User 33753 not found in training data. Skipping evaluation.
# User 457554 not found in training data. Skipping evaluation.
# User 618883 not found in training data. Skipping evaluation.
# User 303646 not found in training data. Skipping evaluation.
# User 738284 not found in training data. Skipping evaluation.
# User 580441 not found in training data. Skipping evaluation.
# User 350079 not found in training data. Skipping evaluation.
# User 835693 not found in training data. Skipping evaluation.
# User 800507 not found in training data. Skipping evaluation.
# User 691287 not found in training data. Skipping evaluation.
# User 329403 not found in training data. Skipping evaluation.
# User 571167 not found in training data. Skipping evaluation.
# User 341845 not found in training data. Skipping evaluation.
# User 539437 not found in training data. Skipping evaluation.
# User 372055 not found in training data. Skipping evaluation.
# User 666805 not found in training data. Skipping evaluation.
# User 761634 not found in training data. Skipping evaluation.
# User 692911 not found in training data. Skipping evaluation.
# User 756586 not found in training data. Skipping evaluation.
# User 990369 not found in training data. Skipping evaluation.
# User 669132 not found in training data. Skipping evaluation.
# User 862919 not found in training data. Skipping evaluation.
# User 190381 not found in training data. Skipping evaluation.
# User 810791 not found in training data. Skipping evaluation.
# User 569491 not found in training data. Skipping evaluation.
# User 569368 not found in training data. Skipping evaluation.
# User 299230 not found in training data. Skipping evaluation.
# User 506128 not found in training data. Skipping evaluation.
# User 729919 not found in training data. Skipping evaluation.
# User 158309 not found in training data. Skipping evaluation.
# User 298193 not found in training data. Skipping evaluation.
# User 371968 not found in training data. Skipping evaluation.
# User 401965 not found in training data. Skipping evaluation.
# User 480448 not found in training data. Skipping evaluation.
# User 412596 not found in training data. Skipping evaluation.
# User 87079 not found in training data. Skipping evaluation.
# User 291157 not found in training data. Skipping evaluation.
# User 743376 not found in training data. Skipping evaluation.
# User 820669 not found in training data. Skipping evaluation.
# User 299742 not found in training data. Skipping evaluation.
# User 882850 not found in training data. Skipping evaluation.
# User 231306 not found in training data. Skipping evaluation.
# User 412273 not found in training data. Skipping evaluation.
# User 414134 not found in training data. Skipping evaluation.
# User 508931 not found in training data. Skipping evaluation.
# User 875654 not found in training data. Skipping evaluation.
# User 936496 not found in training data. Skipping evaluation.
# User 841141 not found in training data. Skipping evaluation.
# User 780334 not found in training data. Skipping evaluation.
# User 955214 not found in training data. Skipping evaluation.
# User 680978 not found in training data. Skipping evaluation.
# User 842169 not found in training data. Skipping evaluation.
# User 957813 not found in training data. Skipping evaluation.
# User 481757 not found in training data. Skipping evaluation.
# User 423903 not found in training data. Skipping evaluation.
# User 549985 not found in training data. Skipping evaluation.
# User 988275 not found in training data. Skipping evaluation.
# User 27497 not found in training data. Skipping evaluation.
# User 718587 not found in training data. Skipping evaluation.
# User 135389 not found in training data. Skipping evaluation.
# User 66452 not found in training data. Skipping evaluation.
# User 842485 not found in training data. Skipping evaluation.
# User 713616 not found in training data. Skipping evaluation.
# User 805395 not found in training data. Skipping evaluation.
# User 525188 not found in training data. Skipping evaluation.
# User 581694 not found in training data. Skipping evaluation.
# User 107956 not found in training data. Skipping evaluation.
# User 682179 not found in training data. Skipping evaluation.
# User 449666 not found in training data. Skipping evaluation.
# User 144604 not found in training data. Skipping evaluation.
# User 451304 not found in training data. Skipping evaluation.
# User 326790 not found in training data. Skipping evaluation.
# User 623617 not found in training data. Skipping evaluation.
# User 644536 not found in training data. Skipping evaluation.
# User 904114 not found in training data. Skipping evaluation.
# User 885844 not found in training data. Skipping evaluation.
# User 943258 not found in training data. Skipping evaluation.
# User 466255 not found in training data. Skipping evaluation.
# User 990470 not found in training data. Skipping evaluation.
# User 938744 not found in training data. Skipping evaluation.
# User 732559 not found in training data. Skipping evaluation.
# User 69799 not found in training data. Skipping evaluation.
# User 967025 not found in training data. Skipping evaluation.
# User 564450 not found in training data. Skipping evaluation.
# User 649100 not found in training data. Skipping evaluation.
# User 126396 not found in training data. Skipping evaluation.
# User 765381 not found in training data. Skipping evaluation.
# User 375708 not found in training data. Skipping evaluation.
# User 493984 not found in training data. Skipping evaluation.
# User 829679 not found in training data. Skipping evaluation.
# User 458837 not found in training data. Skipping evaluation.
# User 843915 not found in training data. Skipping evaluation.
# User 108645 not found in training data. Skipping evaluation.
# User 149493 not found in training data. Skipping evaluation.
# User 487381 not found in training data. Skipping evaluation.
# User 636493 not found in training data. Skipping evaluation.
# User 597482 not found in training data. Skipping evaluation.
# User 619030 not found in training data. Skipping evaluation.
# User 189546 not found in training data. Skipping evaluation.
# User 869584 not found in training data. Skipping evaluation.
# User 587828 not found in training data. Skipping evaluation.
# User 856255 not found in training data. Skipping evaluation.
# User 764414 not found in training data. Skipping evaluation.
# User 924612 not found in training data. Skipping evaluation.
# User 750750 not found in training data. Skipping evaluation.
# User 220121 not found in training data. Skipping evaluation.
# User 228972 not found in training data. Skipping evaluation.
# User 439613 not found in training data. Skipping evaluation.
# User 562497 not found in training data. Skipping evaluation.
# User 354525 not found in training data. Skipping evaluation.
# User 970382 not found in training data. Skipping evaluation.
# User 250921 not found in training data. Skipping evaluation.
# User 391120 not found in training data. Skipping evaluation.
# User 765020 not found in training data. Skipping evaluation.
# User 612090 not found in training data. Skipping evaluation.
# User 910750 not found in training data. Skipping evaluation.
# User 622251 not found in training data. Skipping evaluation.
# User 756743 not found in training data. Skipping evaluation.
# User 978533 not found in training data. Skipping evaluation.
# User 215035 not found in training data. Skipping evaluation.
# User 480435 not found in training data. Skipping evaluation.
# User 521093 not found in training data. Skipping evaluation.
# User 294013 not found in training data. Skipping evaluation.
# User 409585 not found in training data. Skipping evaluation.
# User 481417 not found in training data. Skipping evaluation.
# User 740045 not found in training data. Skipping evaluation.
# User 752731 not found in training data. Skipping evaluation.
# User 747161 not found in training data. Skipping evaluation.
# User 356136 not found in training data. Skipping evaluation.
# User 600718 not found in training data. Skipping evaluation.
# User 351646 not found in training data. Skipping evaluation.
# User 209003 not found in training data. Skipping evaluation.
# User 213306 not found in training data. Skipping evaluation.
# User 707929 not found in training data. Skipping evaluation.
# User 112175 not found in training data. Skipping evaluation.
# User 786848 not found in training data. Skipping evaluation.
# User 747922 not found in training data. Skipping evaluation.
# User 802859 not found in training data. Skipping evaluation.
# User 737406 not found in training data. Skipping evaluation.
# User 511481 not found in training data. Skipping evaluation.
# User 484832 not found in training data. Skipping evaluation.
# User 303644 not found in training data. Skipping evaluation.
# User 701079 not found in training data. Skipping evaluation.
# User 897269 not found in training data. Skipping evaluation.
# User 979986 not found in training data. Skipping evaluation.
# User 400697 not found in training data. Skipping evaluation.
# User 855488 not found in training data. Skipping evaluation.
# User 198071 not found in training data. Skipping evaluation.
# User 84355 not found in training data. Skipping evaluation.
# User 829606 not found in training data. Skipping evaluation.
# User 662180 not found in training data. Skipping evaluation.
# User 798597 not found in training data. Skipping evaluation.
# User 667526 not found in training data. Skipping evaluation.
# User 339064 not found in training data. Skipping evaluation.
# User 300186 not found in training data. Skipping evaluation.
# User 689010 not found in training data. Skipping evaluation.
# User 585245 not found in training data. Skipping evaluation.
# User 691841 not found in training data. Skipping evaluation.
# User 511315 not found in training data. Skipping evaluation.
# User 209766 not found in training data. Skipping evaluation.
# User 447536 not found in training data. Skipping evaluation.
# User 268165 not found in training data. Skipping evaluation.
# User 893015 not found in training data. Skipping evaluation.
# User 769826 not found in training data. Skipping evaluation.
# User 573508 not found in training data. Skipping evaluation.
# User 621969 not found in training data. Skipping evaluation.
# User 495333 not found in training data. Skipping evaluation.
# User 314764 not found in training data. Skipping evaluation.
# User 985934 not found in training data. Skipping evaluation.
# User 694566 not found in training data. Skipping evaluation.
# User 318806 not found in training data. Skipping evaluation.
# User 412461 not found in training data. Skipping evaluation.
# User 187061 not found in training data. Skipping evaluation.
# User 463401 not found in training data. Skipping evaluation.
# User 408895 not found in training data. Skipping evaluation.
# User 670880 not found in training data. Skipping evaluation.
# User 717973 not found in training data. Skipping evaluation.
# User 262493 not found in training data. Skipping evaluation.
# User 853121 not found in training data. Skipping evaluation.
# User 527975 not found in training data. Skipping evaluation.
# User 208728 not found in training data. Skipping evaluation.
# User 546705 not found in training data. Skipping evaluation.
# User 911866 not found in training data. Skipping evaluation.
# User 982193 not found in training data. Skipping evaluation.
# User 300285 not found in training data. Skipping evaluation.
# User 300074 not found in training data. Skipping evaluation.
# User 760586 not found in training data. Skipping evaluation.
# User 652681 not found in training data. Skipping evaluation.
# User 598379 not found in training data. Skipping evaluation.
# User 980109 not found in training data. Skipping evaluation.
# User 114230 not found in training data. Skipping evaluation.
# User 985680 not found in training data. Skipping evaluation.
# User 801249 not found in training data. Skipping evaluation.
# User 220393 not found in training data. Skipping evaluation.
# User 675047 not found in training data. Skipping evaluation.
# User 166549 not found in training data. Skipping evaluation.
# User 367839 not found in training data. Skipping evaluation.
# User 323037 not found in training data. Skipping evaluation.
# User 455442 not found in training data. Skipping evaluation.
# User 151698 not found in training data. Skipping evaluation.
# User 150679 not found in training data. Skipping evaluation.
# User 177677 not found in training data. Skipping evaluation.
# User 614842 not found in training data. Skipping evaluation.
# User 444255 not found in training data. Skipping evaluation.
# User 555186 not found in training data. Skipping evaluation.
# User 443836 not found in training data. Skipping evaluation.
# User 76199 not found in training data. Skipping evaluation.
# User 14177 not found in training data. Skipping evaluation.
# User 46304 not found in training data. Skipping evaluation.
# User 461265 not found in training data. Skipping evaluation.
# User 783260 not found in training data. Skipping evaluation.
# User 865955 not found in training data. Skipping evaluation.
# User 610571 not found in training data. Skipping evaluation.
# User 467366 not found in training data. Skipping evaluation.
# User 947909 not found in training data. Skipping evaluation.
# User 973896 not found in training data. Skipping evaluation.
# User 670794 not found in training data. Skipping evaluation.
# User 478762 not found in training data. Skipping evaluation.
# User 76807 not found in training data. Skipping evaluation.
# User 498518 not found in training data. Skipping evaluation.
# User 437798 not found in training data. Skipping evaluation.
# User 135324 not found in training data. Skipping evaluation.
# User 234236 not found in training data. Skipping evaluation.
# User 784866 not found in training data. Skipping evaluation.
# User 381099 not found in training data. Skipping evaluation.
# User 541692 not found in training data. Skipping evaluation.
# User 318636 not found in training data. Skipping evaluation.
# User 727057 not found in training data. Skipping evaluation.
# User 814418 not found in training data. Skipping evaluation.
# User 627660 not found in training data. Skipping evaluation.
# User 176399 not found in training data. Skipping evaluation.
# User 190329 not found in training data. Skipping evaluation.
# User 305802 not found in training data. Skipping evaluation.
# User 282643 not found in training data. Skipping evaluation.
# User 632389 not found in training data. Skipping evaluation.
# User 569488 not found in training data. Skipping evaluation.
# User 323946 not found in training data. Skipping evaluation.
# User 907707 not found in training data. Skipping evaluation.
# User 936583 not found in training data. Skipping evaluation.
# User 550831 not found in training data. Skipping evaluation.
# User 867537 not found in training data. Skipping evaluation.
# User 134526 not found in training data. Skipping evaluation.
# User 957250 not found in training data. Skipping evaluation.
# User 754446 not found in training data. Skipping evaluation.
# User 63755 not found in training data. Skipping evaluation.
# User 976118 not found in training data. Skipping evaluation.
# User 49161 not found in training data. Skipping evaluation.
# User 260985 not found in training data. Skipping evaluation.
# User 535580 not found in training data. Skipping evaluation.
# User 458706 not found in training data. Skipping evaluation.
# User 166007 not found in training data. Skipping evaluation.
# User 600867 not found in training data. Skipping evaluation.
# User 255984 not found in training data. Skipping evaluation.
# User 390966 not found in training data. Skipping evaluation.
# User 11392 not found in training data. Skipping evaluation.
# User 588856 not found in training data. Skipping evaluation.
# User 13009 not found in training data. Skipping evaluation.
# User 664123 not found in training data. Skipping evaluation.
# User 15931 not found in training data. Skipping evaluation.
# User 661704 not found in training data. Skipping evaluation.
# User 984042 not found in training data. Skipping evaluation.
# User 587705 not found in training data. Skipping evaluation.
# User 403662 not found in training data. Skipping evaluation.
# User 40699 not found in training data. Skipping evaluation.
# User 527047 not found in training data. Skipping evaluation.
# User 322081 not found in training data. Skipping evaluation.
# User 785905 not found in training data. Skipping evaluation.
# User 371592 not found in training data. Skipping evaluation.
# User 561770 not found in training data. Skipping evaluation.
# User 559273 not found in training data. Skipping evaluation.
# User 664767 not found in training data. Skipping evaluation.
# User 567101 not found in training data. Skipping evaluation.
# User 577420 not found in training data. Skipping evaluation.
# User 244296 not found in training data. Skipping evaluation.
# User 637189 not found in training data. Skipping evaluation.
# User 366010 not found in training data. Skipping evaluation.
# User 539728 not found in training data. Skipping evaluation.
# User 467250 not found in training data. Skipping evaluation.
# User 746886 not found in training data. Skipping evaluation.
# User 260992 not found in training data. Skipping evaluation.
# User 725295 not found in training data. Skipping evaluation.
# User 729760 not found in training data. Skipping evaluation.
# User 328318 not found in training data. Skipping evaluation.
# User 441078 not found in training data. Skipping evaluation.
# User 95559 not found in training data. Skipping evaluation.
# User 975381 not found in training data. Skipping evaluation.
# User 962572 not found in training data. Skipping evaluation.
# User 564818 not found in training data. Skipping evaluation.
# User 586117 not found in training data. Skipping evaluation.
# User 52424 not found in training data. Skipping evaluation.
# User 249788 not found in training data. Skipping evaluation.
# User 293200 not found in training data. Skipping evaluation.
# User 891063 not found in training data. Skipping evaluation.
# User 573806 not found in training data. Skipping evaluation.
# User 628872 not found in training data. Skipping evaluation.
# User 197317 not found in training data. Skipping evaluation.
# User 477581 not found in training data. Skipping evaluation.
# User 128530 not found in training data. Skipping evaluation.
# User 67455 not found in training data. Skipping evaluation.
# User 987172 not found in training data. Skipping evaluation.
# User 399627 not found in training data. Skipping evaluation.
# User 438718 not found in training data. Skipping evaluation.
# User 198359 not found in training data. Skipping evaluation.
# User 937263 not found in training data. Skipping evaluation.
# User 3521 not found in training data. Skipping evaluation.
# User 189324 not found in training data. Skipping evaluation.
# User 131821 not found in training data. Skipping evaluation.
# User 535918 not found in training data. Skipping evaluation.
# User 207452 not found in training data. Skipping evaluation.
# User 424928 not found in training data. Skipping evaluation.
# User 901840 not found in training data. Skipping evaluation.
# User 491752 not found in training data. Skipping evaluation.
# User 542847 not found in training data. Skipping evaluation.
# User 562382 not found in training data. Skipping evaluation.
# User 153072 not found in training data. Skipping evaluation.
# User 921163 not found in training data. Skipping evaluation.
# User 369187 not found in training data. Skipping evaluation.
# User 706855 not found in training data. Skipping evaluation.
# User 572361 not found in training data. Skipping evaluation.
# User 112528 not found in training data. Skipping evaluation.
# User 93272 not found in training data. Skipping evaluation.
# User 699274 not found in training data. Skipping evaluation.
# User 778362 not found in training data. Skipping evaluation.
# User 186420 not found in training data. Skipping evaluation.
# User 399178 not found in training data. Skipping evaluation.
# User 94684 not found in training data. Skipping evaluation.
# User 811999 not found in training data. Skipping evaluation.
# User 535438 not found in training data. Skipping evaluation.
# User 605788 not found in training data. Skipping evaluation.
# User 235556 not found in training data. Skipping evaluation.
# User 606944 not found in training data. Skipping evaluation.
# User 213848 not found in training data. Skipping evaluation.
# User 272266 not found in training data. Skipping evaluation.
# User 785590 not found in training data. Skipping evaluation.
# User 792966 not found in training data. Skipping evaluation.
# User 497503 not found in training data. Skipping evaluation.
# User 245342 not found in training data. Skipping evaluation.
# User 363358 not found in training data. Skipping evaluation.
# User 829214 not found in training data. Skipping evaluation.
# User 396100 not found in training data. Skipping evaluation.
# User 326209 not found in training data. Skipping evaluation.
# User 836746 not found in training data. Skipping evaluation.
# User 942 not found in training data. Skipping evaluation.
# User 896818 not found in training data. Skipping evaluation.
# User 404963 not found in training data. Skipping evaluation.
# User 509966 not found in training data. Skipping evaluation.
# User 489594 not found in training data. Skipping evaluation.
# User 867463 not found in training data. Skipping evaluation.
# User 367526 not found in training data. Skipping evaluation.
# User 434812 not found in training data. Skipping evaluation.
# User 675796 not found in training data. Skipping evaluation.
# User 537729 not found in training data. Skipping evaluation.
# User 486610 not found in training data. Skipping evaluation.
# User 332 not found in training data. Skipping evaluation.
# User 635451 not found in training data. Skipping evaluation.
# User 932710 not found in training data. Skipping evaluation.
# User 558575 not found in training data. Skipping evaluation.
# User 67478 not found in training data. Skipping evaluation.
# User 172742 not found in training data. Skipping evaluation.
# User 171104 not found in training data. Skipping evaluation.
# User 279667 not found in training data. Skipping evaluation.
# User 737697 not found in training data. Skipping evaluation.
# User 637745 not found in training data. Skipping evaluation.
# User 168221 not found in training data. Skipping evaluation.
# User 712518 not found in training data. Skipping evaluation.
# User 910927 not found in training data. Skipping evaluation.
# User 94458 not found in training data. Skipping evaluation.
# User 883379 not found in training data. Skipping evaluation.
# User 633931 not found in training data. Skipping evaluation.
# User 90382 not found in training data. Skipping evaluation.
# User 40266 not found in training data. Skipping evaluation.
# User 25262 not found in training data. Skipping evaluation.
# User 376571 not found in training data. Skipping evaluation.
# User 480676 not found in training data. Skipping evaluation.
# User 388488 not found in training data. Skipping evaluation.
# User 342859 not found in training data. Skipping evaluation.
# User 432017 not found in training data. Skipping evaluation.
# User 305091 not found in training data. Skipping evaluation.
# User 718023 not found in training data. Skipping evaluation.
# User 911745 not found in training data. Skipping evaluation.
# User 598903 not found in training data. Skipping evaluation.
# User 491466 not found in training data. Skipping evaluation.
# User 47317 not found in training data. Skipping evaluation.
# User 582072 not found in training data. Skipping evaluation.
# User 377407 not found in training data. Skipping evaluation.
# User 787286 not found in training data. Skipping evaluation.
# User 707353 not found in training data. Skipping evaluation.
# User 852540 not found in training data. Skipping evaluation.
# User 995731 not found in training data. Skipping evaluation.
# User 586111 not found in training data. Skipping evaluation.
# User 912941 not found in training data. Skipping evaluation.
# User 445267 not found in training data. Skipping evaluation.
# User 704084 not found in training data. Skipping evaluation.
# User 627668 not found in training data. Skipping evaluation.
# User 952408 not found in training data. Skipping evaluation.
# User 745989 not found in training data. Skipping evaluation.
# User 45800 not found in training data. Skipping evaluation.
# User 960778 not found in training data. Skipping evaluation.
# User 771450 not found in training data. Skipping evaluation.
# User 483552 not found in training data. Skipping evaluation.
# User 257420 not found in training data. Skipping evaluation.
# User 971864 not found in training data. Skipping evaluation.
# User 462980 not found in training data. Skipping evaluation.
# User 991556 not found in training data. Skipping evaluation.
# User 48514 not found in training data. Skipping evaluation.
# User 911594 not found in training data. Skipping evaluation.
# User 786639 not found in training data. Skipping evaluation.
# User 85200 not found in training data. Skipping evaluation.
# User 968542 not found in training data. Skipping evaluation.
# User 468552 not found in training data. Skipping evaluation.
# User 136390 not found in training data. Skipping evaluation.
# User 265423 not found in training data. Skipping evaluation.
# User 238480 not found in training data. Skipping evaluation.
# User 770112 not found in training data. Skipping evaluation.
# User 594966 not found in training data. Skipping evaluation.
# User 896742 not found in training data. Skipping evaluation.
# User 900230 not found in training data. Skipping evaluation.
# User 536483 not found in training data. Skipping evaluation.
# User 582665 not found in training data. Skipping evaluation.
# User 768250 not found in training data. Skipping evaluation.
# User 351508 not found in training data. Skipping evaluation.
# User 975051 not found in training data. Skipping evaluation.
# User 717696 not found in training data. Skipping evaluation.
# User 600307 not found in training data. Skipping evaluation.
# User 520918 not found in training data. Skipping evaluation.
# User 455656 not found in training data. Skipping evaluation.
# User 207069 not found in training data. Skipping evaluation.
# User 890698 not found in training data. Skipping evaluation.
# User 763093 not found in training data. Skipping evaluation.
# User 731862 not found in training data. Skipping evaluation.
# User 542855 not found in training data. Skipping evaluation.
# User 678 not found in training data. Skipping evaluation.
# User 141597 not found in training data. Skipping evaluation.
# User 122522 not found in training data. Skipping evaluation.
# User 580708 not found in training data. Skipping evaluation.
# User 303282 not found in training data. Skipping evaluation.
# User 413115 not found in training data. Skipping evaluation.
# User 426746 not found in training data. Skipping evaluation.
# User 832277 not found in training data. Skipping evaluation.
# User 720718 not found in training data. Skipping evaluation.
# User 111181 not found in training data. Skipping evaluation.
# User 875810 not found in training data. Skipping evaluation.
# User 956144 not found in training data. Skipping evaluation.
# User 896964 not found in training data. Skipping evaluation.
# User 727848 not found in training data. Skipping evaluation.
# User 745553 not found in training data. Skipping evaluation.
# User 69343 not found in training data. Skipping evaluation.
# User 270224 not found in training data. Skipping evaluation.
# User 105893 not found in training data. Skipping evaluation.
# User 32911 not found in training data. Skipping evaluation.
# User 834257 not found in training data. Skipping evaluation.
# User 187590 not found in training data. Skipping evaluation.
# User 295950 not found in training data. Skipping evaluation.
# User 549123 not found in training data. Skipping evaluation.
# User 524834 not found in training data. Skipping evaluation.
# User 744829 not found in training data. Skipping evaluation.
# User 842905 not found in training data. Skipping evaluation.
# User 717817 not found in training data. Skipping evaluation.
# User 793437 not found in training data. Skipping evaluation.
# User 141112 not found in training data. Skipping evaluation.
# User 747075 not found in training data. Skipping evaluation.
# User 620597 not found in training data. Skipping evaluation.
# User 112258 not found in training data. Skipping evaluation.
# User 164789 not found in training data. Skipping evaluation.
# User 763963 not found in training data. Skipping evaluation.
# User 108266 not found in training data. Skipping evaluation.
# User 188686 not found in training data. Skipping evaluation.
# User 800019 not found in training data. Skipping evaluation.
# User 115072 not found in training data. Skipping evaluation.
# User 982462 not found in training data. Skipping evaluation.
# User 531285 not found in training data. Skipping evaluation.
# User 757514 not found in training data. Skipping evaluation.
# User 429970 not found in training data. Skipping evaluation.
# User 139783 not found in training data. Skipping evaluation.
# User 964117 not found in training data. Skipping evaluation.
# User 884763 not found in training data. Skipping evaluation.
# User 717963 not found in training data. Skipping evaluation.
# User 694013 not found in training data. Skipping evaluation.
# User 144050 not found in training data. Skipping evaluation.
# User 708291 not found in training data. Skipping evaluation.
# User 169215 not found in training data. Skipping evaluation.
# User 514331 not found in training data. Skipping evaluation.
# User 140761 not found in training data. Skipping evaluation.
# User 857890 not found in training data. Skipping evaluation.
# User 183488 not found in training data. Skipping evaluation.
# User 121825 not found in training data. Skipping evaluation.
# User 796355 not found in training data. Skipping evaluation.
# User 945200 not found in training data. Skipping evaluation.
# User 84739 not found in training data. Skipping evaluation.
# User 238967 not found in training data. Skipping evaluation.
# User 298520 not found in training data. Skipping evaluation.
# User 880762 not found in training data. Skipping evaluation.
# ...
# User 707988 not found in training data. Skipping evaluation.
# User 355537 not found in training data. Skipping evaluation.
# User 294913 not found in training data. Skipping evaluation.
# User 44953 not found in training data. Skipping evaluation.
# User 485648 not found in training data. Skipping evaluation.
# User 268303 not found in training data. Skipping evaluation.
# User 905693 not found in training data. Skipping evaluation.
# User 249174 not found in training data. Skipping evaluation.
# User 652439 not found in training data. Skipping evaluation.
# User 419600 not found in training data. Skipping evaluation.
# User 973935 not found in training data. Skipping evaluation.
# User 153590 not found in training data. Skipping evaluation.
# User 373194 not found in training data. Skipping evaluation.
# User 634890 not found in training data. Skipping evaluation.
# User 646626 not found in training data. Skipping evaluation.
# User 817212 not found in training data. Skipping evaluation.
# User 360246 not found in training data. Skipping evaluation.
# User 88928 not found in training data. Skipping evaluation.
# User 446034 not found in training data. Skipping evaluation.
# User 417338 not found in training data. Skipping evaluation.
# User 152221 not found in training data. Skipping evaluation.
# User 227238 not found in training data. Skipping evaluation.
# User 843261 not found in training data. Skipping evaluation.
# User 820288 not found in training data. Skipping evaluation.
# User 519408 not found in training data. Skipping evaluation.
# User 578567 not found in training data. Skipping evaluation.
# User 57196 not found in training data. Skipping evaluation.
# User 471929 not found in training data. Skipping evaluation.
# User 453578 not found in training data. Skipping evaluation.
# User 959863 not found in training data. Skipping evaluation.
# User 403613 not found in training data. Skipping evaluation.
# User 62326 not found in training data. Skipping evaluation.
# User 921495 not found in training data. Skipping evaluation.
# User 854489 not found in training data. Skipping evaluation.
# User 820546 not found in training data. Skipping evaluation.
# User 545663 not found in training data. Skipping evaluation.
# User 443153 not found in training data. Skipping evaluation.
# User 919395 not found in training data. Skipping evaluation.
# User 698260 not found in training data. Skipping evaluation.
# User 792289 not found in training data. Skipping evaluation.
# User 815864 not found in training data. Skipping evaluation.
# User 339281 not found in training data. Skipping evaluation.
# User 931949 not found in training data. Skipping evaluation.
# User 322467 not found in training data. Skipping evaluation.
# User 853956 not found in training data. Skipping evaluation.
# User 983726 not found in training data. Skipping evaluation.
# User 435460 not found in training data. Skipping evaluation.
# User 882762 not found in training data. Skipping evaluation.
# User 155885 not found in training data. Skipping evaluation.
# User 165722 not found in training data. Skipping evaluation.
# User 271261 not found in training data. Skipping evaluation.
# User 180460 not found in training data. Skipping evaluation.
# User 329882 not found in training data. Skipping evaluation.
# User 265077 not found in training data. Skipping evaluation.
# User 918150 not found in training data. Skipping evaluation.
# User 575735 not found in training data. Skipping evaluation.
# User 839941 not found in training data. Skipping evaluation.
# User 410656 not found in training data. Skipping evaluation.
# User 916455 not found in training data. Skipping evaluation.
# User 748301 not found in training data. Skipping evaluation.
# User 802163 not found in training data. Skipping evaluation.
# User 302919 not found in training data. Skipping evaluation.
# User 955725 not found in training data. Skipping evaluation.
# User 215656 not found in training data. Skipping evaluation.
# User 379415 not found in training data. Skipping evaluation.
# User 446338 not found in training data. Skipping evaluation.
# User 861493 not found in training data. Skipping evaluation.
# User 527155 not found in training data. Skipping evaluation.
# User 539011 not found in training data. Skipping evaluation.
# User 383515 not found in training data. Skipping evaluation.
# User 385133 not found in training data. Skipping evaluation.
# User 680224 not found in training data. Skipping evaluation.
# User 118893 not found in training data. Skipping evaluation.
# User 347899 not found in training data. Skipping evaluation.
# User 515360 not found in training data. Skipping evaluation.
# User 264765 not found in training data. Skipping evaluation.
# User 236315 not found in training data. Skipping evaluation.
# User 392585 not found in training data. Skipping evaluation.
# User 294576 not found in training data. Skipping evaluation.
# User 38366 not found in training data. Skipping evaluation.
# User 915013 not found in training data. Skipping evaluation.
# User 568366 not found in training data. Skipping evaluation.
# User 892346 not found in training data. Skipping evaluation.
# User 649160 not found in training data. Skipping evaluation.
# User 231820 not found in training data. Skipping evaluation.
# User 125283 not found in training data. Skipping evaluation.
# User 104912 not found in training data. Skipping evaluation.
# User 827608 not found in training data. Skipping evaluation.
# User 438491 not found in training data. Skipping evaluation.
# User 125885 not found in training data. Skipping evaluation.
# User 102248 not found in training data. Skipping evaluation.
# User 321135 not found in training data. Skipping evaluation.
# User 177699 not found in training data. Skipping evaluation.
# User 100710 not found in training data. Skipping evaluation.
# User 115639 not found in training data. Skipping evaluation.
# User 799297 not found in training data. Skipping evaluation.
# User 265971 not found in training data. Skipping evaluation.
# User 957130 not found in training data. Skipping evaluation.
# User 66396 not found in training data. Skipping evaluation.
# User 69716 not found in training data. Skipping evaluation.
# User 192564 not found in training data. Skipping evaluation.
# User 522482 not found in training data. Skipping evaluation.
# User 206463 not found in training data. Skipping evaluation.
# User 519109 not found in training data. Skipping evaluation.
# User 747257 not found in training data. Skipping evaluation.
# User 353508 not found in training data. Skipping evaluation.
# User 43488 not found in training data. Skipping evaluation.
# User 996090 not found in training data. Skipping evaluation.
# User 814803 not found in training data. Skipping evaluation.
# User 407420 not found in training data. Skipping evaluation.
# User 627569 not found in training data. Skipping evaluation.
# User 288258 not found in training data. Skipping evaluation.
# User 347773 not found in training data. Skipping evaluation.
# User 416361 not found in training data. Skipping evaluation.
# User 580159 not found in training data. Skipping evaluation.
# User 310054 not found in training data. Skipping evaluation.
# User 702143 not found in training data. Skipping evaluation.
# User 450759 not found in training data. Skipping evaluation.
# User 412419 not found in training data. Skipping evaluation.
# User 44239 not found in training data. Skipping evaluation.
# User 607604 not found in training data. Skipping evaluation.
# User 613367 not found in training data. Skipping evaluation.
# User 950454 not found in training data. Skipping evaluation.
# User 587485 not found in training data. Skipping evaluation.
# User 208596 not found in training data. Skipping evaluation.
# User 923135 not found in training data. Skipping evaluation.
# User 347485 not found in training data. Skipping evaluation.
# User 922105 not found in training data. Skipping evaluation.
# User 226492 not found in training data. Skipping evaluation.
# User 541759 not found in training data. Skipping evaluation.
# User 878771 not found in training data. Skipping evaluation.
# User 69296 not found in training data. Skipping evaluation.
# User 184422 not found in training data. Skipping evaluation.
# User 880539 not found in training data. Skipping evaluation.
# User 126490 not found in training data. Skipping evaluation.
# User 805873 not found in training data. Skipping evaluation.
# User 207461 not found in training data. Skipping evaluation.
# User 90352 not found in training data. Skipping evaluation.
# User 112637 not found in training data. Skipping evaluation.
# User 421978 not found in training data. Skipping evaluation.
# User 955738 not found in training data. Skipping evaluation.
# User 482989 not found in training data. Skipping evaluation.
# User 636315 not found in training data. Skipping evaluation.
# User 788280 not found in training data. Skipping evaluation.
# User 94174 not found in training data. Skipping evaluation.
# User 98430 not found in training data. Skipping evaluation.
# User 35925 not found in training data. Skipping evaluation.
# User 226213 not found in training data. Skipping evaluation.
# User 407722 not found in training data. Skipping evaluation.
# User 812428 not found in training data. Skipping evaluation.
# User 283597 not found in training data. Skipping evaluation.
# User 824982 not found in training data. Skipping evaluation.
# User 795651 not found in training data. Skipping evaluation.
# User 111908 not found in training data. Skipping evaluation.
# User 123588 not found in training data. Skipping evaluation.
# User 907073 not found in training data. Skipping evaluation.
# User 448262 not found in training data. Skipping evaluation.
# User 968168 not found in training data. Skipping evaluation.
# User 279801 not found in training data. Skipping evaluation.
# User 990259 not found in training data. Skipping evaluation.
# User 857921 not found in training data. Skipping evaluation.
# User 431717 not found in training data. Skipping evaluation.
# User 325083 not found in training data. Skipping evaluation.
# User 159101 not found in training data. Skipping evaluation.
# User 767765 not found in training data. Skipping evaluation.
# User 996408 not found in training data. Skipping evaluation.
# User 721095 not found in training data. Skipping evaluation.
# User 388369 not found in training data. Skipping evaluation.
# User 873239 not found in training data. Skipping evaluation.
# User 258014 not found in training data. Skipping evaluation.
# User 357032 not found in training data. Skipping evaluation.
# User 526657 not found in training data. Skipping evaluation.
# User 196181 not found in training data. Skipping evaluation.
# User 801450 not found in training data. Skipping evaluation.
# User 104901 not found in training data. Skipping evaluation.
# User 960365 not found in training data. Skipping evaluation.
# User 712619 not found in training data. Skipping evaluation.
# User 966913 not found in training data. Skipping evaluation.
# User 704518 not found in training data. Skipping evaluation.
# User 722916 not found in training data. Skipping evaluation.
# User 473571 not found in training data. Skipping evaluation.
# User 587460 not found in training data. Skipping evaluation.
# User 417998 not found in training data. Skipping evaluation.
# User 511162 not found in training data. Skipping evaluation.
# User 678424 not found in training data. Skipping evaluation.
# User 308996 not found in training data. Skipping evaluation.
# User 720920 not found in training data. Skipping evaluation.
# User 975283 not found in training data. Skipping evaluation.
# User 614851 not found in training data. Skipping evaluation.
# User 285620 not found in training data. Skipping evaluation.
# User 396018 not found in training data. Skipping evaluation.
# User 153673 not found in training data. Skipping evaluation.
# User 49099 not found in training data. Skipping evaluation.
# User 121031 not found in training data. Skipping evaluation.
# User 84679 not found in training data. Skipping evaluation.
# User 90653 not found in training data. Skipping evaluation.
# User 568935 not found in training data. Skipping evaluation.
# User 602147 not found in training data. Skipping evaluation.
# User 118258 not found in training data. Skipping evaluation.
# User 582539 not found in training data. Skipping evaluation.
# User 609814 not found in training data. Skipping evaluation.
# User 329702 not found in training data. Skipping evaluation.
# User 684221 not found in training data. Skipping evaluation.
# User 659172 not found in training data. Skipping evaluation.
# User 650502 not found in training data. Skipping evaluation.
# User 134775 not found in training data. Skipping evaluation.
# User 657713 not found in training data. Skipping evaluation.
# User 944677 not found in training data. Skipping evaluation.
# User 592156 not found in training data. Skipping evaluation.
# User 675498 not found in training data. Skipping evaluation.
# User 984811 not found in training data. Skipping evaluation.
# User 506657 not found in training data. Skipping evaluation.
# User 802240 not found in training data. Skipping evaluation.
# User 49530 not found in training data. Skipping evaluation.
# User 384024 not found in training data. Skipping evaluation.
# Metrics for round 3: {'ndcg@k': 0.007339389669820055, 'hr@k': 0.013222222222222222, 'mrr@k': 0.005433333333333334, 'ndcg_low': 0.018527898893130255, 'ndcg_moderate_high': 0.005132051745359629, 'DI_NDCG': 3.6102322837806673, 'GRU_NDCG': 0.013395847147770625, 'CV': 0.026444444444444444, 'cv_low': 0.06608226567768037, 'cv_moderate_high': 0.01862445124384728, 'HR_LOW': 0.033041132838840186, 'HR_MODERATE_HIGH': 0.00931222562192364, 'MRR_LOW': 0.013823331085637222, 'MRR_MODERATE_HIGH': 0.003778102966609019, 'UCV_NDCG': 8.340071381915592, 'UCV_HR': 7.862043426342337, 'UCV_MRR': 9.27305729462702, 'DI_HR': 3.548145650708024, 'GRU_HR': 0.023728907216916548, 'DI_MRR': 3.6588021046033457, 'GRU_MRR': 0.010045228119028204}
#
# Overall Results:
# {1: {'ndcg@k': 0.006912527105497238, 'hr@k': 0.012555555555555556, 'mrr@k': 0.005074074074074074, 'ndcg_low': 0.014818835626908363, 'ndcg_moderate_high': 0.005352721925604633, 'DI_NDCG': 2.7684673018455848, 'GRU_NDCG': 0.009466113701303729, 'CV': 0.025111111111111115, 'cv_low': 0.049898853674983146, 'cv_moderate_high': 0.02022083277903419, 'HR_LOW': 0.024949426837491573, 'HR_MODERATE_HIGH': 0.010110416389517094, 'MRR_LOW': 0.011485727129692064, 'MRR_MODERATE_HIGH': 0.0038091437186820983, 'UCV_NDCG': 8.485734784068576, 'UCV_HR': 8.073164067254087, 'UCV_MRR': 9.302230135492294, 'DI_HR': 2.46769528338716, 'GRU_HR': 0.014839010447974478, 'DI_MRR': 3.0153042200429074, 'GRU_MRR': 0.0076765834110099655}, 2: {'ndcg@k': 0.006990195329679597, 'hr@k': 0.012666666666666666, 'mrr@k': 0.005133333333333333, 'ndcg_low': 0.016578119201138313, 'ndcg_moderate_high': 0.00509863072925745, 'DI_NDCG': 3.2514845811461037, 'GRU_NDCG': 0.011479488471880864, 'CV': 0.025333333333333333, 'cv_low': 0.05799055967633176, 'cv_moderate_high': 0.0188905148330451, 'HR_LOW': 0.02899527983816588, 'HR_MODERATE_HIGH': 0.00944525741652255, 'MRR_LOW': 0.012530905821532929, 'MRR_MODERATE_HIGH': 0.0036738947275065407, 'UCV_NDCG': 8.395601220599916, 'UCV_HR': 8.013838740969508, 'UCV_MRR': 9.1545963220025, 'DI_HR': 3.069824204837928, 'GRU_HR': 0.01955002242164333, 'DI_MRR': 3.410796103577418, 'GRU_MRR': 0.008857011094026389}, 3: {'ndcg@k': 0.007339389669820055, 'hr@k': 0.013222222222222222, 'mrr@k': 0.005433333333333334, 'ndcg_low': 0.018527898893130255, 'ndcg_moderate_high': 0.005132051745359629, 'DI_NDCG': 3.6102322837806673, 'GRU_NDCG': 0.013395847147770625, 'CV': 0.026444444444444444, 'cv_low': 0.06608226567768037, 'cv_moderate_high': 0.01862445124384728, 'HR_LOW': 0.033041132838840186, 'HR_MODERATE_HIGH': 0.00931222562192364, 'MRR_LOW': 0.013823331085637222, 'MRR_MODERATE_HIGH': 0.003778102966609019, 'UCV_NDCG': 8.340071381915592, 'UCV_HR': 7.862043426342337, 'UCV_MRR': 9.27305729462702, 'DI_HR': 3.548145650708024, 'GRU_HR': 0.023728907216916548, 'DI_MRR': 3.6588021046033457, 'GRU_MRR': 0.010045228119028204}}

# %% [markdown]
# Overall Results:
# {1: {'ndcg@k': 0.006912527105497238, 'hr@k': 0.012555555555555556, 'mrr@k': 0.005074074074074074, 'ndcg_low': 0.014818835626908363, 'ndcg_moderate_high': 0.005352721925604633, 'DI_NDCG': 2.7684673018455848, 'GRU_NDCG': 0.009466113701303729, 'CV': 0.025111111111111115, 'cv_low': 0.049898853674983146, 'cv_moderate_high': 0.02022083277903419, 'HR_LOW': 0.024949426837491573, 'HR_MODERATE_HIGH': 0.010110416389517094, 'MRR_LOW': 0.011485727129692064, 'MRR_MODERATE_HIGH': 0.0038091437186820983, 'UCV_NDCG': 8.485734784068576, 'UCV_HR': 8.073164067254087, 'UCV_MRR': 9.302230135492294, 'DI_HR': 2.46769528338716, 'GRU_HR': 0.014839010447974478, 'DI_MRR': 3.0153042200429074, 'GRU_MRR': 0.0076765834110099655}, 2: {'ndcg@k': 0.006990195329679597, 'hr@k': 0.012666666666666666, 'mrr@k': 0.005133333333333333, 'ndcg_low': 0.016578119201138313, 'ndcg_moderate_high': 0.00509863072925745, 'DI_NDCG': 3.2514845811461037, 'GRU_NDCG': 0.011479488471880864, 'CV': 0.025333333333333333, 'cv_low': 0.05799055967633176, 'cv_moderate_high': 0.0188905148330451, 'HR_LOW': 0.02899527983816588, 'HR_MODERATE_HIGH': 0.00944525741652255, 'MRR_LOW': 0.012530905821532929, 'MRR_MODERATE_HIGH': 0.0036738947275065407, 'UCV_NDCG': 8.395601220599916, 'UCV_HR': 8.013838740969508, 'UCV_MRR': 9.1545963220025, 'DI_HR': 3.069824204837928, 'GRU_HR': 0.01955002242164333, 'DI_MRR': 3.410796103577418, 'GRU_MRR': 0.008857011094026389}, 3: {'ndcg@k': 0.007339389669820055, 'hr@k': 0.013222222222222222, 'mrr@k': 0.005433333333333334, 'ndcg_low': 0.018527898893130255, 'ndcg_moderate_high': 0.005132051745359629, 'DI_NDCG': 3.6102322837806673, 'GRU_NDCG': 0.013395847147770625, 'CV': 0.026444444444444444, 'cv_low': 0.06608226567768037, 'cv_moderate_high': 0.01862445124384728, 'HR_LOW': 0.033041132838840186, 'HR_MODERATE_HIGH': 0.00931222562192364, 'MRR_LOW': 0.013823331085637222, 'MRR_MODERATE_HIGH': 0.003778102966609019, 'UCV_NDCG': 8.340071381915592, 'UCV_HR': 7.862043426342337, 'UCV_MRR': 9.27305729462702, 'DI_HR': 3.548145650708024, 'GRU_HR': 0.023728907216916548, 'DI_MRR': 3.6588021046033457, 'GRU_MRR': 0.010045228119028204}}

# %%
print(f"train_user_item_matrix.shape: {train_user_item_matrix.shape}")
# Out:
# train_user_item_matrix.shape: (27439, 5389)

# %%
print(f"df_rent_clean head:\n{df_rent_clean.head()}")
# Out:
# df_rent_clean head:
#           fit  user_id bust size  item_id  weight  rating     rented for  \
# 125033    fit   581157       34b   126335  118lbs     4.0          party
# 83094   large   623100       34d   125564  120lbs     2.0  formal affair
# 131558    fit   284739       36c   145906  170lbs    10.0  formal affair
# 54303   small   395409       36c   144714  170lbs     6.0  formal affair
# 140548    fit   946927       34c   160612  130lbs    10.0       vacation
#
#                                               review_text  body type  \
# 125033  The dress is gorgeous but the gathering in the...     petite
# 83094   This dress just didn't work for me.  There was...  hourglass
# 131558  I wore this dress for an inaugural ball.  I go...       pear
# 54303          Beautiful gown, i just wish it had fit me        pear
# 140548  This dress fit me beautifully, I received both...   athletic
#
#                                    review_summary category height  size   age  \
# 125033                               UNFLATTERING    dress  5' 2"     4  44.0
# 83094                                   Odd dress     gown  5' 4"     8  39.0
# 131558                         Fun, fancy dress!      gown  5' 9"    24  31.0
# 54303   it was too tight on the side , bust line      gown  5' 4"    24  48.0
# 140548                   The Perfect Vegas Dress!    dress  5' 3"     8  49.0
#
#           review_date  interaction user_activity
# 125033  April 1, 2011          4.0          High
# 83094   April 1, 2012          2.0          High
# 131558  April 1, 2013         10.0          High
# 54303   April 1, 2013          6.0          High
# 140548  April 1, 2013         10.0           Low

# %%
import numpy as np
from lightfm import LightFM
from scipy.sparse import coo_matrix # sparse matrix
from lightfm.evaluation import precision_at_k, recall_at_k


interactions = coo_matrix(train_user_item_matrix.values)


model = LightFM(loss='bpr')
 # https://making.lyst.com/lightfm/docs/lightfm.html


model.fit(interactions, epochs=30, num_threads=2)

train_precision = precision_at_k(model, interactions, k=5).mean()
train_recall = recall_at_k(model, interactions, k=5).mean()


print(f"Train Precision at k=5: {train_precision}")
print(f"Train Recall at k=5: {train_recall}")


user_id = 55
scores = model.predict(user_id, np.arange(interactions.shape[1]))


top_items = np.argsort(-scores)

print("Top 10 recommended items for user 55:", top_items[:10])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 22
#      20 #  precision@k, recall@k) on the training set
#      21 train_precision = precision_at_k(model, interactions, k=5).mean()
# ---> 22 train_recall = recall_at_k(model, interactions, k=5).mean()
#      25 print(f"Train Precision at k=5: {train_precision}")
#      26 print(f"Train Recall at k=5: {train_recall}")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/lightfm/evaluation.py:148, in recall_at_k(model, test_interactions, train_interactions, k, user_features, item_features, preserve_rows, num_threads, check_intersections)
#     145 if num_threads < 1:
#     146     raise ValueError("Number of threads must be 1 or larger.")
# --> 148 ranks = model.predict_rank(
#     149     test_interactions,
#     150     train_interactions=train_interactions,
#     151     user_features=user_features,
#     152     item_features=item_features,
#     153     num_threads=num_threads,
#     154     check_intersections=check_intersections,
#     155 )
#     157 ranks.data = np.less(ranks.data, k, ranks.data)
#     159 retrieved = np.squeeze(test_interactions.getnnz(axis=1))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/lightfm/lightfm.py:979, in LightFM.predict_rank(self, test_interactions, train_interactions, item_features, user_features, num_threads, check_intersections)
#     968 ranks = sp.csr_matrix(
#     969     (
#     970         np.zeros_like(test_interactions.data),
#    (...)
#     974     shape=test_interactions.shape,
#     975 )
#     977 lightfm_data = self._get_lightfm_data()
# --> 979 predict_ranks(
#     980     CSRMatrix(item_features),
#     981     CSRMatrix(user_features),
#     982     CSRMatrix(test_interactions),
#     983     CSRMatrix(train_interactions),
#     984     ranks.data,
#     985     lightfm_data,
#     986     num_threads,
#     987 )
#     989 return ranks
#
# KeyboardInterrupt:

# %%
test_items = test_df.groupby("user_id")["item_id"].first().to_dict()

def calculate_metrics_for_user(user, actual_item, recs, group):
    relevance_scores = [1 if item == actual_item else 0 for item in recs]
    ndcg = ndcg_at_k(relevance_scores, k=6)
    hr = hr_at_k([actual_item], recs, k=5)
    mrr = mrr_at_k([actual_item], recs, k=5)
    cv = coefficient_of_variance(relevance_scores)
    return [user, ndcg, hr, mrr, cv, group]



metrics_lightfm = []
for user_id in train_user_item_matrix.index:  
    
    actual_item = test_items.get(user_id, None)
    if actual_item is None:
        continue

    
    engagement_level = df_rent_clean[df_rent_clean["user_id"] == user_id][
        "user_activity"
    ].values[0]
    try:
        user_id_internal = train_user_item_matrix.index.get_loc(user_id)
    except KeyError:
        
        print(f"User {user_id} not found in training data. Skipping.")
        continue

   
    scores = best_model.predict(user_id_internal, np.arange(interactions.shape[1])) 
    top_items = np.argsort(-scores)
    recs = [train_user_item_matrix.columns[i] for i in top_items]

   
    metrics_lightfm.append(
        calculate_metrics_for_user(user_id, actual_item, recs, engagement_level)
    )

metrics_lightfm_df = pd.DataFrame(
    metrics_lightfm, columns=["User", "NDCG@K", "HR@K", "MRR@K","CV", "Engagement Group"]
)
metrics_lightfm_df['User'] = pd.to_numeric(metrics_lightfm_df['User'], errors='coerce')


grouped_metrics_lightfm = metrics_lightfm_df.groupby("Engagement Group").agg(
    {"NDCG@K": "mean", "HR@K": "mean", "MRR@K": "mean", "CV":"mean"}
)
print("\nLightFM Metrics by User Engagement Level:")
grouped_metrics_lightfm

# %%
ndcg_low = grouped_metrics_lightfm.loc["Low", "NDCG@K"]
ndcg_high = grouped_metrics_lightfm.loc["High", "NDCG@K"]


di_ndcg = calculate_disparate_impact(ndcg_low, ndcg_high)
gru_ndcg = calculate_group_recommender_unfairness(ndcg_low, ndcg_high)

print(f"\nLightFM - BPR - NDCG Metrics:")
print(f"Disparate Impact: {di_ndcg}")
print(f"Group Recommender Unfairness: {gru_ndcg}")

hr_low = grouped_metrics_lightfm.loc["Low", "HR@K"]
hr_high = grouped_metrics_lightfm.loc["High", "HR@K"]


di_hr = calculate_disparate_impact(hr_low, hr_high)
gru_hr = calculate_group_recommender_unfairness(hr_low, hr_high)

print(f"\nLightFM - BPR - HR@K Metrics:")
print(f"Disparate Impact: {di_hr}")
print(f"Group Recommender Unfairness: {gru_hr}")


mrr_low = grouped_metrics_lightfm.loc["Low", "MRR@K"]
mrr_high = grouped_metrics_lightfm.loc["High", "MRR@K"]


di_mrr = calculate_disparate_impact(mrr_low, mrr_high)
gru_mrr = calculate_group_recommender_unfairness(mrr_low, mrr_high)

print(f"\nLightFM - BPR - MRR@K Metrics:")
print(f"Disparate Impact: {di_mrr}")
print(f"Group Recommender Unfairness: {gru_mrr}")

# %%
import numpy as np
from lightfm import LightFM
from scipy.sparse import csr_matrix  # sparse matrix
from lightfm.evaluation import precision_at_k, recall_at_k, auc_score
from lightfm.cross_validation import random_train_test_split
from sklearn.metrics import ndcg_score
import pandas as pd # Import pandas


def evaluate_lightfm_multiple_rounds(
    interactions, test_df, df_rent_clean, num_rounds=3, k=5, epochs=30, user_id_to_print=55
):
    """
    Evaluates LightFM model with multiple training rounds, fairness metrics, and prints recommendations for a user.

    Args:
        interactions: The user-item interaction matrix (sparse).
        test_df: The test DataFrame.
        df_rent_clean: The cleaned main DataFrame with user activity.
        num_rounds: The number of training rounds.
        k: The value of k for precision@k, recall@k metrics.
        epochs: The number of epochs for each training round.
        user_id_to_print: The user ID for which recommendations will be printed.

    Returns:
        A dictionary containing metrics for each round.
    """

    train_interactions, test_interactions = random_train_test_split(
        interactions, test_percentage=0.2, random_state=42
    )

    round_metrics = {}
    model = LightFM(loss='bpr', no_components=50, learning_rate=0.1, item_alpha=1e-05, user_alpha=1e-06)


    test_items = test_df.groupby("user_id")["item_id"].first().to_dict()


    user_id_map = {user: i for i, user in enumerate(train_user_item_matrix.index)}


    for round_num in range(num_rounds):
        print(f"Training Round {round_num + 1}...")
        model.fit(train_interactions, epochs=epochs) 

       
        test_user_ids = test_df['user_id'].unique()

        ndcg_scores = []
        hr_scores = []
        mrr_scores = []
        cv_scores = []
        engagement_levels_list = []

        for user_id in test_user_ids:
            actual_item = test_items.get(user_id, None)
            if actual_item is None:
                continue

            user_id_internal = user_id_map.get(user_id, None)
            if user_id_internal is None:
               
                print(f"User {user_id} not found in training data. Skipping evaluation.")
                continue


            engagement_level_row = df_rent_clean[df_rent_clean["user_id"] == user_id]
            if engagement_level_row.empty:
                 print(f"User {user_id} not found in df_rent_clean for engagement level. Skipping.")
                 continue
            engagement_level = engagement_level_row["user_activity"].values[0]
            engagement_levels_list.append(engagement_level)


            scores = model.predict(user_id_internal, np.arange(interactions.shape[1]))
            top_k_indices = np.argsort(-scores)[:k]
            top_k_items_predicted = [train_user_item_matrix.columns[i] for i in top_k_indices]

            relevance_scores = [1 if item == actual_item else 0 for item in top_k_items_predicted]

           
            ndcg_scores.append(ndcg_at_k(relevance_scores, k))


            hr_scores.append(hr_at_k([actual_item], top_k_items_predicted, k))
            mrr_scores.append(mrr_at_k([actual_item], top_k_items_predicted, k))
            cv_scores.append(coefficient_of_variance(np.array(relevance_scores))) 

 
        ndcg = np.mean(ndcg_scores) if ndcg_scores else 0
        hr = np.mean(hr_scores) if hr_scores else 0
        mrr = np.mean(mrr_scores) if mrr_scores else 0
        cv = np.mean(cv_scores) if cv_scores else 0



        ndcg_low = [
            ndcg_scores[i]
            for i in range(len(ndcg_scores))
            if engagement_levels_list[i] == "Low"
        ]
        ndcg_moderate_high = [
            ndcg_scores[i]
            for i in range(len(ndcg_scores))
            if engagement_levels_list[i] == "High"
        ]
        cv_low = [
            cv_scores[i]
            for i in range(len(cv_scores))
            if engagement_levels_list[i] == "Low"
        ]
        cv_moderate_high = [
            cv_scores[i]
            for i in range(len(cv_scores))
            if engagement_levels_list[i] == "High"
        ]
        hr_low = [
            hr_scores[i]
            for i in range(len(hr_scores))
            if engagement_levels_list[i] == "Low"
        ]
        hr_moderate_high = [
            hr_scores[i]
            for i in range(len(hr_scores))
            if engagement_levels_list[i] == "High"
        ]
        mrr_low = [
            mrr_scores[i]
            for i in range(len(mrr_scores))
            if engagement_levels_list[i] == "Low"
        ]
        mrr_moderate_high = [
            mrr_scores[i]
            for i in range(len(mrr_scores))
            if engagement_levels_list[i] == "High"
        ]

        ucv_ndcg = calculate_ucv(ndcg_low, ndcg_moderate_high)
        
        ucv_hr = calculate_ucv(hr_low, hr_moderate_high)
        ucv_mrr = calculate_ucv(mrr_low, mrr_moderate_high)
        cv_low_mean = np.mean(cv_low) if cv_low else 0
        cv_moderate_high_mean = np.mean(cv_moderate_high) if cv_moderate_high else 0
        hr_low_mean = np.mean(hr_low) if hr_low else 0
        hr_moderate_high_mean = np.mean(hr_moderate_high) if hr_moderate_high else 0
        mrr_low_mean = np.mean(mrr_low) if mrr_low else 0
        mrr_moderate_high_mean = np.mean(mrr_moderate_high) if mrr_moderate_high else 0
        di_ndcg = calculate_disparate_impact(ndcg_low, ndcg_moderate_high) if ndcg_moderate_high else np.inf 
        gru_ndcg = calculate_group_recommender_unfairness(ndcg_low, ndcg_moderate_high)
        ndcg_low = np.mean(ndcg_low) if ndcg_low else 0
        ndcg_moderate_high = np.mean(ndcg_moderate_high) if ndcg_moderate_high else 0
        di_hr = calculate_disparate_impact(hr_low, hr_moderate_high) if hr_moderate_high else np.inf
        gru_hr = calculate_group_recommender_unfairness(hr_low, hr_moderate_high)
        di_mrr = calculate_disparate_impact(mrr_low, mrr_moderate_high) if mrr_moderate_high else np.inf
        gru_mrr = calculate_group_recommender_unfairness(mrr_low, mrr_moderate_high)
        round_metrics[round_num + 1] = {
            "ndcg@k": ndcg,
            "hr@k": hr,
            "mrr@k": mrr,
            "DI_NDCG": di_ndcg,
            "GRU_NDCG": gru_ndcg,
            "ndcg_low": ndcg_low,
            "ndcg_moderate_high": ndcg_moderate_high,
            "CV": cv,
            "cv_low": cv_low_mean,
            "cv_moderate_high": cv_moderate_high_mean,
            "HR_LOW": hr_low_mean,
            "HR_MODERATE_HIGH": hr_moderate_high_mean,
            "MRR_LOW": mrr_low_mean,
            "MRR_MODERATE_HIGH": mrr_moderate_high_mean,
            "UCV_NDCG": ucv_ndcg,
            "UCV_HR": ucv_hr,
            "UCV_MRR": ucv_mrr,
            "DI_HR": di_hr,
            "GRU_HR": gru_hr,
            "DI_MRR": di_mrr,
            "GRU_MRR": gru_mrr
        }

        print(f"Metrics for round {round_num + 1}: {round_metrics[round_num + 1]}")


        if round_num == 0 and user_id_to_print in user_id_map: 
            user_index = user_id_map[user_id_to_print]
            scores = model.predict(user_index, np.arange(interactions.shape[1]))
            top_items_indices = np.argsort(-scores)[:k]
            top_items_actual_ids = [train_user_item_matrix.columns[i] for i in top_items_indices]
            print(
                f"Top {k} recommendations for user {user_id_to_print}: {top_items_actual_ids}"
            )
        elif round_num == 0 and user_id_to_print not in user_id_map:
            print(
                f"User {user_id_to_print} not found in training data mapping. Skipping recommendations."
            )

    return round_metrics

interactions = csr_matrix(train_user_item_matrix.values)

round_results = evaluate_lightfm_multiple_rounds(interactions, test_df, df_rent_clean)

print("\nOverall Results:")
print(round_results)
# Out:
# Training Round 1...
# User 696430 not found in training data. Skipping evaluation.
# User 987390 not found in training data. Skipping evaluation.
# User 405715 not found in training data. Skipping evaluation.
# User 436933 not found in training data. Skipping evaluation.
# User 522905 not found in training data. Skipping evaluation.
# User 751887 not found in training data. Skipping evaluation.
# User 854188 not found in training data. Skipping evaluation.
# User 818665 not found in training data. Skipping evaluation.
# User 750491 not found in training data. Skipping evaluation.
# User 387463 not found in training data. Skipping evaluation.
# User 160450 not found in training data. Skipping evaluation.
# User 523458 not found in training data. Skipping evaluation.
# User 791921 not found in training data. Skipping evaluation.
# User 214592 not found in training data. Skipping evaluation.
# User 24811 not found in training data. Skipping evaluation.
# User 418034 not found in training data. Skipping evaluation.
# User 459541 not found in training data. Skipping evaluation.
# User 975280 not found in training data. Skipping evaluation.
# User 704568 not found in training data. Skipping evaluation.
# User 731615 not found in training data. Skipping evaluation.
# User 585687 not found in training data. Skipping evaluation.
# User 796991 not found in training data. Skipping evaluation.
# User 623671 not found in training data. Skipping evaluation.
# User 372105 not found in training data. Skipping evaluation.
# User 31024 not found in training data. Skipping evaluation.
# User 560182 not found in training data. Skipping evaluation.
# User 365115 not found in training data. Skipping evaluation.
# User 475721 not found in training data. Skipping evaluation.
# User 962756 not found in training data. Skipping evaluation.
# User 339207 not found in training data. Skipping evaluation.
# User 873528 not found in training data. Skipping evaluation.
# User 611488 not found in training data. Skipping evaluation.
# User 741505 not found in training data. Skipping evaluation.
# User 539451 not found in training data. Skipping evaluation.
# User 742898 not found in training data. Skipping evaluation.
# User 873155 not found in training data. Skipping evaluation.
# User 581492 not found in training data. Skipping evaluation.
# User 139884 not found in training data. Skipping evaluation.
# User 655705 not found in training data. Skipping evaluation.
# User 174111 not found in training data. Skipping evaluation.
# User 467351 not found in training data. Skipping evaluation.
# User 235056 not found in training data. Skipping evaluation.
# User 352845 not found in training data. Skipping evaluation.
# User 414346 not found in training data. Skipping evaluation.
# User 880569 not found in training data. Skipping evaluation.
# User 667471 not found in training data. Skipping evaluation.
# User 786634 not found in training data. Skipping evaluation.
# User 877590 not found in training data. Skipping evaluation.
# User 700797 not found in training data. Skipping evaluation.
# User 104655 not found in training data. Skipping evaluation.
# User 698525 not found in training data. Skipping evaluation.
# User 181428 not found in training data. Skipping evaluation.
# User 826711 not found in training data. Skipping evaluation.
# User 223943 not found in training data. Skipping evaluation.
# User 482893 not found in training data. Skipping evaluation.
# User 327999 not found in training data. Skipping evaluation.
# User 806600 not found in training data. Skipping evaluation.
# User 936344 not found in training data. Skipping evaluation.
# User 6178 not found in training data. Skipping evaluation.
# User 601310 not found in training data. Skipping evaluation.
# User 560652 not found in training data. Skipping evaluation.
# User 339899 not found in training data. Skipping evaluation.
# User 251985 not found in training data. Skipping evaluation.
# User 508336 not found in training data. Skipping evaluation.
# User 25841 not found in training data. Skipping evaluation.
# User 288610 not found in training data. Skipping evaluation.
# User 807581 not found in training data. Skipping evaluation.
# User 621541 not found in training data. Skipping evaluation.
# User 847369 not found in training data. Skipping evaluation.
# User 392466 not found in training data. Skipping evaluation.
# User 540165 not found in training data. Skipping evaluation.
# User 939959 not found in training data. Skipping evaluation.
# User 131913 not found in training data. Skipping evaluation.
# User 470696 not found in training data. Skipping evaluation.
# User 375558 not found in training data. Skipping evaluation.
# User 387613 not found in training data. Skipping evaluation.
# User 811271 not found in training data. Skipping evaluation.
# User 223897 not found in training data. Skipping evaluation.
# User 364919 not found in training data. Skipping evaluation.
# User 511023 not found in training data. Skipping evaluation.
# User 137298 not found in training data. Skipping evaluation.
# User 7754 not found in training data. Skipping evaluation.
# User 493357 not found in training data. Skipping evaluation.
# User 66954 not found in training data. Skipping evaluation.
# User 784726 not found in training data. Skipping evaluation.
# User 100457 not found in training data. Skipping evaluation.
# User 166678 not found in training data. Skipping evaluation.
# User 750282 not found in training data. Skipping evaluation.
# User 623946 not found in training data. Skipping evaluation.
# User 963146 not found in training data. Skipping evaluation.
# User 115744 not found in training data. Skipping evaluation.
# User 220840 not found in training data. Skipping evaluation.
# User 880436 not found in training data. Skipping evaluation.
# User 225070 not found in training data. Skipping evaluation.
# User 736552 not found in training data. Skipping evaluation.
# User 353326 not found in training data. Skipping evaluation.
# User 66079 not found in training data. Skipping evaluation.
# User 266717 not found in training data. Skipping evaluation.
# User 520730 not found in training data. Skipping evaluation.
# User 96762 not found in training data. Skipping evaluation.
# User 766971 not found in training data. Skipping evaluation.
# User 560294 not found in training data. Skipping evaluation.
# User 281229 not found in training data. Skipping evaluation.
# User 655536 not found in training data. Skipping evaluation.
# User 453024 not found in training data. Skipping evaluation.
# User 295627 not found in training data. Skipping evaluation.
# User 371892 not found in training data. Skipping evaluation.
# User 272690 not found in training data. Skipping evaluation.
# User 717181 not found in training data. Skipping evaluation.
# User 242042 not found in training data. Skipping evaluation.
# User 952119 not found in training data. Skipping evaluation.
# User 536050 not found in training data. Skipping evaluation.
# User 959160 not found in training data. Skipping evaluation.
# User 845030 not found in training data. Skipping evaluation.
# User 942618 not found in training data. Skipping evaluation.
# User 225435 not found in training data. Skipping evaluation.
# User 376304 not found in training data. Skipping evaluation.
# User 250828 not found in training data. Skipping evaluation.
# User 777291 not found in training data. Skipping evaluation.
# User 664388 not found in training data. Skipping evaluation.
# User 44523 not found in training data. Skipping evaluation.
# User 988691 not found in training data. Skipping evaluation.
# User 34768 not found in training data. Skipping evaluation.
# User 232640 not found in training data. Skipping evaluation.
# User 202639 not found in training data. Skipping evaluation.
# User 42515 not found in training data. Skipping evaluation.
# User 298694 not found in training data. Skipping evaluation.
# User 653594 not found in training data. Skipping evaluation.
# User 817290 not found in training data. Skipping evaluation.
# User 424138 not found in training data. Skipping evaluation.
# User 100362 not found in training data. Skipping evaluation.
# User 313355 not found in training data. Skipping evaluation.
# User 733152 not found in training data. Skipping evaluation.
# User 307440 not found in training data. Skipping evaluation.
# User 801364 not found in training data. Skipping evaluation.
# User 914606 not found in training data. Skipping evaluation.
# User 898726 not found in training data. Skipping evaluation.
# User 454572 not found in training data. Skipping evaluation.
# User 619349 not found in training data. Skipping evaluation.
# User 895448 not found in training data. Skipping evaluation.
# User 788678 not found in training data. Skipping evaluation.
# User 293351 not found in training data. Skipping evaluation.
# User 630306 not found in training data. Skipping evaluation.
# User 700181 not found in training data. Skipping evaluation.
# User 963136 not found in training data. Skipping evaluation.
# User 691104 not found in training data. Skipping evaluation.
# User 516831 not found in training data. Skipping evaluation.
# User 35836 not found in training data. Skipping evaluation.
# User 756638 not found in training data. Skipping evaluation.
# User 893654 not found in training data. Skipping evaluation.
# User 132995 not found in training data. Skipping evaluation.
# User 560820 not found in training data. Skipping evaluation.
# User 726884 not found in training data. Skipping evaluation.
# User 753824 not found in training data. Skipping evaluation.
# User 806423 not found in training data. Skipping evaluation.
# User 147361 not found in training data. Skipping evaluation.
# User 748215 not found in training data. Skipping evaluation.
# User 824111 not found in training data. Skipping evaluation.
# User 35 not found in training data. Skipping evaluation.
# User 566072 not found in training data. Skipping evaluation.
# User 326277 not found in training data. Skipping evaluation.
# User 463778 not found in training data. Skipping evaluation.
# User 191221 not found in training data. Skipping evaluation.
# User 695982 not found in training data. Skipping evaluation.
# User 407462 not found in training data. Skipping evaluation.
# User 829604 not found in training data. Skipping evaluation.
# User 332102 not found in training data. Skipping evaluation.
# User 913611 not found in training data. Skipping evaluation.
# User 756059 not found in training data. Skipping evaluation.
# User 554489 not found in training data. Skipping evaluation.
# User 714088 not found in training data. Skipping evaluation.
# User 677822 not found in training data. Skipping evaluation.
# User 49557 not found in training data. Skipping evaluation.
# User 70799 not found in training data. Skipping evaluation.
# User 753639 not found in training data. Skipping evaluation.
# User 230804 not found in training data. Skipping evaluation.
# User 44237 not found in training data. Skipping evaluation.
# User 640674 not found in training data. Skipping evaluation.
# User 231864 not found in training data. Skipping evaluation.
# User 868840 not found in training data. Skipping evaluation.
# User 987986 not found in training data. Skipping evaluation.
# User 582900 not found in training data. Skipping evaluation.
# User 59692 not found in training data. Skipping evaluation.
# User 182068 not found in training data. Skipping evaluation.
# User 499929 not found in training data. Skipping evaluation.
# User 428762 not found in training data. Skipping evaluation.
# User 614955 not found in training data. Skipping evaluation.
# User 107876 not found in training data. Skipping evaluation.
# User 542911 not found in training data. Skipping evaluation.
# User 446896 not found in training data. Skipping evaluation.
# User 262557 not found in training data. Skipping evaluation.
# User 529649 not found in training data. Skipping evaluation.
# User 883596 not found in training data. Skipping evaluation.
# User 687849 not found in training data. Skipping evaluation.
# User 940158 not found in training data. Skipping evaluation.
# User 352754 not found in training data. Skipping evaluation.
# User 590474 not found in training data. Skipping evaluation.
# User 337541 not found in training data. Skipping evaluation.
# User 288353 not found in training data. Skipping evaluation.
# User 318179 not found in training data. Skipping evaluation.
# User 776529 not found in training data. Skipping evaluation.
# User 545560 not found in training data. Skipping evaluation.
# User 758632 not found in training data. Skipping evaluation.
# User 372933 not found in training data. Skipping evaluation.
# User 819746 not found in training data. Skipping evaluation.
# User 398417 not found in training data. Skipping evaluation.
# User 657865 not found in training data. Skipping evaluation.
# User 160229 not found in training data. Skipping evaluation.
# User 249896 not found in training data. Skipping evaluation.
# User 597555 not found in training data. Skipping evaluation.
# User 976904 not found in training data. Skipping evaluation.
# User 433396 not found in training data. Skipping evaluation.
# User 368014 not found in training data. Skipping evaluation.
# User 345652 not found in training data. Skipping evaluation.
# User 716440 not found in training data. Skipping evaluation.
# User 4914 not found in training data. Skipping evaluation.
# User 878032 not found in training data. Skipping evaluation.
# User 355937 not found in training data. Skipping evaluation.
# User 810527 not found in training data. Skipping evaluation.
# User 600430 not found in training data. Skipping evaluation.
# User 206179 not found in training data. Skipping evaluation.
# User 199055 not found in training data. Skipping evaluation.
# User 203965 not found in training data. Skipping evaluation.
# User 401565 not found in training data. Skipping evaluation.
# User 87400 not found in training data. Skipping evaluation.
# User 488148 not found in training data. Skipping evaluation.
# User 697165 not found in training data. Skipping evaluation.
# User 630678 not found in training data. Skipping evaluation.
# User 63659 not found in training data. Skipping evaluation.
# User 632017 not found in training data. Skipping evaluation.
# User 204149 not found in training data. Skipping evaluation.
# User 105428 not found in training data. Skipping evaluation.
# User 888818 not found in training data. Skipping evaluation.
# User 303943 not found in training data. Skipping evaluation.
# User 496456 not found in training data. Skipping evaluation.
# User 351722 not found in training data. Skipping evaluation.
# User 638947 not found in training data. Skipping evaluation.
# User 836346 not found in training data. Skipping evaluation.
# User 974966 not found in training data. Skipping evaluation.
# User 507270 not found in training data. Skipping evaluation.
# User 511943 not found in training data. Skipping evaluation.
# User 146235 not found in training data. Skipping evaluation.
# User 221737 not found in training data. Skipping evaluation.
# User 412650 not found in training data. Skipping evaluation.
# User 109577 not found in training data. Skipping evaluation.
# User 80805 not found in training data. Skipping evaluation.
# User 859964 not found in training data. Skipping evaluation.
# User 721851 not found in training data. Skipping evaluation.
# User 887111 not found in training data. Skipping evaluation.
# User 809077 not found in training data. Skipping evaluation.
# User 550361 not found in training data. Skipping evaluation.
# User 518289 not found in training data. Skipping evaluation.
# User 492698 not found in training data. Skipping evaluation.
# User 253863 not found in training data. Skipping evaluation.
# User 158214 not found in training data. Skipping evaluation.
# User 792619 not found in training data. Skipping evaluation.
# User 234668 not found in training data. Skipping evaluation.
# User 326171 not found in training data. Skipping evaluation.
# User 537790 not found in training data. Skipping evaluation.
# User 564829 not found in training data. Skipping evaluation.
# User 304660 not found in training data. Skipping evaluation.
# User 145305 not found in training data. Skipping evaluation.
# User 182490 not found in training data. Skipping evaluation.
# User 682532 not found in training data. Skipping evaluation.
# User 644297 not found in training data. Skipping evaluation.
# User 779798 not found in training data. Skipping evaluation.
# User 629898 not found in training data. Skipping evaluation.
# User 74777 not found in training data. Skipping evaluation.
# User 573164 not found in training data. Skipping evaluation.
# User 462553 not found in training data. Skipping evaluation.
# User 402385 not found in training data. Skipping evaluation.
# User 659747 not found in training data. Skipping evaluation.
# User 52573 not found in training data. Skipping evaluation.
# User 371038 not found in training data. Skipping evaluation.
# User 735923 not found in training data. Skipping evaluation.
# User 429827 not found in training data. Skipping evaluation.
# User 628834 not found in training data. Skipping evaluation.
# User 679250 not found in training data. Skipping evaluation.
# User 939432 not found in training data. Skipping evaluation.
# User 10861 not found in training data. Skipping evaluation.
# User 628022 not found in training data. Skipping evaluation.
# User 315223 not found in training data. Skipping evaluation.
# User 800626 not found in training data. Skipping evaluation.
# User 685128 not found in training data. Skipping evaluation.
# User 819897 not found in training data. Skipping evaluation.
# User 204312 not found in training data. Skipping evaluation.
# User 759112 not found in training data. Skipping evaluation.
# User 386826 not found in training data. Skipping evaluation.
# User 129277 not found in training data. Skipping evaluation.
# User 418491 not found in training data. Skipping evaluation.
# User 878239 not found in training data. Skipping evaluation.
# User 321 not found in training data. Skipping evaluation.
# User 854638 not found in training data. Skipping evaluation.
# User 546038 not found in training data. Skipping evaluation.
# User 328714 not found in training data. Skipping evaluation.
# User 33753 not found in training data. Skipping evaluation.
# User 457554 not found in training data. Skipping evaluation.
# User 618883 not found in training data. Skipping evaluation.
# User 303646 not found in training data. Skipping evaluation.
# User 738284 not found in training data. Skipping evaluation.
# User 580441 not found in training data. Skipping evaluation.
# User 350079 not found in training data. Skipping evaluation.
# User 835693 not found in training data. Skipping evaluation.
# User 800507 not found in training data. Skipping evaluation.
# User 691287 not found in training data. Skipping evaluation.
# User 329403 not found in training data. Skipping evaluation.
# User 571167 not found in training data. Skipping evaluation.
# User 341845 not found in training data. Skipping evaluation.
# User 539437 not found in training data. Skipping evaluation.
# User 372055 not found in training data. Skipping evaluation.
# User 666805 not found in training data. Skipping evaluation.
# User 761634 not found in training data. Skipping evaluation.
# User 692911 not found in training data. Skipping evaluation.
# User 756586 not found in training data. Skipping evaluation.
# User 990369 not found in training data. Skipping evaluation.
# User 669132 not found in training data. Skipping evaluation.
# User 862919 not found in training data. Skipping evaluation.
# User 190381 not found in training data. Skipping evaluation.
# User 810791 not found in training data. Skipping evaluation.
# User 569491 not found in training data. Skipping evaluation.
# User 569368 not found in training data. Skipping evaluation.
# User 299230 not found in training data. Skipping evaluation.
# User 506128 not found in training data. Skipping evaluation.
# User 729919 not found in training data. Skipping evaluation.
# User 158309 not found in training data. Skipping evaluation.
# User 298193 not found in training data. Skipping evaluation.
# User 371968 not found in training data. Skipping evaluation.
# User 401965 not found in training data. Skipping evaluation.
# User 480448 not found in training data. Skipping evaluation.
# User 412596 not found in training data. Skipping evaluation.
# User 87079 not found in training data. Skipping evaluation.
# User 291157 not found in training data. Skipping evaluation.
# User 743376 not found in training data. Skipping evaluation.
# User 820669 not found in training data. Skipping evaluation.
# User 299742 not found in training data. Skipping evaluation.
# User 882850 not found in training data. Skipping evaluation.
# User 231306 not found in training data. Skipping evaluation.
# User 412273 not found in training data. Skipping evaluation.
# User 414134 not found in training data. Skipping evaluation.
# User 508931 not found in training data. Skipping evaluation.
# User 875654 not found in training data. Skipping evaluation.
# User 936496 not found in training data. Skipping evaluation.
# User 841141 not found in training data. Skipping evaluation.
# User 780334 not found in training data. Skipping evaluation.
# User 955214 not found in training data. Skipping evaluation.
# User 680978 not found in training data. Skipping evaluation.
# User 842169 not found in training data. Skipping evaluation.
# User 957813 not found in training data. Skipping evaluation.
# User 481757 not found in training data. Skipping evaluation.
# User 423903 not found in training data. Skipping evaluation.
# User 549985 not found in training data. Skipping evaluation.
# User 988275 not found in training data. Skipping evaluation.
# User 27497 not found in training data. Skipping evaluation.
# User 718587 not found in training data. Skipping evaluation.
# User 135389 not found in training data. Skipping evaluation.
# User 66452 not found in training data. Skipping evaluation.
# User 842485 not found in training data. Skipping evaluation.
# User 713616 not found in training data. Skipping evaluation.
# User 805395 not found in training data. Skipping evaluation.
# User 525188 not found in training data. Skipping evaluation.
# User 581694 not found in training data. Skipping evaluation.
# User 107956 not found in training data. Skipping evaluation.
# User 682179 not found in training data. Skipping evaluation.
# User 449666 not found in training data. Skipping evaluation.
# User 144604 not found in training data. Skipping evaluation.
# User 451304 not found in training data. Skipping evaluation.
# User 326790 not found in training data. Skipping evaluation.
# User 623617 not found in training data. Skipping evaluation.
# User 644536 not found in training data. Skipping evaluation.
# User 904114 not found in training data. Skipping evaluation.
# User 885844 not found in training data. Skipping evaluation.
# User 943258 not found in training data. Skipping evaluation.
# User 466255 not found in training data. Skipping evaluation.
# User 990470 not found in training data. Skipping evaluation.
# User 938744 not found in training data. Skipping evaluation.
# User 732559 not found in training data. Skipping evaluation.
# User 69799 not found in training data. Skipping evaluation.
# User 967025 not found in training data. Skipping evaluation.
# User 564450 not found in training data. Skipping evaluation.
# User 649100 not found in training data. Skipping evaluation.
# User 126396 not found in training data. Skipping evaluation.
# User 765381 not found in training data. Skipping evaluation.
# User 375708 not found in training data. Skipping evaluation.
# User 493984 not found in training data. Skipping evaluation.
# User 829679 not found in training data. Skipping evaluation.
# User 458837 not found in training data. Skipping evaluation.
# User 843915 not found in training data. Skipping evaluation.
# User 108645 not found in training data. Skipping evaluation.
# User 149493 not found in training data. Skipping evaluation.
# User 487381 not found in training data. Skipping evaluation.
# User 636493 not found in training data. Skipping evaluation.
# User 597482 not found in training data. Skipping evaluation.
# User 619030 not found in training data. Skipping evaluation.
# User 189546 not found in training data. Skipping evaluation.
# User 869584 not found in training data. Skipping evaluation.
# User 587828 not found in training data. Skipping evaluation.
# User 856255 not found in training data. Skipping evaluation.
# User 764414 not found in training data. Skipping evaluation.
# User 924612 not found in training data. Skipping evaluation.
# User 750750 not found in training data. Skipping evaluation.
# User 220121 not found in training data. Skipping evaluation.
# User 228972 not found in training data. Skipping evaluation.
# User 439613 not found in training data. Skipping evaluation.
# User 562497 not found in training data. Skipping evaluation.
# User 354525 not found in training data. Skipping evaluation.
# User 970382 not found in training data. Skipping evaluation.
# User 250921 not found in training data. Skipping evaluation.
# User 391120 not found in training data. Skipping evaluation.
# User 765020 not found in training data. Skipping evaluation.
# User 612090 not found in training data. Skipping evaluation.
# User 910750 not found in training data. Skipping evaluation.
# User 622251 not found in training data. Skipping evaluation.
# User 756743 not found in training data. Skipping evaluation.
# User 978533 not found in training data. Skipping evaluation.
# User 215035 not found in training data. Skipping evaluation.
# User 480435 not found in training data. Skipping evaluation.
# User 521093 not found in training data. Skipping evaluation.
# User 294013 not found in training data. Skipping evaluation.
# User 409585 not found in training data. Skipping evaluation.
# User 481417 not found in training data. Skipping evaluation.
# User 740045 not found in training data. Skipping evaluation.
# User 752731 not found in training data. Skipping evaluation.
# User 747161 not found in training data. Skipping evaluation.
# User 356136 not found in training data. Skipping evaluation.
# User 600718 not found in training data. Skipping evaluation.
# User 351646 not found in training data. Skipping evaluation.
# User 209003 not found in training data. Skipping evaluation.
# User 213306 not found in training data. Skipping evaluation.
# User 707929 not found in training data. Skipping evaluation.
# User 112175 not found in training data. Skipping evaluation.
# User 786848 not found in training data. Skipping evaluation.
# User 747922 not found in training data. Skipping evaluation.
# User 802859 not found in training data. Skipping evaluation.
# User 737406 not found in training data. Skipping evaluation.
# User 511481 not found in training data. Skipping evaluation.
# User 484832 not found in training data. Skipping evaluation.
# User 303644 not found in training data. Skipping evaluation.
# User 701079 not found in training data. Skipping evaluation.
# User 897269 not found in training data. Skipping evaluation.
# User 979986 not found in training data. Skipping evaluation.
# User 400697 not found in training data. Skipping evaluation.
# User 855488 not found in training data. Skipping evaluation.
# User 198071 not found in training data. Skipping evaluation.
# User 84355 not found in training data. Skipping evaluation.
# User 829606 not found in training data. Skipping evaluation.
# User 662180 not found in training data. Skipping evaluation.
# User 798597 not found in training data. Skipping evaluation.
# User 667526 not found in training data. Skipping evaluation.
# User 339064 not found in training data. Skipping evaluation.
# User 300186 not found in training data. Skipping evaluation.
# User 689010 not found in training data. Skipping evaluation.
# User 585245 not found in training data. Skipping evaluation.
# User 691841 not found in training data. Skipping evaluation.
# User 511315 not found in training data. Skipping evaluation.
# User 209766 not found in training data. Skipping evaluation.
# User 447536 not found in training data. Skipping evaluation.
# User 268165 not found in training data. Skipping evaluation.
# User 893015 not found in training data. Skipping evaluation.
# User 769826 not found in training data. Skipping evaluation.
# User 573508 not found in training data. Skipping evaluation.
# User 621969 not found in training data. Skipping evaluation.
# User 495333 not found in training data. Skipping evaluation.
# User 314764 not found in training data. Skipping evaluation.
# User 985934 not found in training data. Skipping evaluation.
# User 694566 not found in training data. Skipping evaluation.
# User 318806 not found in training data. Skipping evaluation.
# User 412461 not found in training data. Skipping evaluation.
# User 187061 not found in training data. Skipping evaluation.
# User 463401 not found in training data. Skipping evaluation.
# User 408895 not found in training data. Skipping evaluation.
# User 670880 not found in training data. Skipping evaluation.
# User 717973 not found in training data. Skipping evaluation.
# User 262493 not found in training data. Skipping evaluation.
# User 853121 not found in training data. Skipping evaluation.
# User 527975 not found in training data. Skipping evaluation.
# User 208728 not found in training data. Skipping evaluation.
# User 546705 not found in training data. Skipping evaluation.
# User 911866 not found in training data. Skipping evaluation.
# User 982193 not found in training data. Skipping evaluation.
# User 300285 not found in training data. Skipping evaluation.
# User 300074 not found in training data. Skipping evaluation.
# User 760586 not found in training data. Skipping evaluation.
# User 652681 not found in training data. Skipping evaluation.
# User 598379 not found in training data. Skipping evaluation.
# User 980109 not found in training data. Skipping evaluation.
# User 114230 not found in training data. Skipping evaluation.
# User 985680 not found in training data. Skipping evaluation.
# User 801249 not found in training data. Skipping evaluation.
# User 220393 not found in training data. Skipping evaluation.
# User 675047 not found in training data. Skipping evaluation.
# User 166549 not found in training data. Skipping evaluation.
# User 367839 not found in training data. Skipping evaluation.
# User 323037 not found in training data. Skipping evaluation.
# User 455442 not found in training data. Skipping evaluation.
# User 151698 not found in training data. Skipping evaluation.
# User 150679 not found in training data. Skipping evaluation.
# User 177677 not found in training data. Skipping evaluation.
# User 614842 not found in training data. Skipping evaluation.
# User 444255 not found in training data. Skipping evaluation.
# User 555186 not found in training data. Skipping evaluation.
# User 443836 not found in training data. Skipping evaluation.
# User 76199 not found in training data. Skipping evaluation.
# User 14177 not found in training data. Skipping evaluation.
# User 46304 not found in training data. Skipping evaluation.
# User 461265 not found in training data. Skipping evaluation.
# User 783260 not found in training data. Skipping evaluation.
# User 865955 not found in training data. Skipping evaluation.
# User 610571 not found in training data. Skipping evaluation.
# User 467366 not found in training data. Skipping evaluation.
# User 947909 not found in training data. Skipping evaluation.
# User 973896 not found in training data. Skipping evaluation.
# User 670794 not found in training data. Skipping evaluation.
# User 478762 not found in training data. Skipping evaluation.
# User 76807 not found in training data. Skipping evaluation.
# User 498518 not found in training data. Skipping evaluation.
# User 437798 not found in training data. Skipping evaluation.
# User 135324 not found in training data. Skipping evaluation.
# User 234236 not found in training data. Skipping evaluation.
# User 784866 not found in training data. Skipping evaluation.
# User 381099 not found in training data. Skipping evaluation.
# User 541692 not found in training data. Skipping evaluation.
# User 318636 not found in training data. Skipping evaluation.
# User 727057 not found in training data. Skipping evaluation.
# User 814418 not found in training data. Skipping evaluation.
# User 627660 not found in training data. Skipping evaluation.
# User 176399 not found in training data. Skipping evaluation.
# User 190329 not found in training data. Skipping evaluation.
# User 305802 not found in training data. Skipping evaluation.
# User 282643 not found in training data. Skipping evaluation.
# User 632389 not found in training data. Skipping evaluation.
# User 569488 not found in training data. Skipping evaluation.
# User 323946 not found in training data. Skipping evaluation.
# User 907707 not found in training data. Skipping evaluation.
# User 936583 not found in training data. Skipping evaluation.
# User 550831 not found in training data. Skipping evaluation.
# User 867537 not found in training data. Skipping evaluation.
# User 134526 not found in training data. Skipping evaluation.
# User 957250 not found in training data. Skipping evaluation.
# User 754446 not found in training data. Skipping evaluation.
# User 63755 not found in training data. Skipping evaluation.
# User 976118 not found in training data. Skipping evaluation.
# User 49161 not found in training data. Skipping evaluation.
# User 260985 not found in training data. Skipping evaluation.
# User 535580 not found in training data. Skipping evaluation.
# User 458706 not found in training data. Skipping evaluation.
# User 166007 not found in training data. Skipping evaluation.
# User 600867 not found in training data. Skipping evaluation.
# User 255984 not found in training data. Skipping evaluation.
# User 390966 not found in training data. Skipping evaluation.
# User 11392 not found in training data. Skipping evaluation.
# User 588856 not found in training data. Skipping evaluation.
# User 13009 not found in training data. Skipping evaluation.
# User 664123 not found in training data. Skipping evaluation.
# User 15931 not found in training data. Skipping evaluation.
# User 661704 not found in training data. Skipping evaluation.
# User 984042 not found in training data. Skipping evaluation.
# User 587705 not found in training data. Skipping evaluation.
# User 403662 not found in training data. Skipping evaluation.
# User 40699 not found in training data. Skipping evaluation.
# User 527047 not found in training data. Skipping evaluation.
# User 322081 not found in training data. Skipping evaluation.
# User 785905 not found in training data. Skipping evaluation.
# User 371592 not found in training data. Skipping evaluation.
# User 561770 not found in training data. Skipping evaluation.
# User 559273 not found in training data. Skipping evaluation.
# User 664767 not found in training data. Skipping evaluation.
# User 567101 not found in training data. Skipping evaluation.
# User 577420 not found in training data. Skipping evaluation.
# User 244296 not found in training data. Skipping evaluation.
# User 637189 not found in training data. Skipping evaluation.
# User 366010 not found in training data. Skipping evaluation.
# User 539728 not found in training data. Skipping evaluation.
# User 467250 not found in training data. Skipping evaluation.
# User 746886 not found in training data. Skipping evaluation.
# User 260992 not found in training data. Skipping evaluation.
# User 725295 not found in training data. Skipping evaluation.
# User 729760 not found in training data. Skipping evaluation.
# User 328318 not found in training data. Skipping evaluation.
# User 441078 not found in training data. Skipping evaluation.
# User 95559 not found in training data. Skipping evaluation.
# User 975381 not found in training data. Skipping evaluation.
# User 962572 not found in training data. Skipping evaluation.
# User 564818 not found in training data. Skipping evaluation.
# User 586117 not found in training data. Skipping evaluation.
# User 52424 not found in training data. Skipping evaluation.
# User 249788 not found in training data. Skipping evaluation.
# User 293200 not found in training data. Skipping evaluation.
# User 891063 not found in training data. Skipping evaluation.
# User 573806 not found in training data. Skipping evaluation.
# User 628872 not found in training data. Skipping evaluation.
# User 197317 not found in training data. Skipping evaluation.
# User 477581 not found in training data. Skipping evaluation.
# User 128530 not found in training data. Skipping evaluation.
# User 67455 not found in training data. Skipping evaluation.
# User 987172 not found in training data. Skipping evaluation.
# User 399627 not found in training data. Skipping evaluation.
# User 438718 not found in training data. Skipping evaluation.
# User 198359 not found in training data. Skipping evaluation.
# User 937263 not found in training data. Skipping evaluation.
# User 3521 not found in training data. Skipping evaluation.
# User 189324 not found in training data. Skipping evaluation.
# User 131821 not found in training data. Skipping evaluation.
# User 535918 not found in training data. Skipping evaluation.
# User 207452 not found in training data. Skipping evaluation.
# User 424928 not found in training data. Skipping evaluation.
# User 901840 not found in training data. Skipping evaluation.
# User 491752 not found in training data. Skipping evaluation.
# User 542847 not found in training data. Skipping evaluation.
# User 562382 not found in training data. Skipping evaluation.
# User 153072 not found in training data. Skipping evaluation.
# User 921163 not found in training data. Skipping evaluation.
# User 369187 not found in training data. Skipping evaluation.
# User 706855 not found in training data. Skipping evaluation.
# User 572361 not found in training data. Skipping evaluation.
# User 112528 not found in training data. Skipping evaluation.
# User 93272 not found in training data. Skipping evaluation.
# User 699274 not found in training data. Skipping evaluation.
# User 778362 not found in training data. Skipping evaluation.
# User 186420 not found in training data. Skipping evaluation.
# User 399178 not found in training data. Skipping evaluation.
# User 94684 not found in training data. Skipping evaluation.
# User 811999 not found in training data. Skipping evaluation.
# User 535438 not found in training data. Skipping evaluation.
# User 605788 not found in training data. Skipping evaluation.
# User 235556 not found in training data. Skipping evaluation.
# User 606944 not found in training data. Skipping evaluation.
# User 213848 not found in training data. Skipping evaluation.
# User 272266 not found in training data. Skipping evaluation.
# User 785590 not found in training data. Skipping evaluation.
# User 792966 not found in training data. Skipping evaluation.
# User 497503 not found in training data. Skipping evaluation.
# User 245342 not found in training data. Skipping evaluation.
# User 363358 not found in training data. Skipping evaluation.
# User 829214 not found in training data. Skipping evaluation.
# User 396100 not found in training data. Skipping evaluation.
# User 326209 not found in training data. Skipping evaluation.
# User 836746 not found in training data. Skipping evaluation.
# User 942 not found in training data. Skipping evaluation.
# User 896818 not found in training data. Skipping evaluation.
# User 404963 not found in training data. Skipping evaluation.
# User 509966 not found in training data. Skipping evaluation.
# User 489594 not found in training data. Skipping evaluation.
# User 867463 not found in training data. Skipping evaluation.
# User 367526 not found in training data. Skipping evaluation.
# User 434812 not found in training data. Skipping evaluation.
# User 675796 not found in training data. Skipping evaluation.
# User 537729 not found in training data. Skipping evaluation.
# User 486610 not found in training data. Skipping evaluation.
# User 332 not found in training data. Skipping evaluation.
# User 635451 not found in training data. Skipping evaluation.
# User 932710 not found in training data. Skipping evaluation.
# User 558575 not found in training data. Skipping evaluation.
# User 67478 not found in training data. Skipping evaluation.
# User 172742 not found in training data. Skipping evaluation.
# User 171104 not found in training data. Skipping evaluation.
# User 279667 not found in training data. Skipping evaluation.
# User 737697 not found in training data. Skipping evaluation.
# User 637745 not found in training data. Skipping evaluation.
# User 168221 not found in training data. Skipping evaluation.
# User 712518 not found in training data. Skipping evaluation.
# User 910927 not found in training data. Skipping evaluation.
# User 94458 not found in training data. Skipping evaluation.
# User 883379 not found in training data. Skipping evaluation.
# User 633931 not found in training data. Skipping evaluation.
# User 90382 not found in training data. Skipping evaluation.
# User 40266 not found in training data. Skipping evaluation.
# User 25262 not found in training data. Skipping evaluation.
# User 376571 not found in training data. Skipping evaluation.
# User 480676 not found in training data. Skipping evaluation.
# User 388488 not found in training data. Skipping evaluation.
# User 342859 not found in training data. Skipping evaluation.
# User 432017 not found in training data. Skipping evaluation.
# User 305091 not found in training data. Skipping evaluation.
# User 718023 not found in training data. Skipping evaluation.
# User 911745 not found in training data. Skipping evaluation.
# User 598903 not found in training data. Skipping evaluation.
# User 491466 not found in training data. Skipping evaluation.
# User 47317 not found in training data. Skipping evaluation.
# User 582072 not found in training data. Skipping evaluation.
# User 377407 not found in training data. Skipping evaluation.
# User 787286 not found in training data. Skipping evaluation.
# User 707353 not found in training data. Skipping evaluation.
# User 852540 not found in training data. Skipping evaluation.
# User 995731 not found in training data. Skipping evaluation.
# User 586111 not found in training data. Skipping evaluation.
# User 912941 not found in training data. Skipping evaluation.
# User 445267 not found in training data. Skipping evaluation.
# User 704084 not found in training data. Skipping evaluation.
# User 627668 not found in training data. Skipping evaluation.
# User 952408 not found in training data. Skipping evaluation.
# User 745989 not found in training data. Skipping evaluation.
# User 45800 not found in training data. Skipping evaluation.
# User 960778 not found in training data. Skipping evaluation.
# User 771450 not found in training data. Skipping evaluation.
# User 483552 not found in training data. Skipping evaluation.
# User 257420 not found in training data. Skipping evaluation.
# User 971864 not found in training data. Skipping evaluation.
# User 462980 not found in training data. Skipping evaluation.
# User 991556 not found in training data. Skipping evaluation.
# User 48514 not found in training data. Skipping evaluation.
# User 911594 not found in training data. Skipping evaluation.
# User 786639 not found in training data. Skipping evaluation.
# User 85200 not found in training data. Skipping evaluation.
# User 968542 not found in training data. Skipping evaluation.
# User 468552 not found in training data. Skipping evaluation.
# User 136390 not found in training data. Skipping evaluation.
# User 265423 not found in training data. Skipping evaluation.
# User 238480 not found in training data. Skipping evaluation.
# User 770112 not found in training data. Skipping evaluation.
# User 594966 not found in training data. Skipping evaluation.
# User 896742 not found in training data. Skipping evaluation.
# User 900230 not found in training data. Skipping evaluation.
# User 536483 not found in training data. Skipping evaluation.
# User 582665 not found in training data. Skipping evaluation.
# User 768250 not found in training data. Skipping evaluation.
# User 351508 not found in training data. Skipping evaluation.
# User 975051 not found in training data. Skipping evaluation.
# User 717696 not found in training data. Skipping evaluation.
# User 600307 not found in training data. Skipping evaluation.
# User 520918 not found in training data. Skipping evaluation.
# User 455656 not found in training data. Skipping evaluation.
# User 207069 not found in training data. Skipping evaluation.
# User 890698 not found in training data. Skipping evaluation.
# User 763093 not found in training data. Skipping evaluation.
# User 731862 not found in training data. Skipping evaluation.
# User 542855 not found in training data. Skipping evaluation.
# User 678 not found in training data. Skipping evaluation.
# User 141597 not found in training data. Skipping evaluation.
# User 122522 not found in training data. Skipping evaluation.
# User 580708 not found in training data. Skipping evaluation.
# User 303282 not found in training data. Skipping evaluation.
# User 413115 not found in training data. Skipping evaluation.
# User 426746 not found in training data. Skipping evaluation.
# User 832277 not found in training data. Skipping evaluation.
# User 720718 not found in training data. Skipping evaluation.
# User 111181 not found in training data. Skipping evaluation.
# User 875810 not found in training data. Skipping evaluation.
# User 956144 not found in training data. Skipping evaluation.
# User 896964 not found in training data. Skipping evaluation.
# User 727848 not found in training data. Skipping evaluation.
# User 745553 not found in training data. Skipping evaluation.
# User 69343 not found in training data. Skipping evaluation.
# User 270224 not found in training data. Skipping evaluation.
# User 105893 not found in training data. Skipping evaluation.
# User 32911 not found in training data. Skipping evaluation.
# User 834257 not found in training data. Skipping evaluation.
# User 187590 not found in training data. Skipping evaluation.
# User 295950 not found in training data. Skipping evaluation.
# User 549123 not found in training data. Skipping evaluation.
# User 524834 not found in training data. Skipping evaluation.
# User 744829 not found in training data. Skipping evaluation.
# User 842905 not found in training data. Skipping evaluation.
# User 717817 not found in training data. Skipping evaluation.
# User 793437 not found in training data. Skipping evaluation.
# User 141112 not found in training data. Skipping evaluation.
# User 747075 not found in training data. Skipping evaluation.
# User 620597 not found in training data. Skipping evaluation.
# User 112258 not found in training data. Skipping evaluation.
# User 164789 not found in training data. Skipping evaluation.
# User 763963 not found in training data. Skipping evaluation.
# User 108266 not found in training data. Skipping evaluation.
# User 188686 not found in training data. Skipping evaluation.
# User 800019 not found in training data. Skipping evaluation.
# User 115072 not found in training data. Skipping evaluation.
# User 982462 not found in training data. Skipping evaluation.
# User 531285 not found in training data. Skipping evaluation.
# User 757514 not found in training data. Skipping evaluation.
# User 429970 not found in training data. Skipping evaluation.
# User 139783 not found in training data. Skipping evaluation.
# User 964117 not found in training data. Skipping evaluation.
# User 884763 not found in training data. Skipping evaluation.
# User 717963 not found in training data. Skipping evaluation.
# User 694013 not found in training data. Skipping evaluation.
# User 144050 not found in training data. Skipping evaluation.
# User 708291 not found in training data. Skipping evaluation.
# User 169215 not found in training data. Skipping evaluation.
# User 514331 not found in training data. Skipping evaluation.
# User 140761 not found in training data. Skipping evaluation.
# User 857890 not found in training data. Skipping evaluation.
# User 183488 not found in training data. Skipping evaluation.
# User 121825 not found in training data. Skipping evaluation.
# User 796355 not found in training data. Skipping evaluation.
# User 945200 not found in training data. Skipping evaluation.
# User 84739 not found in training data. Skipping evaluation.
# User 238967 not found in training data. Skipping evaluation.
# User 298520 not found in training data. Skipping evaluation.
# User 880762 not found in training data. Skipping evaluation.
# ...
# User 816877 not found in training data. Skipping evaluation.
# User 707988 not found in training data. Skipping evaluation.
# User 355537 not found in training data. Skipping evaluation.
# User 294913 not found in training data. Skipping evaluation.
# User 44953 not found in training data. Skipping evaluation.
# User 485648 not found in training data. Skipping evaluation.
# User 268303 not found in training data. Skipping evaluation.
# User 905693 not found in training data. Skipping evaluation.
# User 249174 not found in training data. Skipping evaluation.
# User 652439 not found in training data. Skipping evaluation.
# User 419600 not found in training data. Skipping evaluation.
# User 973935 not found in training data. Skipping evaluation.
# User 153590 not found in training data. Skipping evaluation.
# User 373194 not found in training data. Skipping evaluation.
# User 634890 not found in training data. Skipping evaluation.
# User 646626 not found in training data. Skipping evaluation.
# User 817212 not found in training data. Skipping evaluation.
# User 360246 not found in training data. Skipping evaluation.
# User 88928 not found in training data. Skipping evaluation.
# User 446034 not found in training data. Skipping evaluation.
# User 417338 not found in training data. Skipping evaluation.
# User 152221 not found in training data. Skipping evaluation.
# User 227238 not found in training data. Skipping evaluation.
# User 843261 not found in training data. Skipping evaluation.
# User 820288 not found in training data. Skipping evaluation.
# User 519408 not found in training data. Skipping evaluation.
# User 578567 not found in training data. Skipping evaluation.
# User 57196 not found in training data. Skipping evaluation.
# User 471929 not found in training data. Skipping evaluation.
# User 453578 not found in training data. Skipping evaluation.
# User 959863 not found in training data. Skipping evaluation.
# User 403613 not found in training data. Skipping evaluation.
# User 62326 not found in training data. Skipping evaluation.
# User 921495 not found in training data. Skipping evaluation.
# User 854489 not found in training data. Skipping evaluation.
# User 820546 not found in training data. Skipping evaluation.
# User 545663 not found in training data. Skipping evaluation.
# User 443153 not found in training data. Skipping evaluation.
# User 919395 not found in training data. Skipping evaluation.
# User 698260 not found in training data. Skipping evaluation.
# User 792289 not found in training data. Skipping evaluation.
# User 815864 not found in training data. Skipping evaluation.
# User 339281 not found in training data. Skipping evaluation.
# User 931949 not found in training data. Skipping evaluation.
# User 322467 not found in training data. Skipping evaluation.
# User 853956 not found in training data. Skipping evaluation.
# User 983726 not found in training data. Skipping evaluation.
# User 435460 not found in training data. Skipping evaluation.
# User 882762 not found in training data. Skipping evaluation.
# User 155885 not found in training data. Skipping evaluation.
# User 165722 not found in training data. Skipping evaluation.
# User 271261 not found in training data. Skipping evaluation.
# User 180460 not found in training data. Skipping evaluation.
# User 329882 not found in training data. Skipping evaluation.
# User 265077 not found in training data. Skipping evaluation.
# User 918150 not found in training data. Skipping evaluation.
# User 575735 not found in training data. Skipping evaluation.
# User 839941 not found in training data. Skipping evaluation.
# User 410656 not found in training data. Skipping evaluation.
# User 916455 not found in training data. Skipping evaluation.
# User 748301 not found in training data. Skipping evaluation.
# User 802163 not found in training data. Skipping evaluation.
# User 302919 not found in training data. Skipping evaluation.
# User 955725 not found in training data. Skipping evaluation.
# User 215656 not found in training data. Skipping evaluation.
# User 379415 not found in training data. Skipping evaluation.
# User 446338 not found in training data. Skipping evaluation.
# User 861493 not found in training data. Skipping evaluation.
# User 527155 not found in training data. Skipping evaluation.
# User 539011 not found in training data. Skipping evaluation.
# User 383515 not found in training data. Skipping evaluation.
# User 385133 not found in training data. Skipping evaluation.
# User 680224 not found in training data. Skipping evaluation.
# User 118893 not found in training data. Skipping evaluation.
# User 347899 not found in training data. Skipping evaluation.
# User 515360 not found in training data. Skipping evaluation.
# User 264765 not found in training data. Skipping evaluation.
# User 236315 not found in training data. Skipping evaluation.
# User 392585 not found in training data. Skipping evaluation.
# User 294576 not found in training data. Skipping evaluation.
# User 38366 not found in training data. Skipping evaluation.
# User 915013 not found in training data. Skipping evaluation.
# User 568366 not found in training data. Skipping evaluation.
# User 892346 not found in training data. Skipping evaluation.
# User 649160 not found in training data. Skipping evaluation.
# User 231820 not found in training data. Skipping evaluation.
# User 125283 not found in training data. Skipping evaluation.
# User 104912 not found in training data. Skipping evaluation.
# User 827608 not found in training data. Skipping evaluation.
# User 438491 not found in training data. Skipping evaluation.
# User 125885 not found in training data. Skipping evaluation.
# User 102248 not found in training data. Skipping evaluation.
# User 321135 not found in training data. Skipping evaluation.
# User 177699 not found in training data. Skipping evaluation.
# User 100710 not found in training data. Skipping evaluation.
# User 115639 not found in training data. Skipping evaluation.
# User 799297 not found in training data. Skipping evaluation.
# User 265971 not found in training data. Skipping evaluation.
# User 957130 not found in training data. Skipping evaluation.
# User 66396 not found in training data. Skipping evaluation.
# User 69716 not found in training data. Skipping evaluation.
# User 192564 not found in training data. Skipping evaluation.
# User 522482 not found in training data. Skipping evaluation.
# User 206463 not found in training data. Skipping evaluation.
# User 519109 not found in training data. Skipping evaluation.
# User 747257 not found in training data. Skipping evaluation.
# User 353508 not found in training data. Skipping evaluation.
# User 43488 not found in training data. Skipping evaluation.
# User 996090 not found in training data. Skipping evaluation.
# User 814803 not found in training data. Skipping evaluation.
# User 407420 not found in training data. Skipping evaluation.
# User 627569 not found in training data. Skipping evaluation.
# User 288258 not found in training data. Skipping evaluation.
# User 347773 not found in training data. Skipping evaluation.
# User 416361 not found in training data. Skipping evaluation.
# User 580159 not found in training data. Skipping evaluation.
# User 310054 not found in training data. Skipping evaluation.
# User 702143 not found in training data. Skipping evaluation.
# User 450759 not found in training data. Skipping evaluation.
# User 412419 not found in training data. Skipping evaluation.
# User 44239 not found in training data. Skipping evaluation.
# User 607604 not found in training data. Skipping evaluation.
# User 613367 not found in training data. Skipping evaluation.
# User 950454 not found in training data. Skipping evaluation.
# User 587485 not found in training data. Skipping evaluation.
# User 208596 not found in training data. Skipping evaluation.
# User 923135 not found in training data. Skipping evaluation.
# User 347485 not found in training data. Skipping evaluation.
# User 922105 not found in training data. Skipping evaluation.
# User 226492 not found in training data. Skipping evaluation.
# User 541759 not found in training data. Skipping evaluation.
# User 878771 not found in training data. Skipping evaluation.
# User 69296 not found in training data. Skipping evaluation.
# User 184422 not found in training data. Skipping evaluation.
# User 880539 not found in training data. Skipping evaluation.
# User 126490 not found in training data. Skipping evaluation.
# User 805873 not found in training data. Skipping evaluation.
# User 207461 not found in training data. Skipping evaluation.
# User 90352 not found in training data. Skipping evaluation.
# User 112637 not found in training data. Skipping evaluation.
# User 421978 not found in training data. Skipping evaluation.
# User 955738 not found in training data. Skipping evaluation.
# User 482989 not found in training data. Skipping evaluation.
# User 636315 not found in training data. Skipping evaluation.
# User 788280 not found in training data. Skipping evaluation.
# User 94174 not found in training data. Skipping evaluation.
# User 98430 not found in training data. Skipping evaluation.
# User 35925 not found in training data. Skipping evaluation.
# User 226213 not found in training data. Skipping evaluation.
# User 407722 not found in training data. Skipping evaluation.
# User 812428 not found in training data. Skipping evaluation.
# User 283597 not found in training data. Skipping evaluation.
# User 824982 not found in training data. Skipping evaluation.
# User 795651 not found in training data. Skipping evaluation.
# User 111908 not found in training data. Skipping evaluation.
# User 123588 not found in training data. Skipping evaluation.
# User 907073 not found in training data. Skipping evaluation.
# User 448262 not found in training data. Skipping evaluation.
# User 968168 not found in training data. Skipping evaluation.
# User 279801 not found in training data. Skipping evaluation.
# User 990259 not found in training data. Skipping evaluation.
# User 857921 not found in training data. Skipping evaluation.
# User 431717 not found in training data. Skipping evaluation.
# User 325083 not found in training data. Skipping evaluation.
# User 159101 not found in training data. Skipping evaluation.
# User 767765 not found in training data. Skipping evaluation.
# User 996408 not found in training data. Skipping evaluation.
# User 721095 not found in training data. Skipping evaluation.
# User 388369 not found in training data. Skipping evaluation.
# User 873239 not found in training data. Skipping evaluation.
# User 258014 not found in training data. Skipping evaluation.
# User 357032 not found in training data. Skipping evaluation.
# User 526657 not found in training data. Skipping evaluation.
# User 196181 not found in training data. Skipping evaluation.
# User 801450 not found in training data. Skipping evaluation.
# User 104901 not found in training data. Skipping evaluation.
# User 960365 not found in training data. Skipping evaluation.
# User 712619 not found in training data. Skipping evaluation.
# User 966913 not found in training data. Skipping evaluation.
# User 704518 not found in training data. Skipping evaluation.
# User 722916 not found in training data. Skipping evaluation.
# User 473571 not found in training data. Skipping evaluation.
# User 587460 not found in training data. Skipping evaluation.
# User 417998 not found in training data. Skipping evaluation.
# User 511162 not found in training data. Skipping evaluation.
# User 678424 not found in training data. Skipping evaluation.
# User 308996 not found in training data. Skipping evaluation.
# User 720920 not found in training data. Skipping evaluation.
# User 975283 not found in training data. Skipping evaluation.
# User 614851 not found in training data. Skipping evaluation.
# User 285620 not found in training data. Skipping evaluation.
# User 396018 not found in training data. Skipping evaluation.
# User 153673 not found in training data. Skipping evaluation.
# User 49099 not found in training data. Skipping evaluation.
# User 121031 not found in training data. Skipping evaluation.
# User 84679 not found in training data. Skipping evaluation.
# User 90653 not found in training data. Skipping evaluation.
# User 568935 not found in training data. Skipping evaluation.
# User 602147 not found in training data. Skipping evaluation.
# User 118258 not found in training data. Skipping evaluation.
# User 582539 not found in training data. Skipping evaluation.
# User 609814 not found in training data. Skipping evaluation.
# User 329702 not found in training data. Skipping evaluation.
# User 684221 not found in training data. Skipping evaluation.
# User 659172 not found in training data. Skipping evaluation.
# User 650502 not found in training data. Skipping evaluation.
# User 134775 not found in training data. Skipping evaluation.
# User 657713 not found in training data. Skipping evaluation.
# User 944677 not found in training data. Skipping evaluation.
# User 592156 not found in training data. Skipping evaluation.
# User 675498 not found in training data. Skipping evaluation.
# User 984811 not found in training data. Skipping evaluation.
# User 506657 not found in training data. Skipping evaluation.
# User 802240 not found in training data. Skipping evaluation.
# User 49530 not found in training data. Skipping evaluation.
# User 384024 not found in training data. Skipping evaluation.
# Metrics for round 3: {'ndcg@k': 0.002938381990438287, 'hr@k': 0.006, 'mrr@k': 0.0019444444444444444, 'DI_NDCG': 0.9818839325837447, 'GRU_NDCG': 5.339130597340272e-05, 'ndcg_low': 0.0028937883852158345, 'ndcg_moderate_high': 0.002947179691189237, 'CV': 0.012, 'cv_low': 0.012137559002022926, 'cv_moderate_high': 0.011972861513901822, 'HR_LOW': 0.006068779501011463, 'HR_MODERATE_HIGH': 0.005986430756950911, 'MRR_LOW': 0.0018655877725331535, 'MRR_MODERATE_HIGH': 0.0019600017737572612, 'UCV_NDCG': 13.074922174816814, 'UCV_HR': 12.841696301937258, 'UCV_MRR': 13.673085520268357, 'DI_HR': 1.0137559002022927, 'GRU_HR': 8.23487440605522e-05, 'DI_MRR': 0.95182963480532, 'GRU_MRR': 9.441400122410775e-05}
#
# Overall Results:
# {1: {'ndcg@k': 0.0032436810153349226, 'hr@k': 0.0064444444444444445, 'mrr@k': 0.002194444444444444, 'DI_NDCG': 1.9488763145771328, 'GRU_NDCG': 0.0026616873421238326, 'ndcg_low': 0.0054667814320843505, 'ndcg_moderate_high': 0.002805094089960518, 'CV': 0.012888888888888889, 'cv_low': 0.02157788267026298, 'cv_moderate_high': 0.011174670746308367, 'HR_LOW': 0.01078894133513149, 'HR_MODERATE_HIGH': 0.0055873353731541835, 'MRR_LOW': 0.0037199370645088783, 'MRR_MODERATE_HIGH': 0.0018934858764578066, 'UCV_NDCG': 11.64644070136195, 'UCV_HR': 11.458065367879275, 'UCV_MRR': 12.075506405521077, 'DI_HR': 1.9309636194329385, 'GRU_HR': 0.005201605961977307, 'DI_MRR': 1.964597207066504, 'GRU_MRR': 0.0018264511880510717}, 2: {'ndcg@k': 0.0030591744490191834, 'hr@k': 0.006111111111111111, 'mrr@k': 0.0020703703703703704, 'DI_NDCG': 1.6424746662995122, 'GRU_NDCG': 0.0017772884662253896, 'ndcg_low': 0.004543605271309878, 'ndcg_moderate_high': 0.0027663168050844887, 'CV': 0.012222222222222223, 'cv_low': 0.01753202966958867, 'cv_moderate_high': 0.011174670746308367, 'HR_LOW': 0.008766014834794335, 'HR_MODERATE_HIGH': 0.0055873353731541835, 'MRR_LOW': 0.003158013036637447, 'MRR_MODERATE_HIGH': 0.0018557935346547824, 'UCV_NDCG': 12.307826946650248, 'UCV_HR': 11.987267544517136, 'UCV_MRR': 13.054980436172727, 'DI_HR': 1.5689079407892623, 'GRU_HR': 0.0031786794616401517, 'DI_MRR': 1.7017049459787592, 'GRU_MRR': 0.0013022195019826645}, 3: {'ndcg@k': 0.002938381990438287, 'hr@k': 0.006, 'mrr@k': 0.0019444444444444444, 'DI_NDCG': 0.9818839325837447, 'GRU_NDCG': 5.339130597340272e-05, 'ndcg_low': 0.0028937883852158345, 'ndcg_moderate_high': 0.002947179691189237, 'CV': 0.012, 'cv_low': 0.012137559002022926, 'cv_moderate_high': 0.011972861513901822, 'HR_LOW': 0.006068779501011463, 'HR_MODERATE_HIGH': 0.005986430756950911, 'MRR_LOW': 0.0018655877725331535, 'MRR_MODERATE_HIGH': 0.0019600017737572612, 'UCV_NDCG': 13.074922174816814, 'UCV_HR': 12.841696301937258, 'UCV_MRR': 13.673085520268357, 'DI_HR': 1.0137559002022927, 'GRU_HR': 8.23487440605522e-05, 'DI_MRR': 0.95182963480532, 'GRU_MRR': 9.441400122410775e-05}}

# %% [markdown]
# Overall Results:
# {1: {'ndcg@k': 0.0032436810153349226, 'hr@k': 0.0064444444444444445, 'mrr@k': 0.002194444444444444, 'DI_NDCG': 1.9488763145771328, 'GRU_NDCG': 0.0026616873421238326, 'ndcg_low': 0.0054667814320843505, 'ndcg_moderate_high': 0.002805094089960518, 'CV': 0.012888888888888889, 'cv_low': 0.02157788267026298, 'cv_moderate_high': 0.011174670746308367, 'HR_LOW': 0.01078894133513149, 'HR_MODERATE_HIGH': 0.0055873353731541835, 'MRR_LOW': 0.0037199370645088783, 'MRR_MODERATE_HIGH': 0.0018934858764578066, 'UCV_NDCG': 11.64644070136195, 'UCV_HR': 11.458065367879275, 'UCV_MRR': 12.075506405521077, 'DI_HR': 1.9309636194329385, 'GRU_HR': 0.005201605961977307, 'DI_MRR': 1.964597207066504, 'GRU_MRR': 0.0018264511880510717}, 2: {'ndcg@k': 0.0030591744490191834, 'hr@k': 0.006111111111111111, 'mrr@k': 0.0020703703703703704, 'DI_NDCG': 1.6424746662995122, 'GRU_NDCG': 0.0017772884662253896, 'ndcg_low': 0.004543605271309878, 'ndcg_moderate_high': 0.0027663168050844887, 'CV': 0.012222222222222223, 'cv_low': 0.01753202966958867, 'cv_moderate_high': 0.011174670746308367, 'HR_LOW': 0.008766014834794335, 'HR_MODERATE_HIGH': 0.0055873353731541835, 'MRR_LOW': 0.003158013036637447, 'MRR_MODERATE_HIGH': 0.0018557935346547824, 'UCV_NDCG': 12.307826946650248, 'UCV_HR': 11.987267544517136, 'UCV_MRR': 13.054980436172727, 'DI_HR': 1.5689079407892623, 'GRU_HR': 0.0031786794616401517, 'DI_MRR': 1.7017049459787592, 'GRU_MRR': 0.0013022195019826645}, 3: {'ndcg@k': 0.002938381990438287, 'hr@k': 0.006, 'mrr@k': 0.0019444444444444444, 'DI_NDCG': 0.9818839325837447, 'GRU_NDCG': 5.339130597340272e-05, 'ndcg_low': 0.0028937883852158345, 'ndcg_moderate_high': 0.002947179691189237, 'CV': 0.012, 'cv_low': 0.012137559002022926, 'cv_moderate_high': 0.011972861513901822, 'HR_LOW': 0.006068779501011463, 'HR_MODERATE_HIGH': 0.005986430756950911, 'MRR_LOW': 0.0018655877725331535, 'MRR_MODERATE_HIGH': 0.0019600017737572612, 'UCV_NDCG': 13.074922174816814, 'UCV_HR': 12.841696301937258, 'UCV_MRR': 13.673085520268357, 'DI_HR': 1.0137559002022927, 'GRU_HR': 8.23487440605522e-05, 'DI_MRR': 0.95182963480532, 'GRU_MRR': 9.441400122410775e-05}}

# %%
metrics = ["NDCG@K", "HR@K", "MRR@K"]

for metric in metrics:
    low_metric = grouped_metrics_lightfm.loc["Low", metric]
    high_metric = grouped_metrics_lightfm.loc["High", metric]

    di = calculate_disparate_impact([low_metric], [high_metric]) 
    gru = calculate_group_recommender_unfairness([low_metric], [high_metric])

    print(f"\nLightFM - {metric} Metrics:")
    print(f"Disparate Impact: {di}")
    print(f"Group Recommender Unfairness: {gru}")
# Out:
# LightFM - NDCG@K Metrics:
# Disparate Impact: 2.336459514210217
# Group Recommender Unfairness: 0.017081941766557376
#
# LightFM - HR@K Metrics:
# Disparate Impact: 2.2052482244660263
# Group Recommender Unfairness: 0.024691795472631107
#
# LightFM - MRR@K Metrics:
# Disparate Impact: 2.5209304315970447
# Group Recommender Unfairness: 0.012699711776405637
